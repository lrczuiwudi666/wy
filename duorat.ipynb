# %%
# coding=utf8

import os
import json
import numpy as np
import pandas as pd
from pprint import pprint
from typing import List, Dict
from sql_hardness import eval_hardness, eval_hardness_by_from

# %%
original_sparc_dev_path = os.path.join('..', 'data', 'original_sparc_dev.json')
sparc_dev_annotated_path = os.path.join('..', 'data', 'sparc_dev_annotated.tsv')
duorat_sparc_path = os.path.join('..', 'data', 'duorat_sparc.json')
editsql_sparc_path = os.path.join('..', 'data', 'editsql_sparc.json')
igsql_sparc_path = os.path.join('..', 'data', 'igsql_sparc.json')

# %%
def read_annotation(path: str) -> pd.DataFrame:
    df = pd.read_csv(path, sep='\t')
    df.fillna('', inplace=True)
    return df


def read_json(path: str) -> List[Dict]:
    with open(path, 'r', encoding="utf8") as f:
        return json.load(f)


def read_predictions(path: str) -> List[Dict]:
    predictions = list()
    with open(path, 'r') as f:
        predictions = json.load(f)
    interaction_ids, turn_ids = set(), set()
    for p in predictions:
        turn_ids.add(p['turn_id'])
        interaction_ids.add(p['interaction_id'])
    total_question_sequence = len(interaction_ids)
    total_question = len(predictions)
    print(total_question_sequence, total_question)
    
    grouped_predictions = list()
    for example_id in interaction_ids:
        result = {"example_id": example_id, "interaction": list()}
        for turn_id in [1, 2, 3, 4, 5]:
            for p in predictions:
                if p['interaction_id'] == example_id and p['turn_id'] == turn_id:
                    result['interaction'].append(p)
                    break
            else:
                # Not found
                break
        grouped_predictions.append(result)
    
    print(len(grouped_predictions))
    assert len(grouped_predictions) == total_question_sequence
    _count = sum([len(gp['interaction']) for gp in grouped_predictions])
    print(_count)
    assert _count == total_question
    
    return grouped_predictions


def measure_accuracy(predictions: List[Dict]):
    question_match = 0
    question_sequence_match = 0
    total_question = sum([len(p['interaction']) for p in predictions])
    total_question_sequence = len(predictions)
    
    for p in predictions:
        has_error = False
        for turn in p['interaction']:
            if turn['exact'] == 1 or turn['exact'] is True:
                question_match += 1
            else:
                has_error = True
        if not has_error:
            question_sequence_match += 1
    
    print("Question Match: %f" % (question_match / total_question))
    print("Interaction Match: %f" % (question_sequence_match / total_question_sequence))
    

CONTEXTUAL_PHENOMENA = ['Coreference', 'Part/Whole', 'Ellipsis', 'Explict/Implict', 'Operator/Schema', 'Modification/Continutation']

    
def measure_context_independent_accuracy(predictions: List[Dict], source_examples: List[Dict], annotation: pd.DataFrame):
    dependent_match, dependent_total = 0, 0
    independent_match, independent_total = 0, 0
    first_independent_match, first_independent_total = 0, 0
    other_independent_match, other_independent_total = 0, 0
    total_question = 0
    independent_hardness = {"easy": 0, "medium": 0, "hard": 0, "extra": 0}
    dependent_hardness = {"easy": 0, "medium": 0, "hard": 0, "extra": 0}
    independent_hardness_match = {"easy": 0, "medium": 0, "hard": 0, "extra": 0}
    dependent_hardness_match = {"easy": 0, "medium": 0, "hard": 0, "extra": 0}

    for p in predictions:
        example_id = p['example_id']
        for turn in p['interaction']:
            total_question += 1
            turn_id = turn['turn_id']
            source_turn = source_examples[example_id - 1]['interaction'][turn_id - 1]
            print(source_turn['utterance'].lower().strip(), turn['question'].lower().strip())
            assert source_turn['utterance'].lower().strip().replace(" ", "").replace("`", "").replace('"', "").replace("''", "") in turn['question'].lower().strip().replace(" ", "").replace("`", "").replace('"', "").replace("''", "")
            hardness = eval_hardness(source_turn['sql'])
            row = annotation[(annotation.InterID == example_id - 1) & (annotation.Turn == turn_id - 1)]
            is_independent = all([row.iloc[0][key] == "" for key in CONTEXTUAL_PHENOMENA]) or row.iloc[0]["Ellipsis"] == "Context Independent"
            if is_independent:
                if turn['exact'] == 1 or turn['exact'] is True:
                    independent_match += 1
                    independent_hardness_match[hardness] += 1
                independent_total += 1
                independent_hardness[hardness] += 1
                
                if row.iloc[0]["Ellipsis"] == "Context Independent":
                    if turn['exact'] == 1 or turn['exact'] is True:
                        other_independent_match += 1
                    other_independent_total += 1
                else:
                    # First
                    if turn['exact'] == 1 or turn['exact'] is True:
                        first_independent_match += 1
                    first_independent_total += 1
                
            else:
                if turn['exact'] == 1 or turn['exact'] is True:
                    dependent_match += 1
                    dependent_hardness_match[hardness] += 1
                dependent_total += 1
                dependent_hardness[hardness] += 1
    
    print("Independent: %d, %d, %f" % (independent_match, independent_total, independent_match / independent_total))
    print("Dependent: %d, %d, %f" % (dependent_match, dependent_total, dependent_match / dependent_total))
    
    print("First Independent: %d, %d, %f" % (first_independent_match, first_independent_total, first_independent_match / first_independent_total))
    print("Other Independent: %d, %d, %f" % (other_independent_match, other_independent_total, other_independent_match / other_independent_total))
    
    assert independent_total + dependent_total == total_question
    print("Independent Percent: %f" % (independent_total / total_question))

    pprint(independent_hardness)
    pprint(independent_hardness_match)
    pprint(dependent_hardness)

    pprint({key: value / independent_total for key, value in independent_hardness.items()})
    pprint({key: value / dependent_total for key, value in dependent_hardness.items()})
    
    # Total Hardness
    total_hardness = {k: independent_hardness[k] + dependent_hardness[k] for k in ["easy", "medium", "hard", "extra"]}
    total_hardness_match = {k: independent_hardness_match[k] + dependent_hardness_match[k] for k in ["easy", "medium", "hard", "extra"]}
    total_hardness = {k: independent_hardness[k] + dependent_hardness[k] for k in ["easy", "medium", "hard", "extra"]}
    total_hardness_distribution = {k: (independent_hardness[k] + dependent_hardness[k]) / total_question for k in ["easy", "medium", "hard", "extra"]}
    total_hardness_accuracy = {k: total_hardness_match[k] / total_hardness[k] for k in ["easy", "medium", "hard", "extra"]}
    print("Total Hardness: ", total_hardness)
    print("Total Hardness Distribution: ", total_hardness_distribution)
    print("Total Hardness Match: ", total_hardness_match)
    print("Total Hardness Accuracy: ", total_hardness_accuracy)

# %%
sparc_dev = read_json(original_sparc_dev_path)

# %%
duorat_sparc_predictions = read_predictions(duorat_sparc_path)
# Out:
# 422 1203
# 422
# 1203

# %%
measure_accuracy(duorat_sparc_predictions)
# Out:
# Question Match: 0.600998
# Interaction Match: 0.386256

# %%
sparc_annotation_df = read_annotation(sparc_dev_annotated_path)

# %%
sparc_annotation_df[(sparc_annotation_df.InterID == 0) & (sparc_annotation_df.Turn == 0)]
# Out:
#    InterID  Turn Database_ID                    Utterance Coreference  \
# 0        0     0    flight_2  what are all the airlines ?
#
#   Part/Whole Ellipsis Explict/Implict Operator/Schema  \
# 0
#
#   Modification/Continutation
# 0

# %%
measure_context_independent_accuracy(duorat_sparc_predictions, sparc_dev, sparc_annotation_df)
# Out:
# what are all the airlines? [sep] what are all the airlines?
# of these, which is jetblue airways? [sep] of these, which is jetblue airways? [sep] what are all the airlines?
# what is the country corresponding it? [sep] what is the country corresponding it? [sep] of these, which is jetblue airways? [sep] what are all the airlines?
# what are all the abbreviations? [sep] what are all the abbreviations?
# what is the abbreviation for jetblue airways? [sep] what is the abbreviation for jetblue airways? [sep] what are all the abbreviations?
# list all airline names and their abbreviations. [sep] list all airline names and their abbreviations.
# of these, list only those in the usa. [sep] of these, list only those in the usa. [sep] list all airline names and their abbreviations.
# find all information about the airport in the city anthony. [sep] find all information about the airport in the city anthony.
# what is the airport code and airport name? [sep] what is the airport code and airport name? [sep] find all information about the airport in the city anthony.
# what are all the airlines? [sep] what are all the airlines?
# how many are there? [sep] how many are there? [sep] what are all the airlines?
# what are all the airports? [sep] what are all the airports?
# how many are there? [sep] how many are there? [sep] what are all the airports?
# what are all the flights? [sep] what are all the flights?
# how many are there? [sep] how many are there? [sep] what are all the flights?
# what are all the airline names? [sep] what are all the airline names?
# of this, which has the abbreviation 'ual'? [sep] of this, which has the abbreviation 'ual'? [sep] what are all the airline names?
# what are the names of the airlines in the usa? [sep] what are the names of the airlines in the usa?
# how many are there? [sep] how many are there? [sep] what are the names of the airlines in the usa?
# what are the city and country for all airports? [sep] what are the city and country for all airports?
# of these, what are the city and country for alton airport? [sep] of these, what are the city and country for alton airport? [sep] what are the city and country for all airports?
# what are all the airport names? [sep] what are all the airport names?
# of these, which has code 'ako'? [sep] of these, which has code 'ako'? [sep] what are all the airport names?
# what are all the airport names? [sep] what are all the airport names?
# which is in aberdeen? [sep] which is in aberdeen? [sep] what are all the airport names?
# what are all the flights departing from 'apg'? [sep] what are all the flights departing from 'apg'?
# how many are there? [sep] how many are there? [sep] what are all the flights departing from 'apg'?
# what flights land in ato? [sep] what flights land in ato?
# how many are there? [sep] how many are there? [sep] what flights land in ato?
# what are all the flights derparting from aberdeen? [sep] what are all the flights derparting from aberdeen?
# how many are there? [sep] how many are there? [sep] what are all the flights derparting from aberdeen?
# what are all the flights arriving in aberdeen. [sep] what are all the flights arriving in aberdeen.
# how many are there? [sep] how many are there? [sep] what are all the flights arriving in aberdeen.
# what are all the flights that leave from aberdeen? [sep] what are all the flights that leave from aberdeen?
# of those, which land in ashley? [sep] of those, which land in ashley? [sep] what are all the flights that leave from aberdeen?
# how many are there? [sep] how many are there? [sep] of those, which land in ashley? [sep] what are all the flights that leave from aberdeen?
# what are all the flights on jetblue airways? [sep] what are all the flights on jetblue airways?
# how many are there? [sep] how many are there? [sep] what are all the flights on jetblue airways?
# what are the united airlines flights? [sep] what are the united airlines flights?
# how many are there? [sep] how many are there? [sep] what are the united airlines flights?
# how many land in asy airport? [sep] how many land in asy airport? [sep] how many are there? [sep] what are the united airlines flights?
# what are the united airlines flights? [sep] what are the united airlines flights?
# which ones leave from ahd? [sep] which ones leave from ahd? [sep] what are the united airlines flights?
# how many are there? [sep] how many are there? [sep] which ones leave from ahd? [sep] what are the united airlines flights?
# which united airlines flights fly into aberdeen? [sep] which united airlines flights fly into aberdeen?
# how many are there? [sep] how many are there? [sep] which united airlines flights fly into aberdeen?
# name all cities that have destination airports. [sep] name all cities that have destination airports.
# order them by number of arriving flights. [sep] order them by number of arriving flights. [sep] name all cities that have destination airports.
# which one has the most? [sep] which one has the most? [sep] order them by number of arriving flights. [sep] name all cities that have destination airports.
# name all cities that have source airports. [sep] name all cities that have source airports.
# order them by number of departing flights. [sep] order them by number of departing flights. [sep] name all cities that have source airports.
# which one has the most? [sep] which one has the most? [sep] order them by number of departing flights. [sep] name all cities that have source airports.
# what are airport codes of any airport with a arriving flight? [sep] what are airport codes of any airport with a arriving flight?
# also include codes of airports with departure flights. [sep] also include codes of airports with departure flights. [sep] what are airport codes of any airport with a arriving flight?
# which one has the highest number of flights? [sep] which one has the highest number of flights? [sep] also include codes of airports with departure flights. [sep] what are airport codes of any airport with a arriving flight?
# what are airport codes of any airport with a arriving flight? [sep] what are airport codes of any airport with a arriving flight?
# also include codes of airports with departure flights. [sep] also include codes of airports with departure flights. [sep] what are airport codes of any airport with a arriving flight?
# which one has the least number of flights? [sep] which one has the least number of flights? [sep] also include codes of airports with departure flights. [sep] what are airport codes of any airport with a arriving flight?
# count the number of flights by airline. [sep] count the number of flights by airline.
# which airline has the most? [sep] which airline has the most? [sep] count the number of flights by airline.
# what are all the airline abbreviations and what countries are they in? [sep] what are all the airline abbreviations and what countries are they in?
# order them by the number of flights that they have. [sep] order them by the number of flights that they have. [sep] what are all the airline abbreviations and what countries are they in?
# which one has the fewest? [sep] which one has the fewest? [sep] order them by the number of flights that they have. [sep] what are all the airline abbreviations and what countries are they in?
# which flights leave from ahd? [sep] which flights leave from ahd?
# what are their airlines? [sep] what are their airlines? [sep] which flights leave from ahd?
# which flights arrive in ahd? [sep] which flights arrive in ahd?
# what are their airlines? [sep] what are their airlines? [sep] which flights arrive in ahd?
# which airlines have flights departing from apg? [sep] which airlines have flights departing from apg?
# of those, which also have flights from cvo? [sep] of those, which also have flights from cvo? [sep] which airlines have flights departing from apg?
# which airlines have flights from cvo? [sep] which airlines have flights from cvo?
# of these, which do not have flights from apg? [sep] of these, which do not have flights from apg? [sep] which airlines have flights from cvo?
# what are all the airlines? [sep] what are all the airlines?
# which ones have more than 10 flights? [sep] which ones have more than 10 flights? [sep] what are all the airlines?
# what are all the airlines? [sep] what are all the airlines?
# which ones have less than 200 flights? [sep] which ones have less than 200 flights? [sep] what are all the airlines?
# what are all the flight numbers? [sep] what are all the flight numbers?
# which belong to united airlines? [sep] which belong to united airlines? [sep] what are all the flight numbers?
# what are all the flight numbers? [sep] what are all the flight numbers?
# of these, which correspond to flights leaving from apg? [sep] of these, which correspond to flights leaving from apg? [sep] what are all the flight numbers?
# what are all the flight numbers? [sep] what are all the flight numbers?
# also, which numbers are for flights that land in apg? [sep] also, which numbers are for flights that land in apg? [sep] what are all the flight numbers?
# what are all the flight numbers? [sep] what are all the flight numbers?
# of these, which are departure flights? [sep] of these, which are departure flights? [sep] what are all the flight numbers?
# which leave from aberdeen? [sep] which leave from aberdeen? [sep] of these, which are departure flights? [sep] what are all the flight numbers?
# what are all the flight numbers? [sep] what are all the flight numbers?
# of these, which are arrival flights? [sep] of these, which are arrival flights? [sep] what are all the flight numbers?
# which land in aberdeen? [sep] which land in aberdeen? [sep] of these, which are arrival flights? [sep] what are all the flight numbers?
# what flights land in aberdeen? [sep] what flights land in aberdeen?
# also include flights that land in abilene. [sep] also include flights that land in abilene. [sep] what flights land in aberdeen?
# how many are there? [sep] how many are there? [sep] also include flights that land in abilene. [sep] what flights land in aberdeen?
# what are the source airports? [sep] what are the source airports?
# also include the destination airports. [sep] also include the destination airports. [sep] what are the source airports?
# which airports are not included? [sep] which airports are not included? [sep] also include the destination airports. [sep] what are the source airports?
# what information is there on pets? [sep] what information is there on pets?
# which pets weigh more than 10? [sep] which pets weigh more than 10? [sep] what information is there on pets?
# how many are there? [sep] how many are there? [sep] which pets weigh more than 10? [sep] what information is there on pets?
# order the pets by age [sep] order the pets by age
# how much does each one weigh? [sep] how much does each one weigh? [sep] order the pets by age
# what about the first one? [sep] what about the first one? [sep] how much does each one weigh? [sep] order the pets by age
# what are the different types of pets? [sep] what are the different types of pets?
# for each of those types, what is the maximum weight? [sep] for each of those types, what is the maximum weight? [sep] what are the different types of pets?
# which pets are owned by students older than 20? [sep] which pets are owned by students older than 20?
# how many are there? [sep] how many are there? [sep] which pets are owned by students older than 20?
# who are the female students? [sep] who are the female students?
# of those, who has a pet? [sep] of those, who has a pet? [sep] who are the female students?
# how many of those have dogs? [sep] how many of those have dogs? [sep] of those, who has a pet? [sep] who are the female students?
# what are the different pet types? [sep] what are the different pet types?
# how many exist? [sep] how many exist? [sep] what are the different pet types?
# what is the first name of every student? [sep] what is the first name of every student?
# of those names, which ones correspond to somebody who has a cat? [sep] of those names, which ones correspond to somebody who has a cat? [sep] what is the first name of every student?
# also, combine those names with those who have a dog. [sep] also, combine those names with those who have a dog. [sep] of those names, which ones correspond to somebody who has a cat? [sep] what is the first name of every student?
# which students have a dog as their type of pet? [sep] which students have a dog as their type of pet?
# who also has a cat? [sep] who also has a cat? [sep] which students have a dog as their type of pet?
# what are their first names? [sep] what are their first names? [sep] who also has a cat? [sep] which students have a dog as their type of pet?
# which students have a cat as their pets? [sep] which students have a cat as their pets?
# what are they majoring in? [sep] what are they majoring in? [sep] which students have a cat as their pets?
# also, how old are they? [sep] also, how old are they? [sep] what are they majoring in? [sep] which students have a cat as their pets?
# what is every student's id? [sep] what is every student's id?
# of those ids, which correspond to those who own cats as pets? [sep] of those ids, which correspond to those who own cats as pets? [sep] what is every student's id?
# list all the other ids. [sep] list all the other ids. [sep] of those ids, which correspond to those who own cats as pets? [sep] what is every student's id?
# which students have dogs? [sep] which students have dogs?
# of those, who does not own a cat? [sep] of those, who does not own a cat? [sep] which students have dogs?
# what are their first names and ages? [sep] what are their first names and ages? [sep] of those, who does not own a cat? [sep] which students have dogs?
# who is the youngest pet? [sep] who is the youngest pet?
# what type are they? [sep] what type are they? [sep] who is the youngest pet?
# also, how much do they weigh? [sep] also, how much do they weigh? [sep] what type are they? [sep] who is the youngest pet?
# what are ids of every pet? [sep] what are ids of every pet?
# for those, which refer to pets older than 1? [sep] for those, which refer to pets older than 1? [sep] what are ids of every pet?
# also, how much do they weigh? [sep] also, how much do they weigh? [sep] for those, which refer to pets older than 1? [sep] what are ids of every pet?
# what are the different pet types? [sep] what are the different pet types?
# for each of those, what is the maximum age? [sep] for each of those, what is the maximum age? [sep] what are the different pet types?
# what about the average age? [sep] what about the average age? [sep] for each of those, what is the maximum age? [sep] what are the different pet types?
# what information is there on pets? [sep] what information is there on pets?
# for each pet type, what is the average weight? [sep] for each pet type, what is the average weight? [sep] what information is there on pets?
# which students have pets? [sep] which students have pets?
# what are the different first names? [sep] what are the different first names? [sep] which students have pets?
# also, what are their ages? [sep] also, what are their ages? [sep] what are the different first names? [sep] which students have pets?
# which students have pets? [sep] which students have pets?
# of those, whose last name is smith? [sep] of those, whose last name is smith? [sep] which students have pets?
# what is their pet's id? [sep] what is their pet's id? [sep] of those, whose last name is smith? [sep] which students have pets?
# which of the students have pets? [sep] which of the students have pets?
# how many pets does each of them have? [sep] how many pets does each of them have? [sep] which of the students have pets?
# what is the first name and sex of each student? [sep] what is the first name and sex of each student?
# which of those belong to somebody who has more than one pet? [sep] which of those belong to somebody who has more than one pet? [sep] what is the first name and sex of each student?
# what is the id of the three-year old cat? [sep] what is the id of the three-year old cat?
# who is the owner of that cat? [sep] who is the owner of that cat? [sep] what is the id of the three-year old cat?
# what is their last name? [sep] what is their last name? [sep] who is the owner of that cat? [sep] what is the id of the three-year old cat?
# which students do not own any pets? [sep] which students do not own any pets?
# what is their average age? [sep] what is their average age? [sep] which students do not own any pets?
# what are the names of all the countries? [sep] what are the names of all the countries?
# give the names of the ones that became independent after 1950. [sep] give the names of the ones that became independent after 1950. [sep] what are the names of all the countries?
# how many countries are there? [sep] how many countries are there?
# out of those, how many have a republic as their form of government? [sep] out of those, how many have a republic as their form of government? [sep] how many countries are there?
# what are the countries in the carribean region? [sep] what are the countries in the carribean region?
# what is the surface area of each of those countries? [sep] what is the surface area of each of those countries? [sep] what are the countries in the carribean region?
# find the total surface area of the above. [sep] find the total surface area of the above. [sep] what is the surface area of each of those countries? [sep] what are the countries in the carribean region?
# what continent does each country belong to? [sep] what continent does each country belong to?
# which one does anguila belong to? [sep] which one does anguila belong to? [sep] what continent does each country belong to?
# what are the names of all the regions? [sep] what are the names of all the regions?
# which of those is the city kabul located in? [sep] which of those is the city kabul located in? [sep] what are the names of all the regions?
# what are all the languages? [sep] what are all the languages?
# what are the languages spoken in aruba? [sep] what are the languages spoken in aruba? [sep] what are all the languages?
# which one is the most popular? [sep] which one is the most popular? [sep] what are the languages spoken in aruba? [sep] what are all the languages?
# what are the population and life expectancies for all countries? [sep] what are the population and life expectancies for all countries?
# of those, which ones are for the country brazil? [sep] of those, which ones are for the country brazil? [sep] what are the population and life expectancies for all countries?
# which region is angola in? [sep] which region is angola in?
# for that country, what is its population? [sep] for that country, what is its population? [sep] which region is angola in?
# what are the life expectancies for all the countries? [sep] what are the life expectancies for all the countries?
# what are the life expectancies for the countries in the region of central africa? [sep] what are the life expectancies for the countries in the region of central africa? [sep] what are the life expectancies for all the countries?
# what is the average of those? [sep] what is the average of those? [sep] what are the life expectancies for the countries in the region of central africa? [sep] what are the life expectancies for all the countries?
# what are the names of the countries in asia? [sep] what are the names of the countries in asia?
# which one has the shortest life expectancy? [sep] which one has the shortest life expectancy? [sep] what are the names of the countries in asia?
# how many people live in asia? [sep] how many people live in asia?
# what about the largest gnp among them? [sep] what about the largest gnp among them? [sep] how many people live in asia?
# which countries are in africa? [sep] which countries are in africa?
# which countries are also republics? [sep] which countries are also republics? [sep] which countries are in africa?
# what is the average of their life expectancies? [sep] what is the average of their life expectancies? [sep] which countries are also republics? [sep] which countries are in africa?
# what are the countries in the continents of asia or europe? [sep] what are the countries in the continents of asia or europe?
# what is the surface area of each country? [sep] what is the surface area of each country? [sep] what are the countries in the continents of asia or europe?
# what is the total surface area summed up? [sep] what is the total surface area summed up? [sep] what is the surface area of each country? [sep] what are the countries in the continents of asia or europe?
# what are the populations of each city in the district of gelderland? [sep] what are the populations of each city in the district of gelderland?
# what is the total population in that district? [sep] what is the total population in that district? [sep] what are the populations of each city in the district of gelderland?
# what are all the nations? [sep] what are all the nations?
# which of those have a government that is a us territory? [sep] which of those have a government that is a us territory? [sep] what are all the nations?
# for those, what is the average gnp and total population? [sep] for those, what is the average gnp and total population? [sep] which of those have a government that is a us territory? [sep] what are all the nations?
# what are all the distinct languages used around the world? [sep] what are all the distinct languages used around the world?
# how many are there? [sep] how many are there? [sep] what are all the distinct languages used around the world?
# what are the distinct forms of government in the continent of africa? [sep] what are the distinct forms of government in the continent of africa?
# how many are there? [sep] how many are there? [sep] what are the distinct forms of government in the continent of africa?
# what is the information about the country aruba? [sep] what is the information about the country aruba?
# what are the languages used in aruba? [sep] what are the languages used in aruba? [sep] what is the information about the country aruba?
# how many are there? [sep] how many are there? [sep] what are the languages used in aruba? [sep] what is the information about the country aruba?
# what are the languages used in afghanistan? [sep] what are the languages used in afghanistan?
# of those, how many are the official languages? [sep] of those, how many are the official languages? [sep] what are the languages used in afghanistan?
# how many languages are spoken in each country? [sep] how many languages are spoken in each country?
# which country speaks the most? [sep] which country speaks the most? [sep] how many languages are spoken in each country?
# how many languages are spoken on each continent? [sep] how many languages are spoken on each continent?
# which one speaks the most languages? [sep] which one speaks the most languages? [sep] how many languages are spoken on each continent?
# what are the countries that speak english? [sep] what are the countries that speak english?
# which of those also speak dutch? [sep] which of those also speak dutch? [sep] what are the countries that speak english?
# how many of them are there? [sep] how many of them are there? [sep] which of those also speak dutch? [sep] what are the countries that speak english?
# what are the names of countries which speak english? [sep] what are the names of countries which speak english?
# of those countries, what are the names of the nations that speak french as well? [sep] of those countries, what are the names of the nations that speak french as well? [sep] what are the names of countries which speak english?
# what are the official languages of each country? [sep] what are the official languages of each country?
# of those countries, give the names of the ones that have english as one of the official languages. [sep] of those countries, give the names of the ones that have english as one of the official languages. [sep] what are the official languages of each country?
# of those, which also have french as another official language? [sep] of those, which also have french as another official language? [sep] of those countries, give the names of the ones that have english as one of the official languages. [sep] what are the official languages of each country?
# in which countries is chinese spoken? [sep] in which countries is chinese spoken?
# which distinct continents are they in? [sep] which distinct continents are they in? [sep] in which countries is chinese spoken?
# how many of them are there? [sep] how many of them are there? [sep] which distinct continents are they in? [sep] in which countries is chinese spoken?
# what are all the different regions? [sep] what are all the different regions?
# which of those speak dutch or english? [sep] which of those speak dutch or english? [sep] what are all the different regions?
# what are the official languages for each country? [sep] what are the official languages for each country?
# which of these countries have english or dutch? [sep] which of these countries have english or dutch? [sep] what are the official languages for each country?
# what are all the different languages used in the continent of asia? [sep] what are all the different languages used in the continent of asia?
# which one is used by the largest number of asian countries? [sep] which one is used by the largest number of asian countries? [sep] what are all the different languages used in the continent of asia?
# which countries have republics as their form of government? [sep] which countries have republics as their form of government?
# which language is spoken by only one of those countries? [sep] which language is spoken by only one of those countries? [sep] which countries have republics as their form of government?
# what are the names of all the cities that use english? [sep] what are the names of all the cities that use english?
# which of those has the largest population? [sep] which of those has the largest population? [sep] what are the names of all the cities that use english?
# what are the names, population, and life expectancy for all the countries in asia? [sep] what are the names, population, and life expectancy for all the countries in asia?
# of those, which belong to the country with the largest surface area? [sep] of those, which belong to the country with the largest surface area? [sep] what are the names, population, and life expectancy for all the countries in asia?
# what are the official languages of each country? [sep] what are the official languages of each country?
# which countries do not have english as the official language? [sep] which countries do not have english as the official language? [sep] what are the official languages of each country?
# in those countries, what is the average life expectancy? [sep] in those countries, what is the average life expectancy? [sep] which countries do not have english as the official language? [sep] what are the official languages of each country?
# what are the names of each country that does not speak english? [sep] what are the names of each country that does not speak english?
# how many people live in those countries? [sep] how many people live in those countries? [sep] what are the names of each country that does not speak english?
# which country has a head of state named beatrix? [sep] which country has a head of state named beatrix?
# what languages are spoken in that country? [sep] what languages are spoken in that country? [sep] which country has a head of state named beatrix?
# which of those languages is the official one? [sep] which of those languages is the official one? [sep] what languages are spoken in that country? [sep] which country has a head of state named beatrix?
# what are the names of all the countries? [sep] what are the names of all the countries?
# what are the names of those countries that were founded after 1930? [sep] what are the names of those countries that were founded after 1930? [sep] what are the names of all the countries?
# for those countries, how many unique official languages are spoken in total? [sep] for those countries, how many unique official languages are spoken in total? [sep] what are the names of those countries that were founded after 1930? [sep] what are the names of all the countries?
# what are all the information about european countries? [sep] what are all the information about european countries?
# of those countries, what is the minimum surface area? [sep] of those countries, what is the minimum surface area? [sep] what are all the information about european countries?
# what are the countries that have a greater surface area than that? [sep] what are the countries that have a greater surface area than that? [sep] of those countries, what is the minimum surface area? [sep] what are all the information about european countries?
# what is the maximum population of a country in asia? [sep] what is the maximum population of a country in asia?
# which countries in africa have a population smaller than that? [sep] which countries in africa have a population smaller than that? [sep] what is the maximum population of a country in asia?
# what is the smallest population of a country in africa? [sep] what is the smallest population of a country in africa?
# which asian countries have a greater population than that? [sep] which asian countries have a greater population than that? [sep] what is the smallest population of a country in africa?
# what are the country codes of all the countries? [sep] what are the country codes of all the countries?
# of those countries, give the country codes for those which do not speak english. [sep] of those countries, give the country codes for those which do not speak english. [sep] what are the country codes of all the countries?
# what are the country codes of all the countries? [sep] what are the country codes of all the countries?
# of those, which do not speak english? [sep] of those, which do not speak english? [sep] what are the country codes of all the countries?
# what are the country codes for countries which are not republics? [sep] what are the country codes for countries which are not republics?
# of those, which do not speak english? [sep] of those, which do not speak english? [sep] what are the country codes for countries which are not republics?
# what are the names of the countries where english is the official language? [sep] what are the names of the countries where english is the official language?
# what are the names of the countries in europe that are not one of those? [sep] what are the names of the countries in europe that are not one of those? [sep] what are the names of the countries where english is the official language?
# what are the names of the cities in those countries? [sep] what are the names of the cities in those countries? [sep] what are the names of the countries in europe that are not one of those? [sep] what are the names of the countries where english is the official language?
# what are the countries in asia where chinese is spoken? [sep] what are the countries in asia where chinese is spoken?
# of those, which have chinese as the official language? [sep] of those, which have chinese as the official language? [sep] what are the countries in asia where chinese is spoken?
# what are the different cities in those countries? [sep] what are the different cities in those countries? [sep] of those, which have chinese as the official language? [sep] what are the countries in asia where chinese is spoken?
# which country has the smallest population? [sep] which country has the smallest population?
# what is its name, independence year, and surface area? [sep] what is its name, independence year, and surface area? [sep] which country has the smallest population?
# what is the country with the largest surface area? [sep] what is the country with the largest surface area?
# what is its population, name and leader? [sep] what is its population, name and leader? [sep] what is the country with the largest surface area?
# what are the names of the countries? [sep] what are the names of the countries?
# which of them speak at least three languages? [sep] which of them speak at least three languages? [sep] what are the names of the countries?
# also, how many languages are spoken in each of those countries? [sep] also, how many languages are spoken in each of those countries? [sep] which of them speak at least three languages? [sep] what are the names of the countries?
# what is the average city population for each city? [sep] what is the average city population for each city?
# for each district, count how many cities have a population greater than the average. [sep] for each district, count how many cities have a population greater than the average. [sep] what is the average city population for each city?
# the countries with which government form have an average life expectancy greater than age 72? [sep] the countries with which government form have an average life expectancy greater than age 72?
# for those, list the total population and government form name. [sep] for those, list the total population and government form name. [sep] the countries with which government form have an average life expectancy greater than age 72?
# which continents have an average life expectancy less than age 72? [sep] which continents have an average life expectancy less than age 72?
# give their average life expectancy and total population. [sep] give their average life expectancy and total population. [sep] which continents have an average life expectancy less than age 72?
# what are the countries with the top 5 largest surface areas? [sep] what are the countries with the top 5 largest surface areas?
# what are the surface areas and names of those countries? [sep] what are the surface areas and names of those countries? [sep] what are the countries with the top 5 largest surface areas?
# order the countries by descending population size. [sep] order the countries by descending population size.
# give the names of the 3 countries which have the most. [sep] give the names of the 3 countries which have the most. [sep] order the countries by descending population size.
# order the countries by increasing population. [sep] order the countries by increasing population.
# give the names of the 3 countries with the lowest. [sep] give the names of the 3 countries with the lowest. [sep] order the countries by increasing population.
# what are the countries in the continent of asia? [sep] what are the countries in the continent of asia?
# how many are there? [sep] how many are there? [sep] what are the countries in the continent of asia?
# which countries are in the continent of europe? [sep] which countries are in the continent of europe?
# of those, what are the names of those that have a population of 80000? [sep] of those, what are the names of those that have a population of 80000? [sep] which countries are in the continent of europe?
# what countries are in north america? [sep] what countries are in north america?
# of those, which have surface area greater than 3000? [sep] of those, which have surface area greater than 3000? [sep] what countries are in north america?
# what is the total population and average surface area of those countries? [sep] what is the total population and average surface area of those countries? [sep] of those, which have surface area greater than 3000? [sep] what countries are in north america?
# what are the names of all the cities? [sep] what are the names of all the cities?
# which of those have a population between 160000 and 900000? [sep] which of those have a population between 160000 and 900000? [sep] what are the names of all the cities?
# what are the different languages? [sep] what are the different languages?
# which one is spoken in the most countries? [sep] which one is spoken in the most countries? [sep] what are the different languages?
# tell me﻿ the director of the cartoon named "day of the dark knight!". [sep] tell me﻿ the director of the cartoon named "day of the dark knight!".
# what is the channel of this cartoon? [sep] what is the channel of this cartoon? [sep] tell me﻿ the director of the cartoon named "day of the dark knight!".
# give me the titles of all cartoon directed by "ben jones" or "brandon vietti"? [sep] give me the titles of all cartoon directed by "ben jones" or "brandon vietti"? [sep] what is the channel of this cartoon? [sep] tell me﻿ the director of the cartoon named "day of the dark knight!".
# show me all the information about the italian tv channels. [sep] show me all the information about the italian tv channels.
# how about the polish tv channels? [sep] how about the polish tv channels? [sep] show me all the information about the italian tv channels.
# which country has the most of tv channels? list the country and number of tv channels it has. [sep] which country has the most of tv channels? list the country and number of tv channels it has. [sep] how about the polish tv channels? [sep] show me all the information about the italian tv channels.
# tell me the tv channel of the cartoon titled "the eyes of despero!". [sep] tell me the tv channel of the cartoon titled "the eyes of despero!".
# how about this channel's series name? [sep] how about this channel's series name? [sep] tell me the tv channel of the cartoon titled "the eyes of despero!".
# tell me the number of different series names and contents in the tv channel table. [sep] tell me the number of different series names and contents in the tv channel table. [sep] how about this channel's series name? [sep] tell me the tv channel of the cartoon titled "the eyes of despero!".
# tell me the package option for the series named "rock tv". [sep] tell me the package option for the series named "rock tv".
# tell me the language of this series. [sep] tell me the language of this series. [sep] tell me the package option for the series named "rock tv".
# list the language used least number of tv channel. list language and number of tv channel. [sep] list the language used least number of tv channel. list language and number of tv channel. [sep] tell me the language of this series. [sep] tell me the package option for the series named "rock tv".
# tell me the author of the cartoon "the rise of the blue beetle!" [sep] tell me the author of the cartoon "the rise of the blue beetle!"
# how about its director? [sep] how about its director? [sep] tell me the author of the cartoon "the rise of the blue beetle!"
# what is its tv channel? [sep] what is its tv channel? [sep] how about its director? [sep] tell me the author of the cartoon "the rise of the blue beetle!"
# tell me the country of the tv channel for the series named "sky radio". [sep] tell me the country of the tv channel for the series named "sky radio".
# how about its content? [sep] how about its content? [sep] tell me the country of the tv channel for the series named "sky radio".
# i want to know the title of all cartoons showed on tv channel with series name "sky radio". [sep] i want to know the title of all cartoons showed on tv channel with series name "sky radio". [sep] how about its content? [sep] tell me the country of the tv channel for the series named "sky radio".
# tell me the rating of the episode named "double down". [sep] tell me the rating of the episode named "double down".
# how about the rating of the episode named "keepers". [sep] how about the rating of the episode named "keepers". [sep] tell me the rating of the episode named "double down".
# okay, i want to know the top 3 highest rating tv series. list the tv series's episode and rating. [sep] okay, i want to know the top 3 highest rating tv series. list the tv series's episode and rating. [sep] how about the rating of the episode named "keepers". [sep] tell me the rating of the episode named "double down".
# tell me the weekly rank of the episode named "emily". [sep] tell me the weekly rank of the episode named "emily".
# how about its share? [sep] how about its share? [sep] tell me the weekly rank of the episode named "emily".
# tell me the minimum and maximum share of tv series. [sep] tell me the minimum and maximum share of tv series. [sep] how about its share? [sep] tell me the weekly rank of the episode named "emily".
# tell me the rating of the episode titled "a love of a lifetime". [sep] tell me the rating of the episode titled "a love of a lifetime".
# how about its weekly rank? [sep] how about its weekly rank? [sep] tell me the rating of the episode titled "a love of a lifetime".
# and what is its tv channel? [sep] and what is its tv channel? [sep] how about its weekly rank? [sep] tell me the rating of the episode titled "a love of a lifetime".
# tell me the content of tv channel with the series named "sky radio". [sep] tell me the content of tv channel with the series named "sky radio".
# how about its language? [sep] how about its language? [sep] tell me the content of tv channel with the series named "sky radio".
# okay, now i want to know the episode of all tv series showed on tv channel with series name "sky radio". [sep] okay, now i want to know the episode of all tv series showed on tv channel with series name "sky radio". [sep] how about its language? [sep] tell me the content of tv channel with the series named "sky radio".
# tell me the air date of the cartoon titled "fall of the blue beetle!". [sep] tell me the air date of the cartoon titled "fall of the blue beetle!".
# what is its production code? [sep] what is its production code? [sep] tell me the air date of the cartoon titled "fall of the blue beetle!".
# tell me the production code and channel of the most recently aired cartoon. [sep] tell me the production code and channel of the most recently aired cartoon. [sep] what is its production code? [sep] tell me the air date of the cartoon titled "fall of the blue beetle!".
# tell me the cartoons directed by ben jone. [sep] tell me the cartoons directed by ben jone.
# tell me the cartoons written by todd casey. [sep] tell me the cartoons written by todd casey. [sep] tell me the cartoons directed by ben jone.
# which countries' tv channels are playing some cartoon written by todd casey? [sep] which countries' tv channels are playing some cartoon written by todd casey? [sep] tell me the cartoons written by todd casey. [sep] tell me the cartoons directed by ben jone.
# which countries' tv channels are playing some cartoon written by steven melching? [sep] which countries' tv channels are playing some cartoon written by steven melching?
# which countries' tv channels are not playing any cartoon written by todd casey? [sep] which countries' tv channels are not playing any cartoon written by todd casey? [sep] which countries' tv channels are playing some cartoon written by steven melching?
# tell me the director of the cartoon titled "deep cover for batman!". [sep] tell me the director of the cartoon titled "deep cover for batman!".
# i want to know this cartoon's production code. [sep] i want to know this cartoon's production code. [sep] tell me the director of the cartoon titled "deep cover for batman!".
# tell me the series name and country of the tv channel that is playing some cartoons directed by ben jones and michael chang. [sep] tell me the series name and country of the tv channel that is playing some cartoons directed by ben jones and michael chang. [sep] i want to know this cartoon's production code. [sep] tell me the director of the cartoon titled "deep cover for batman!".
# tell me the country of the tv channel with series named "mtv music" [sep] tell me the country of the tv channel with series named "mtv music"
# tell me the number of italian channels. [sep] tell me the number of italian channels. [sep] tell me the country of the tv channel with series named "mtv music"
# find id of the tv channels that from the countries where have more than two tv channels. [sep] find id of the tv channels that from the countries where have more than two tv channels. [sep] tell me the number of italian channels. [sep] tell me the country of the tv channel with series named "mtv music"
# who is the director of the cartoon titled "return of the fearsome fangs!"? [sep] who is the director of the cartoon titled "return of the fearsome fangs!"?
# tell me the cartoons directed by ben jones. [sep] tell me the cartoons directed by ben jones. [sep] who is the director of the cartoon titled "return of the fearsome fangs!"?
# find the id of tv channels that do not play any cartoon directed by ben jones. [sep] find the id of tv channels that do not play any cartoon directed by ben jones. [sep] tell me the cartoons directed by ben jones. [sep] who is the director of the cartoon titled "return of the fearsome fangs!"?
# show all the poker players. [sep] show all the poker players.
# how many are there? [sep] how many are there? [sep] show all the poker players.
# what is the earnings of each poker player? [sep] what is the earnings of each poker player?
# sort them in descending order. [sep] sort them in descending order. [sep] what is the earnings of each poker player?
# show all the information about each poker player. [sep] show all the information about each poker player.
# what are their final table mades? [sep] what are their final table mades? [sep] show all the information about each poker player.
# what are their final table mades and best finishes? [sep] what are their final table mades and best finishes? [sep] what are their final table mades? [sep] show all the information about each poker player.
# what is the earnings of each poker player? [sep] what is the earnings of each poker player?
# give me the average. [sep] give me the average. [sep] what is the earnings of each poker player?
# what is the money rank of each poker player? [sep] what is the money rank of each poker player?
# sort them in the decreasing order. [sep] sort them in the decreasing order. [sep] what is the money rank of each poker player?
# return the top one. [sep] return the top one. [sep] sort them in the decreasing order. [sep] what is the money rank of each poker player?
# which poker player has earnings less than 200000? [sep] which poker player has earnings less than 200000?
# among them, what is the maximum number of final tables made? [sep] among them, what is the maximum number of final tables made? [sep] which poker player has earnings less than 200000?
# show all the poker players. [sep] show all the poker players.
# what are their names? [sep] what are their names? [sep] show all the poker players.
# which poker players have earnings higher than 300000? [sep] which poker players have earnings higher than 300000?
# what are their names? [sep] what are their names? [sep] which poker players have earnings higher than 300000?
# what are the names of all poker players? [sep] what are the names of all poker players?
# sort them in the ascending order of the final tables made. [sep] sort them in the ascending order of the final tables made. [sep] what are the names of all poker players?
# what is the birth date of each poker player? [sep] what is the birth date of each poker player?
# sort the list by the poker player's earnings. [sep] sort the list by the poker player's earnings. [sep] what is the birth date of each poker player?
# give me the result for the player with the lowest earnings. [sep] give me the result for the player with the lowest earnings. [sep] sort the list by the poker player's earnings. [sep] what is the birth date of each poker player?
# what is the height of each poker player? [sep] what is the height of each poker player?
# who has the largest height? [sep] who has the largest height? [sep] what is the height of each poker player?
# what is his or her money rank? [sep] what is his or her money rank? [sep] who has the largest height? [sep] what is the height of each poker player?
# what is the height of each poker player? [sep] what is the height of each poker player?
# who all have heights greater than 200? [sep] who all have heights greater than 200? [sep] what is the height of each poker player?
# ...
# show all the dog ages. [sep] show all the dog ages.
# what is the maximum and minimum value? [sep] what is the maximum and minimum value? [sep] show all the dog ages.
# which of the dogs have gone through treatments? [sep] which of the dogs have gone through treatments? [sep] what is the maximum and minimum value? [sep] show all the dog ages.
# what about the average age of them? [sep] what about the average age of them? [sep] which of the dogs have gone through treatments? [sep] what is the maximum and minimum value? [sep] show all the dog ages.
# list all the professionals who are employees. [sep] list all the professionals who are employees.
# how many of them live in connecticut? [sep] how many of them live in connecticut? [sep] list all the professionals who are employees.
# what about in indiana? [sep] what about in indiana? [sep] how many of them live in connecticut? [sep] list all the professionals who are employees.
# among all the professionals, which have done treatment only 1 treatments? [sep] among all the professionals, which have done treatment only 1 treatments? [sep] what about in indiana? [sep] how many of them live in connecticut? [sep] list all the professionals who are employees.
# list the id, last name and cell phone of the professionals who live in the state of indiana or have done treatment on more than 2 treatments? [sep] list the id, last name and cell phone of the professionals who live in the state of indiana or have done treatment on more than 2 treatments? [sep] among all the professionals, which have done treatment only 1 treatments? [sep] what about in indiana? [sep] how many of them live in connecticut? [sep] list all the professionals who are employees.
# show the dog name and total cost of each dog. [sep] show the dog name and total cost of each dog.
# which of them cost over 500? [sep] which of them cost over 500? [sep] show the dog name and total cost of each dog.
# what about more than 1000? [sep] what about more than 1000? [sep] which of them cost over 500? [sep] show the dog name and total cost of each dog.
# list all the names of both professionals and owners. [sep] list all the names of both professionals and owners.
# what about the dog names? [sep] what about the dog names? [sep] list all the names of both professionals and owners.
# which human names are not used as dog names. [sep] which human names are not used as dog names. [sep] what about the dog names? [sep] list all the names of both professionals and owners.
# show the professional first names and the corresponding treatment type codes for the treatment. [sep] show the professional first names and the corresponding treatment type codes for the treatment.
# what about each professional's id, role, email and the treatment type code? [sep] what about each professional's id, role, email and the treatment type code? [sep] show the professional first names and the corresponding treatment type codes for the treatment.
# which professional did not provide any treatment? keep the id, role and email. [sep] which professional did not provide any treatment? keep the id, role and email. [sep] what about each professional's id, role, email and the treatment type code? [sep] show the professional first names and the corresponding treatment type codes for the treatment.
# show the number of dogs for each owner, keep the owner id. [sep] show the number of dogs for each owner, keep the owner id.
# which one has 2 dogs? [sep] which one has 2 dogs? [sep] show the number of dogs for each owner, keep the owner id.
# what about the one with the most dogs? [sep] what about the one with the most dogs? [sep] which one has 2 dogs? [sep] show the number of dogs for each owner, keep the owner id.
# how many treatment does each professional finished? [sep] how many treatment does each professional finished?
# show the first name of the professionals who did only 1 treatment. [sep] show the first name of the professionals who did only 1 treatment. [sep] how many treatment does each professional finished?
# what about at least two treatments? [sep] what about at least two treatments? [sep] show the first name of the professionals who did only 1 treatment. [sep] how many treatment does each professional finished?
# show the id, role, and first name of each from the above. [sep] show the id, role, and first name of each from the above. [sep] what about at least two treatments? [sep] show the first name of the professionals who did only 1 treatment. [sep] how many treatment does each professional finished?
# how many dogs for each breed code? [sep] how many dogs for each breed code?
# which breed codes are the most popular two? [sep] which breed codes are the most popular two? [sep] how many dogs for each breed code?
# what about the most common 1? [sep] what about the most common 1? [sep] which breed codes are the most popular two? [sep] how many dogs for each breed code?
# what name is the breed? [sep] what name is the breed? [sep] what about the most common 1? [sep] which breed codes are the most popular two? [sep] how many dogs for each breed code?
# show the dog name and total cost of each dog. [sep] show the dog name and total cost of each dog.
# what are the owner names and the cost from their dogs. [sep] what are the owner names and the cost from their dogs. [sep] show the dog name and total cost of each dog.
# who has paid for the most treatments on the dogs? keep owner ids and last names. [sep] who has paid for the most treatments on the dogs? keep owner ids and last names. [sep] what are the owner names and the cost from their dogs. [sep] show the dog name and total cost of each dog.
# list the treatment type code and the description. [sep] list the treatment type code and the description.
# for each treatment type, calculate the sum of costs, and order them in descending order. [sep] for each treatment type, calculate the sum of costs, and order them in descending order. [sep] list the treatment type code and the description.
# show the treatment type description also. [sep] show the treatment type description also. [sep] for each treatment type, calculate the sum of costs, and order them in descending order. [sep] list the treatment type code and the description.
# so what is the description of the treatment type that costs the least money in total? [sep] so what is the description of the treatment type that costs the least money in total? [sep] show the treatment type description also. [sep] for each treatment type, calculate the sum of costs, and order them in descending order. [sep] list the treatment type code and the description.
# show the dog name and total cost of each dog. [sep] show the dog name and total cost of each dog.
# how many of them cost over 700? [sep] how many of them cost over 700? [sep] show the dog name and total cost of each dog.
# which owner paid the cost larger than 400, show the owner id and the zip code? [sep] which owner paid the cost larger than 400, show the owner id and the zip code? [sep] how many of them cost over 700? [sep] show the dog name and total cost of each dog.
# what about the owner who spent the largest cost? [sep] what about the owner who spent the largest cost? [sep] which owner paid the cost larger than 400, show the owner id and the zip code? [sep] how many of them cost over 700? [sep] show the dog name and total cost of each dog.
# list the professional first names and their types of treatments. [sep] list the professional first names and their types of treatments.
# add the counts of them also. [sep] add the counts of them also. [sep] list the professional first names and their types of treatments.
# among the results, who did only 1 type of treatment? list the professional ids and cell phone numbers of them. [sep] among the results, who did only 1 type of treatment? list the professional ids and cell phone numbers of them. [sep] add the counts of them also. [sep] list the professional first names and their types of treatments.
# what about at least two types of treatments? [sep] what about at least two types of treatments? [sep] among the results, who did only 1 type of treatment? list the professional ids and cell phone numbers of them. [sep] add the counts of them also. [sep] list the professional first names and their types of treatments.
# what is the minimum, maximum and average value of the treatment costs? [sep] what is the minimum, maximum and average value of the treatment costs?
# which professionals who did the minimum value of the treatment cost? provide the first name and last name. [sep] which professionals who did the minimum value of the treatment cost? provide the first name and last name. [sep] what is the minimum, maximum and average value of the treatment costs?
# what about the maximum cost? [sep] what about the maximum cost? [sep] which professionals who did the minimum value of the treatment cost? provide the first name and last name. [sep] what is the minimum, maximum and average value of the treatment costs?
# how about below the average of the cost? [sep] how about below the average of the cost? [sep] what about the maximum cost? [sep] which professionals who did the minimum value of the treatment cost? provide the first name and last name. [sep] what is the minimum, maximum and average value of the treatment costs?
# how many dogs for each breed code? [sep] how many dogs for each breed code?
# which one is the most popular one? [sep] which one is the most popular one? [sep] how many dogs for each breed code?
# what about the least popular one? [sep] what about the least popular one? [sep] which one is the most popular one? [sep] how many dogs for each breed code?
# so which dogs are having the breed code? and the treatment dates? [sep] so which dogs are having the breed code? and the treatment dates? [sep] what about the least popular one? [sep] which one is the most popular one? [sep] how many dogs for each breed code?
# show the name of dogs whose owners are from the city 'lake tia'. [sep] show the name of dogs whose owners are from the city 'lake tia'.
# add the owner's first names also. [sep] add the owner's first names also. [sep] show the name of dogs whose owners are from the city 'lake tia'.
# what about when the owner is from the state of 'virginia'? [sep] what about when the owner is from the state of 'virginia'? [sep] add the owner's first names also. [sep] show the name of dogs whose owners are from the city 'lake tia'.
# which one is the oldest dog? list the information of it. [sep] which one is the oldest dog? list the information of it.
# what are the last names of the oldest dogs? [sep] what are the last names of the oldest dogs? [sep] which one is the oldest dog? list the information of it.
# what about the owner last name of the youngest dog? [sep] what about the owner last name of the youngest dog? [sep] what are the last names of the oldest dogs? [sep] which one is the oldest dog? list the information of it.
# show the cities and states of the professionals. [sep] show the cities and states of the professionals.
# how many of them are from 'hawaii'? [sep] how many of them are from 'hawaii'? [sep] show the cities and states of the professionals.
# list the emails of the professionals who live in the state of hawaii or the state of wisconsin. [sep] list the emails of the professionals who live in the state of hawaii or the state of wisconsin. [sep] how many of them are from 'hawaii'? [sep] show the cities and states of the professionals.
# show the states of the professionals. [sep] show the states of the professionals.
# how many of them are from 'wisconsin'? [sep] how many of them are from 'wisconsin'? [sep] show the states of the professionals.
# list the role code ,  street ,  city ,  state from the above results. [sep] list the role code ,  street ,  city ,  state from the above results. [sep] how many of them are from 'wisconsin'? [sep] show the states of the professionals.
# what about those professionals who live in a city containing the substring 'west'? [sep] what about those professionals who live in a city containing the substring 'west'? [sep] list the role code ,  street ,  city ,  state from the above results. [sep] how many of them are from 'wisconsin'? [sep] show the states of the professionals.
# show the states of the owners. [sep] show the states of the owners.
# how many of them are from 'vermont'? [sep] how many of them are from 'vermont'? [sep] show the states of the owners.
# list the first name, last name and email of the owners who lives in the states that has the substring 'north'. [sep] list the first name, last name and email of the owners who lives in the states that has the substring 'north'. [sep] how many of them are from 'vermont'? [sep] show the states of the owners.
# order the dog ages in descending order. [sep] order the dog ages in descending order.
# how many of them are below 4? [sep] how many of them are below 4? [sep] order the dog ages in descending order.
# what about the ones that are below the average? [sep] what about the ones that are below the average? [sep] how many of them are below 4? [sep] order the dog ages in descending order.
# show the treatment details. [sep] show the treatment details.
# order the cost in ascending order. [sep] order the cost in ascending order. [sep] show the treatment details.
# what about in descending order? [sep] what about in descending order? [sep] order the cost in ascending order. [sep] show the treatment details.
# which one is the most recent cost? [sep] which one is the most recent cost? [sep] what about in descending order? [sep] order the cost in ascending order. [sep] show the treatment details.
# show all the owner information. [sep] show all the owner information.
# what about the dogs? [sep] what about the dogs? [sep] show all the owner information.
# among those, how many of them have been sent to receive treatment? [sep] among those, how many of them have been sent to receive treatment? [sep] what about the dogs? [sep] show all the owner information.
# what about those who did not? [sep] what about those who did not? [sep] among those, how many of them have been sent to receive treatment? [sep] what about the dogs? [sep] show all the owner information.
# show all the owner information. [sep] show all the owner information.
# how many of them come from the state of 'arizona'? [sep] how many of them come from the state of 'arizona'? [sep] show all the owner information.
# what about those who do not have any dogs temporarily? [sep] what about those who do not have any dogs temporarily? [sep] how many of them come from the state of 'arizona'? [sep] show all the owner information.
# how many professionals are there? [sep] how many professionals are there?
# how many of them come from 'west heidi?' [sep] how many of them come from 'west heidi?' [sep] how many professionals are there?
# what about those who did not operate any treatment on dogs? [sep] what about those who did not operate any treatment on dogs? [sep] how many of them come from 'west heidi?' [sep] how many professionals are there?
# Independent: 385, 571, 0.674256
# Dependent: 338, 632, 0.534810
# First Independent: 303, 422, 0.718009
# Other Independent: 82, 149, 0.550336
# Independent Percent: 0.474647
# {'easy': 330, 'extra': 31, 'hard': 40, 'medium': 170}
# {'easy': 262, 'extra': 7, 'hard': 15, 'medium': 101}
# {'easy': 153, 'extra': 103, 'hard': 105, 'medium': 271}
# {'easy': 0.5779334500875657,
#  'extra': 0.0542907180385289,
#  'hard': 0.07005253940455342,
#  'medium': 0.29772329246935203}
# {'easy': 0.24208860759493672,
#  'extra': 0.1629746835443038,
#  'hard': 0.1661392405063291,
#  'medium': 0.4287974683544304}
# Total Hardness:  {'easy': 483, 'medium': 441, 'hard': 145, 'extra': 134}
# Total Hardness Distribution:  {'easy': 0.4014962593516209, 'medium': 0.36658354114713215, 'hard': 0.12053200332502079, 'extra': 0.1113881961762261}
# Total Hardness Match:  {'easy': 375, 'medium': 263, 'hard': 50, 'extra': 35}
# Total Hardness Accuracy:  {'easy': 0.7763975155279503, 'medium': 0.5963718820861678, 'hard': 0.3448275862068966, 'extra': 0.26119402985074625}

# %%
(263 + 50 + 35) / (441 + 145 + 134)
# Out:
# 0.48333333333333334

# %%
483 + 441 + 145 + 134
# Out:
# 1203

# %% [markdown]
# ### IGSQL

# %%
igsql_sparc_predictions = read_predictions(igsql_sparc_path)
# Out:
# 422 1203
# 422
# 1203

# %%
igsql_sparc_predictions[0]
# Out:
# {'example_id': 1,
#  'interaction': [{'interaction_id': 1,
#    'turn_id': 1,
#    'question': 'What are all the airlines ?',
#    'ground_truth': 'SELECT * FROM AIRLINES',
#    'sql': 'select Airline from airlines',
#    'exact': 0},
#   {'interaction_id': 1,
#    'turn_id': 2,
#    'question': 'Of these , which is Jetblue Airways ?',
#    'ground_truth': 'SELECT * FROM AIRLINES WHERE Airline  =  "JetBlue Airways"',
#    'sql': 'select Airline from airlines where Airline = 1',
#    'exact': 0},
#   {'interaction_id': 1,
#    'turn_id': 3,
#    'question': 'What is the country corresponding it ?',
#    'ground_truth': 'SELECT Country FROM AIRLINES WHERE Airline  =  "JetBlue Airways"',
#    'sql': 'select Country from airlines where Airline = 1',
#    'exact': True}]}

# %%
measure_accuracy(igsql_sparc_predictions)
# Out:
# Question Match: 0.495428
# Interaction Match: 0.300948

# %%
measure_context_independent_accuracy(igsql_sparc_predictions, sparc_dev, sparc_annotation_df)
# Out:
# what are all the airlines? what are all the airlines ?
# of these, which is jetblue airways? of these , which is jetblue airways ?
# what is the country corresponding it? what is the country corresponding it ?
# what are all the abbreviations? what are all the abbreviations ?
# what is the abbreviation for jetblue airways? what is the abbreviation for jetblue airways ?
# list all airline names and their abbreviations. list all airline names and their abbreviations .
# of these, list only those in the usa. of these , list only those in the usa .
# find all information about the airport in the city anthony. find all information about the airport in the city anthony .
# what is the airport code and airport name? what is the airport code and airport name ?
# what are all the airlines? what are all the airlines ?
# how many are there? how many are there ?
# what are all the airports? what are all the airports ?
# how many are there? how many are there ?
# what are all the flights? what are all the flights ?
# how many are there? how many are there ?
# what are all the airline names? what are all the airline names ?
# of this, which has the abbreviation 'ual'? of this , which has the abbreviation 'ual ' ?
# what are the names of the airlines in the usa? what are the names of the airlines in the usa ?
# how many are there? how many are there ?
# what are the city and country for all airports? what are the city and country for all airports ?
# of these, what are the city and country for alton airport? of these , what are the city and country for alton airport ?
# what are all the airport names? what are all the airport names ?
# of these, which has code 'ako'? of these , which has code 'ako ' ?
# what are all the airport names? what are all the airport names ?
# which is in aberdeen? which is in aberdeen ?
# what are all the flights departing from 'apg'? what are all the flights departing from 'apg ' ?
# how many are there? how many are there ?
# what flights land in ato? what flights land in ato ?
# how many are there? how many are there ?
# what are all the flights derparting from aberdeen? what are all the flights derparting from aberdeen ?
# how many are there? how many are there ?
# what are all the flights arriving in aberdeen. what are all the flights arriving in aberdeen .
# how many are there? how many are there ?
# what are all the flights that leave from aberdeen? what are all the flights that leave from aberdeen ?
# of those, which land in ashley? of those , which land in ashley ?
# how many are there? how many are there ?
# what are all the flights on jetblue airways? what are all the flights on jetblue airways ?
# how many are there? how many are there ?
# what are the united airlines flights? what are the united airlines flights ?
# how many are there? how many are there ?
# how many land in asy airport? how many land in asy airport ?
# what are the united airlines flights? what are the united airlines flights ?
# which ones leave from ahd? which ones leave from ahd ?
# how many are there? how many are there ?
# which united airlines flights fly into aberdeen? which united airlines flights fly into aberdeen ?
# how many are there? how many are there ?
# name all cities that have destination airports. name all cities that have destination airports .
# order them by number of arriving flights. order them by number of arriving flights .
# which one has the most? which one has the most ?
# name all cities that have source airports. name all cities that have source airports .
# order them by number of departing flights. order them by number of departing flights .
# which one has the most? which one has the most ?
# what are airport codes of any airport with a arriving flight? what are airport codes of any airport with a arriving flight ?
# also include codes of airports with departure flights. also include codes of airports with departure flights .
# which one has the highest number of flights? which one has the highest number of flights ?
# what are airport codes of any airport with a arriving flight? what are airport codes of any airport with a arriving flight ?
# also include codes of airports with departure flights. also include codes of airports with departure flights .
# which one has the least number of flights? which one has the least number of flights ?
# count the number of flights by airline. count the number of flights by airline .
# which airline has the most? which airline has the most ?
# what are all the airline abbreviations and what countries are they in? what are all the airline abbreviations and what countries are they in ?
# order them by the number of flights that they have. order them by the number of flights that they have .
# which one has the fewest? which one has the fewest ?
# which flights leave from ahd? which flights leave from ahd ?
# what are their airlines? what are their airlines ?
# which flights arrive in ahd? which flights arrive in ahd ?
# what are their airlines? what are their airlines ?
# which airlines have flights departing from apg? which airlines have flights departing from apg ?
# of those, which also have flights from cvo? of those , which also have flights from cvo ?
# which airlines have flights from cvo? which airlines have flights from cvo ?
# of these, which do not have flights from apg? of these , which do not have flights from apg ?
# what are all the airlines? what are all the airlines ?
# which ones have more than 10 flights? which ones have more than 10 flights ?
# what are all the airlines? what are all the airlines ?
# which ones have less than 200 flights? which ones have less than 200 flights ?
# what are all the flight numbers? what are all the flight numbers ?
# which belong to united airlines? which belong to united airlines ?
# what are all the flight numbers? what are all the flight numbers ?
# of these, which correspond to flights leaving from apg? of these , which correspond to flights leaving from apg ?
# what are all the flight numbers? what are all the flight numbers ?
# also, which numbers are for flights that land in apg? also , which numbers are for flights that land in apg ?
# what are all the flight numbers? what are all the flight numbers ?
# of these, which are departure flights? of these , which are departure flights ?
# which leave from aberdeen? which leave from aberdeen ?
# what are all the flight numbers? what are all the flight numbers ?
# of these, which are arrival flights? of these , which are arrival flights ?
# which land in aberdeen? which land in aberdeen ?
# what flights land in aberdeen? what flights land in aberdeen ?
# also include flights that land in abilene. also include flights that land in abilene .
# how many are there? how many are there ?
# what are the source airports? what are the source airports ?
# also include the destination airports. also include the destination airports .
# which airports are not included? which airports are not included ?
# what information is there on pets? what information is there on pets ?
# which pets weigh more than 10? which pets weigh more than 10 ?
# how many are there? how many are there ?
# order the pets by age order the pets by age
# how much does each one weigh? how much does each one weigh ?
# what about the first one? what about the first one ?
# what are the different types of pets? what are the different types of pets ?
# for each of those types, what is the maximum weight? for each of those types , what is the maximum weight ?
# which pets are owned by students older than 20? which pets are owned by students older than 20 ?
# how many are there? how many are there ?
# who are the female students? who are the female students ?
# of those, who has a pet? of those , who has a pet ?
# how many of those have dogs? how many of those have dogs ?
# what are the different pet types? what are the different pet types ?
# how many exist? how many exist ?
# what is the first name of every student? what is the first name of every student ?
# of those names, which ones correspond to somebody who has a cat? of those names , which ones correspond to somebody who has a cat ?
# also, combine those names with those who have a dog. also , combine those names with those who have a dog .
# which students have a dog as their type of pet? which students have a dog as their type of pet ?
# who also has a cat? who also has a cat ?
# what are their first names? what are their first names ?
# which students have a cat as their pets? which students have a cat as their pets ?
# what are they majoring in? what are they majoring in ?
# also, how old are they? also , how old are they ?
# what is every student's id? what is every student 's id ?
# of those ids, which correspond to those who own cats as pets? of those ids , which correspond to those who own cats as pets ?
# list all the other ids. list all the other ids .
# which students have dogs? which students have dogs ?
# of those, who does not own a cat? of those , who does not own a cat ?
# what are their first names and ages? what are their first names and ages ?
# who is the youngest pet? who is the youngest pet ?
# what type are they? what type are they ?
# also, how much do they weigh? also , how much do they weigh ?
# what are ids of every pet? what are ids of every pet ?
# for those, which refer to pets older than 1? for those , which refer to pets older than 1 ?
# also, how much do they weigh? also , how much do they weigh ?
# what are the different pet types? what are the different pet types ?
# for each of those, what is the maximum age? for each of those , what is the maximum age ?
# what about the average age? what about the average age ?
# what information is there on pets? what information is there on pets ?
# for each pet type, what is the average weight? for each pet type , what is the average weight ?
# which students have pets? which students have pets ?
# what are the different first names? what are the different first names ?
# also, what are their ages? also , what are their ages ?
# which students have pets? which students have pets ?
# of those, whose last name is smith? of those , whose last name is smith ?
# what is their pet's id? what is their pet 's id ?
# which of the students have pets? which of the students have pets ?
# how many pets does each of them have? how many pets does each of them have ?
# what is the first name and sex of each student? what is the first name and sex of each student ?
# which of those belong to somebody who has more than one pet? which of those belong to somebody who has more than one pet ?
# what is the id of the three-year old cat? what is the id of the three-year old cat ?
# who is the owner of that cat? who is the owner of that cat ?
# what is their last name? what is their last name ?
# which students do not own any pets? which students do not own any pets ?
# what is their average age? what is their average age ?
# what are the names of all the countries? what are the names of all the countries ?
# give the names of the ones that became independent after 1950. give the names of the ones that became independent after 1950 .
# how many countries are there? how many countries are there ?
# out of those, how many have a republic as their form of government? out of those , how many have a republic as their form of government ?
# what are the countries in the carribean region? what are the countries in the carribean region ?
# what is the surface area of each of those countries? what is the surface area of each of those countries ?
# find the total surface area of the above. find the total surface area of the above .
# what continent does each country belong to? what continent does each country belong to ?
# which one does anguila belong to? which one does anguila belong to ?
# what are the names of all the regions? what are the names of all the regions ?
# which of those is the city kabul located in? which of those is the city kabul located in ?
# what are all the languages? what are all the languages ?
# what are the languages spoken in aruba? what are the languages spoken in aruba ?
# which one is the most popular? which one is the most popular ?
# what are the population and life expectancies for all countries? what are the population and life expectancies for all countries ?
# of those, which ones are for the country brazil? of those , which ones are for the country brazil ?
# which region is angola in? which region is angola in ?
# for that country, what is its population? for that country , what is its population ?
# what are the life expectancies for all the countries? what are the life expectancies for all the countries ?
# what are the life expectancies for the countries in the region of central africa? what are the life expectancies for the countries in the region of central africa ?
# what is the average of those? what is the average of those ?
# what are the names of the countries in asia? what are the names of the countries in asia ?
# which one has the shortest life expectancy? which one has the shortest life expectancy ?
# how many people live in asia? how many people live in asia ?
# what about the largest gnp among them? what about the largest gnp among them ?
# which countries are in africa? which countries are in africa ?
# which countries are also republics? which countries are also republics ?
# what is the average of their life expectancies? what is the average of their life expectancies ?
# what are the countries in the continents of asia or europe? what are the countries in the continents of asia or europe ?
# what is the surface area of each country? what is the surface area of each country ?
# what is the total surface area summed up? what is the total surface area summed up ?
# what are the populations of each city in the district of gelderland? what are the populations of each city in the district of gelderland ?
# what is the total population in that district? what is the total population in that district ?
# what are all the nations? what are all the nations ?
# which of those have a government that is a us territory? which of those have a government that is a us territory ?
# for those, what is the average gnp and total population? for those , what is the average gnp and total population ?
# what are all the distinct languages used around the world? what are all the distinct languages used around the world ?
# how many are there? how many are there ?
# what are the distinct forms of government in the continent of africa? what are the distinct forms of government in the continent of africa ?
# how many are there? how many are there ?
# what is the information about the country aruba? what is the information about the country aruba ?
# what are the languages used in aruba? what are the languages used in aruba ?
# how many are there? how many are there ?
# what are the languages used in afghanistan? what are the languages used in afghanistan ?
# of those, how many are the official languages? of those , how many are the official languages ?
# how many languages are spoken in each country? how many languages are spoken in each country ?
# which country speaks the most? which country speaks the most ?
# how many languages are spoken on each continent? how many languages are spoken on each continent ?
# which one speaks the most languages? which one speaks the most languages ?
# what are the countries that speak english? what are the countries that speak english ?
# which of those also speak dutch? which of those also speak dutch ?
# how many of them are there? how many of them are there ?
# what are the names of countries which speak english? what are the names of countries which speak english ?
# of those countries, what are the names of the nations that speak french as well? of those countries , what are the names of the nations that speak french as well ?
# what are the official languages of each country? what are the official languages of each country ?
# of those countries, give the names of the ones that have english as one of the official languages. of those countries , give the names of the ones that have english as one of the official languages .
# of those, which also have french as another official language? of those , which also have french as another official language ?
# in which countries is chinese spoken? in which countries is chinese spoken ?
# which distinct continents are they in? which distinct continents are they in ?
# how many of them are there? how many of them are there ?
# what are all the different regions? what are all the different regions ?
# which of those speak dutch or english? which of those speak dutch or english ?
# what are the official languages for each country? what are the official languages for each country ?
# which of these countries have english or dutch? which of these countries have english or dutch ?
# what are all the different languages used in the continent of asia? what are all the different languages used in the continent of asia ?
# which one is used by the largest number of asian countries? which one is used by the largest number of asian countries ?
# which countries have republics as their form of government? which countries have republics as their form of government ?
# which language is spoken by only one of those countries? which language is spoken by only one of those countries ?
# what are the names of all the cities that use english? what are the names of all the cities that use english ?
# which of those has the largest population? which of those has the largest population ?
# what are the names, population, and life expectancy for all the countries in asia? what are the names , population , and life expectancy for all the countries in asia ?
# of those, which belong to the country with the largest surface area? of those , which belong to the country with the largest surface area ?
# what are the official languages of each country? what are the official languages of each country ?
# which countries do not have english as the official language? which countries do not have english as the official language ?
# in those countries, what is the average life expectancy? in those countries , what is the average life expectancy ?
# what are the names of each country that does not speak english? what are the names of each country that does not speak english ?
# how many people live in those countries? how many people live in those countries ?
# which country has a head of state named beatrix? which country has a head of state named beatrix ?
# what languages are spoken in that country? what languages are spoken in that country ?
# which of those languages is the official one? which of those languages is the official one ?
# what are the names of all the countries? what are the names of all the countries ?
# what are the names of those countries that were founded after 1930? what are the names of those countries that were founded after 1930 ?
# for those countries, how many unique official languages are spoken in total? for those countries , how many unique official languages are spoken in total ?
# what are all the information about european countries? what are all the information about european countries ?
# of those countries, what is the minimum surface area? of those countries , what is the minimum surface area ?
# what are the countries that have a greater surface area than that? what are the countries that have a greater surface area than that ?
# what is the maximum population of a country in asia? what is the maximum population of a country in asia ?
# which countries in africa have a population smaller than that? which countries in africa have a population smaller than that ?
# what is the smallest population of a country in africa? what is the smallest population of a country in africa ?
# which asian countries have a greater population than that? which asian countries have a greater population than that ?
# what are the country codes of all the countries? what are the country codes of all the countries ?
# of those countries, give the country codes for those which do not speak english. of those countries , give the country codes for those which do not speak english .
# what are the country codes of all the countries? what are the country codes of all the countries ?
# of those, which do not speak english? of those , which do not speak english ?
# what are the country codes for countries which are not republics? what are the country codes for countries which are not republics ?
# of those, which do not speak english? of those , which do not speak english ?
# what are the names of the countries where english is the official language? what are the names of the countries where english is the official language ?
# what are the names of the countries in europe that are not one of those? what are the names of the countries in europe that are not one of those ?
# what are the names of the cities in those countries? what are the names of the cities in those countries ?
# what are the countries in asia where chinese is spoken? what are the countries in asia where chinese is spoken ?
# of those, which have chinese as the official language? of those , which have chinese as the official language ?
# what are the different cities in those countries? what are the different cities in those countries ?
# which country has the smallest population? which country has the smallest population ?
# what is its name, independence year, and surface area? what is its name , independence year , and surface area ?
# what is the country with the largest surface area? what is the country with the largest surface area ?
# what is its population, name and leader? what is its population , name and leader ?
# what are the names of the countries? what are the names of the countries ?
# which of them speak at least three languages? which of them speak at least three languages ?
# also, how many languages are spoken in each of those countries? also , how many languages are spoken in each of those countries ?
# what is the average city population for each city? what is the average city population for each city ?
# for each district, count how many cities have a population greater than the average. for each district , count how many cities have a population greater than the average .
# the countries with which government form have an average life expectancy greater than age 72? the countries with which government form have an average life expectancy greater than age 72 ?
# for those, list the total population and government form name. for those , list the total population and government form name .
# which continents have an average life expectancy less than age 72? which continents have an average life expectancy less than age 72 ?
# give their average life expectancy and total population. give their average life expectancy and total population .
# what are the countries with the top 5 largest surface areas? what are the countries with the top 5 largest surface areas ?
# what are the surface areas and names of those countries? what are the surface areas and names of those countries ?
# order the countries by descending population size. order the countries by descending population size .
# give the names of the 3 countries which have the most. give the names of the 3 countries which have the most .
# order the countries by increasing population. order the countries by increasing population .
# give the names of the 3 countries with the lowest. give the names of the 3 countries with the lowest .
# what are the countries in the continent of asia? what are the countries in the continent of asia ?
# how many are there? how many are there ?
# which countries are in the continent of europe? which countries are in the continent of europe ?
# of those, what are the names of those that have a population of 80000? of those , what are the names of those that have a population of 80000 ?
# what countries are in north america? what countries are in north america ?
# of those, which have surface area greater than 3000? of those , which have surface area greater than 3000 ?
# what is the total population and average surface area of those countries? what is the total population and average surface area of those countries ?
# what are the names of all the cities? what are the names of all the cities ?
# which of those have a population between 160000 and 900000? which of those have a population between 160000 and 900000 ?
# what are the different languages? what are the different languages ?
# which one is spoken in the most countries? which one is spoken in the most countries ?
# tell me﻿ the director of the cartoon named "day of the dark knight!". tell me﻿ the director of the cartoon named `` day of the dark knight ! `` .
# what is the channel of this cartoon? what is the channel of this cartoon ?
# give me the titles of all cartoon directed by "ben jones" or "brandon vietti"? give me the titles of all cartoon directed by `` ben jones '' or `` brandon vietti '' ?
# show me all the information about the italian tv channels. show me all the information about the italian tv channels .
# how about the polish tv channels? how about the polish tv channels ?
# which country has the most of tv channels? list the country and number of tv channels it has. which country has the most of tv channels ? list the country and number of tv channels it has .
# tell me the tv channel of the cartoon titled "the eyes of despero!". tell me the tv channel of the cartoon titled `` the eyes of despero ! `` .
# how about this channel's series name? how about this channel 's series name ?
# tell me the number of different series names and contents in the tv channel table. tell me the number of different series names and contents in the tv channel table .
# tell me the package option for the series named "rock tv". tell me the package option for the series named `` rock tv '' .
# tell me the language of this series. tell me the language of this series .
# list the language used least number of tv channel. list language and number of tv channel. list the language used least number of tv channel . list language and number of tv channel .
# tell me the author of the cartoon "the rise of the blue beetle!" tell me the author of the cartoon `` the rise of the blue beetle ! ''
# how about its director? how about its director ?
# what is its tv channel? what is its tv channel ?
# tell me the country of the tv channel for the series named "sky radio". tell me the country of the tv channel for the series named `` sky radio '' .
# how about its content? how about its content ?
# i want to know the title of all cartoons showed on tv channel with series name "sky radio". i want to know the title of all cartoons showed on tv channel with series name `` sky radio '' .
# tell me the rating of the episode named "double down". tell me the rating of the episode named `` double down '' .
# how about the rating of the episode named "keepers". how about the rating of the episode named `` keepers '' .
# okay, i want to know the top 3 highest rating tv series. list the tv series's episode and rating. okay , i want to know the top 3 highest rating tv series . list the tv series 's episode and rating .
# tell me the weekly rank of the episode named "emily". tell me the weekly rank of the episode named `` emily '' .
# how about its share? how about its share ?
# tell me the minimum and maximum share of tv series. tell me the minimum and maximum share of tv series .
# tell me the rating of the episode titled "a love of a lifetime". tell me the rating of the episode titled `` a love of a lifetime '' .
# how about its weekly rank? how about its weekly rank ?
# and what is its tv channel? and what is its tv channel ?
# tell me the content of tv channel with the series named "sky radio". tell me the content of tv channel with the series named `` sky radio '' .
# how about its language? how about its language ?
# okay, now i want to know the episode of all tv series showed on tv channel with series name "sky radio". okay , now i want to know the episode of all tv series showed on tv channel with series name `` sky radio '' .
# tell me the air date of the cartoon titled "fall of the blue beetle!". tell me the air date of the cartoon titled `` fall of the blue beetle ! `` .
# what is its production code? what is its production code ?
# tell me the production code and channel of the most recently aired cartoon. tell me the production code and channel of the most recently aired cartoon .
# tell me the cartoons directed by ben jone. tell me the cartoons directed by ben jone .
# tell me the cartoons written by todd casey. tell me the cartoons written by todd casey .
# which countries' tv channels are playing some cartoon written by todd casey? which countries ' tv channels are playing some cartoon written by todd casey ?
# which countries' tv channels are playing some cartoon written by steven melching? which countries ' tv channels are playing some cartoon written by steven melching ?
# which countries' tv channels are not playing any cartoon written by todd casey? which countries ' tv channels are not playing any cartoon written by todd casey ?
# tell me the director of the cartoon titled "deep cover for batman!". tell me the director of the cartoon titled `` deep cover for batman ! `` .
# i want to know this cartoon's production code. i want to know this cartoon 's production code .
# tell me the series name and country of the tv channel that is playing some cartoons directed by ben jones and michael chang. tell me the series name and country of the tv channel that is playing some cartoons directed by ben jones and michael chang .
# tell me the country of the tv channel with series named "mtv music" tell me the country of the tv channel with series named `` mtv music ''
# tell me the number of italian channels. tell me the number of italian channels .
# find id of the tv channels that from the countries where have more than two tv channels. find id of the tv channels that from the countries where have more than two tv channels .
# who is the director of the cartoon titled "return of the fearsome fangs!"? who is the director of the cartoon titled `` return of the fearsome fangs ! `` ?
# tell me the cartoons directed by ben jones. tell me the cartoons directed by ben jones .
# find the id of tv channels that do not play any cartoon directed by ben jones. find the id of tv channels that do not play any cartoon directed by ben jones .
# show all the poker players. show all the poker players .
# how many are there? how many are there ?
# what is the earnings of each poker player? what is the earnings of each poker player ?
# sort them in descending order. sort them in descending order .
# show all the information about each poker player. show all the information about each poker player .
# what are their final table mades? what are their final table mades ?
# what are their final table mades and best finishes? what are their final table mades and best finishes ?
# what is the earnings of each poker player? what is the earnings of each poker player ?
# give me the average. give me the average .
# what is the money rank of each poker player? what is the money rank of each poker player ?
# sort them in the decreasing order. sort them in the decreasing order .
# return the top one. return the top one .
# which poker player has earnings less than 200000? which poker player has earnings less than 200000 ?
# among them, what is the maximum number of final tables made? among them , what is the maximum number of final tables made ?
# show all the poker players. show all the poker players .
# what are their names? what are their names ?
# which poker players have earnings higher than 300000? which poker players have earnings higher than 300000 ?
# what are their names? what are their names ?
# what are the names of all poker players? what are the names of all poker players ?
# sort them in the ascending order of the final tables made. sort them in the ascending order of the final tables made .
# what is the birth date of each poker player? what is the birth date of each poker player ?
# sort the list by the poker player's earnings. sort the list by the poker player 's earnings .
# give me the result for the player with the lowest earnings. give me the result for the player with the lowest earnings .
# what is the height of each poker player? what is the height of each poker player ?
# who has the largest height? who has the largest height ?
# what is his or her money rank? what is his or her money rank ?
# what is the height of each poker player? what is the height of each poker player ?
# who all have heights greater than 200? who all have heights greater than 200 ?
# what is the average earnings among them? what is the average earnings among them ?
# sort all the poker players in descending order of earnings. sort all the poker players in descending order of earnings .
# what are the names of poker players in descending order of earnings? what are the names of poker players in descending order of earnings ?
# show the nationality of each person. show the nationality of each person .
# group people by their nationality. group people by their nationality .
# for each of the result, show the corresponding number of people of that nationality? for each of the result , show the corresponding number of people of that nationality ?
# show the nationality of each person. show the nationality of each person .
# count the number of people for each nationality. count the number of people for each nationality .
# what is the most common nationality of people? what is the most common nationality of people ?
# count the number of people for each nationality. count the number of people for each nationality .
# which nationalities are held by at least two people? which nationalities are held by at least two people ?
# what are the names and birth dates of people? what are the names and birth dates of people ?
# sort the results in ascending alphabetical order of name. sort the results in ascending alphabetical order of name .
# what are the names of all people? what are the names of all people ?
# what about people whose nationality is not "russia"? what about people whose nationality is not `` russia '' ?
# show all the poker players. show all the poker players .
# show all people who are not poker players. show all people who are not poker players .
# give me their names. give me their names .
# what are the death tolls each time? what are the death tolls each time ?
# what is the maximum number of deaths in any one time? what is the maximum number of deaths in any one time ?
# what about the minimum? what about the minimum ?
# give me the maximum and also the minimum. give me the maximum and also the minimum .
# show me information about deaths caused by ships. show me information about deaths caused by ships .
# only ships with tonnage 't'. only ships with tonnage 't ' .
# only return the death and injury information for those ships. only return the death and injury information for those ships .
# what are the ids and names of the battles? what are the ids and names of the battles ?
# only show those that ships were lost in. only show those that ships were lost in .
# please, just the ones with 'brig' ship type. please , just the ones with 'brig ' ship type .
# how many people were killed or injured in each battle? how many people were killed or injured in each battle ?
# only show the deaths for those battles that produced at least ten deaths. only show the deaths for those battles that produced at least ten deaths .
# list the injuries caused by each ship (give ship id and name please). list the injuries caused by each ship ( give ship id and name please ) .
# sort it by decreasing number of injuries. sort it by decreasing number of injuries .
# only show the ship id and name that caused the most total injuries. only show the ship id and name that caused the most total injuries .
# which battles did the bulgarian commander 'kaloyan' fight in? which battles did the bulgarian commander 'kaloyan ' fight in ?
# how about the latin commander 'baldwin i'? how about the latin commander 'baldwin i ' ?
# just the ones where they were fighting one another, please. just the ones where they were fighting one another , please .
# which battle ids lost ships with tonnage '225'? which battle ids lost ships with tonnage '225 ' ?
# give the names of these battles, too. give the names of these battles , too .
# which battle ids and names did not lose any ship with tonnage '225'? which battle ids and names did not lose any ship with tonnage '225 ' ?
# how many is that? how many is that ?
# list the name and date of the battle that has lost the ship named 'lettice' list the name and date of the battle that has lost the ship named 'lettice '
# same for 'hms atlanta', please. same for 'hms atlanta ' , please .
# can you intersect those? can you intersect those ?
# which battle ids and names lost ships in the 'english channel'? which battle ids and names lost ships in the 'english channel ' ?
# which did not? which did not ?
# for these ones, show their names, results, and bulgarian commanders. for these ones , show their names , results , and bulgarian commanders .
# how many continents are there? how many continents are there ?
# show all their ids and names! show all their ids and names !
# what countries do they each have? what countries do they each have ?
# count how many there are for each continent name and id! count how many there are for each continent name and id !
# what are the names and ids of the different car makers? what are the names and ids of the different car makers ?
# what countries are they each from? what countries are they each from ?
# for each, how many models do they each produce? for each , how many models do they each produce ?
# can actually just show the name, id and the number of models? can actually just show the name , id and the number of models ?
# what is the average horsepower of all cars? what is the average horsepower of all cars ?
# how about the maximum? how about the maximum ?
# what about the minimum? what about the minimum ?
# what is the model of the car with this horsepower? what is the model of the car with this horsepower ?
# what is the average weight of all the cars? what is the average weight of all the cars ?
# list all the car information with weights above this? list all the car information with weights above this ?
# how about below this? how about below this ?
# please, show just their model names! please , show just their model names !
# what are the ids, and models of the cars were made in 1970? what are the ids , and models of the cars were made in 1970 ?
# show their horsepower and mpg as well? show their horsepower and mpg as well ?
# also provide the names of their makers! also provide the names of their makers !
# just show a unique list of all these different makers. just show a unique list of all these different makers .
# show me the makes and models of each car! show me the makes and models of each car !
# also provide which the year they were produced? also provide which the year they were produced ?
# which ones been produce in the earliest year? which ones been produce in the earliest year ?
# show just the make and year! show just the make and year !
# what are all the different car models? what are all the different car models ?
# show also all the car makes and the years that they were produced! show also all the car makes and the years that they were produced !
# show only those that were made after 1980! show only those that were made after 1980 !
# what are the distinct car models for these? what are the distinct car models for these ?
# what are the names and country name of each car maker? what are the names and country name of each car maker ?
# also provide the continent name for each! also provide the continent name for each !
# how many car makers are there per continent? how many car makers are there per continent ?
# how many countries are there? how many countries are there ?
# how many car makers belong to each one? how many car makers belong to each one ?
# what is the name of the country that has the least number? what is the name of the country that has the least number ?
# how about the most? how about the most ?
# how many makers are there? how many makers are there ?
# what are their full names and ids? what are their full names and ids ?
# what models have they each produced? what models have they each produced ?
# count how many modes there are per maker. count how many modes there are per maker .
# show all the car ids with the make amc hornet sporabout (sw)? show all the car ids with the make amc hornet sporabout ( sw ) ?
# what is its horsepower? what is its horsepower ?
# how about its mpg? how about its mpg ?
# how about its accelerate? how about its accelerate ?
# show all the different car makers? show all the different car makers ?
# what are the names of the countries they belong to? what are the names of the countries they belong to ?
# show just the car makers from france! show just the car makers from france !
# how many are there? how many are there ?
# how many car models are produced in total? how many car models are produced in total ?
# how many in germany? how many in germany ?
# how about in japan? how about in japan ?
# how about the usa? how about the usa ?
# what is all the car information for cars produced in 1974? what is all the car information for cars produced in 1974 ?
# now, show me just the weight and cylinders of these cars. now , show me just the weight and cylinders of these cars .
# list just those with 8 cylinders! list just those with 8 cylinders !
# what is the smallest weight? what is the smallest weight ?
# what are all the different country names? what are all the different country names ?
# which ones have no car makers? which ones have no car makers ?
# which ones have at least one? which ones have at least one ?
# also provide the country id! also provide the country id !
# show all the car makers and their country name? show all the car makers and their country name ?
# count how many there are per country name? count how many there are per country name ?
# show just those from countries in the continent europe. show just those from countries in the continent europe .
# list the country names of those with at least 3 manufacturers! list the country names of those with at least 3 manufacturers !
# what is the horsepower, make for each car! what is the horsepower , make for each car !
# show those with 8 cylinders! show those with 8 cylinders !
# how about 3? how about 3 ?
# show the one with the maximum horsepower. show the one with the maximum horsepower .
# what is id of the car with the max horsepower? what is id of the car with the max horsepower ?
# how about with the max mpg? how about with the max mpg ?
# show its make! show its make !
# now show its model! now show its model !
# what is the average edispl of all cars? what is the average edispl of all cars ?
# can you show the average per car make? can you show the average per car make ?
# how about per car model? how about per car model ?
# show the average for the model volvo! show the average for the model volvo !
# what are all the different models for each car? what are all the different models for each car ?
# what are the makes for each? what are the makes for each ?
# how many makes are there for each? how many makes are there for each ?
# what is the model name with the most makes? what is the model name with the most makes ?
# show the full names of all the different car makers? show the full names of all the different car makers ?
# also include the car models produced by each! also include the car models produced by each !
# show me just those produced by the maker with full name american motor company! show me just those produced by the maker with full name american motor company !
# how many are there? how many are there ?
# what is all the information for the makers that have designed at least 1 car model! what is all the information for the makers that have designed at least 1 car model !
# which ones have designed more than 1? which ones have designed more than 1 ?
# how about more than 3? how about more than 3 ?
# list just the full name and id! list just the full name and id !
# how many different models has maker with full name general motors produced? how many different models has maker with full name general motors produced ?
# how many different models weigh over 3500 pounds? how many different models weigh over 3500 pounds ?
# how many models have either of these features? how many models have either of these features ?
# show me the distinct list of their model names! show me the distinct list of their model names !
# show the years and weight of all the cars! show the years and weight of all the cars !
# show distinct years that the cars that weigh more than 3000 were produced! show distinct years that the cars that weigh more than 3000 were produced !
# how about the different years for those that weight less than 4000. how about the different years for those that weight less than 4000 .
# what are the distinct years, for the cars that are both? what are the distinct years , for the cars that are both ?
# what is the lowest accelerate for any car? what is the lowest accelerate for any car ?
# how about the highest? how about the highest ?
# what is the id, make and model of this car? what is the id , make and model of this car ?
# show just its horsepower. show just its horsepower .
# show all the car information for any car of the model volvo! show all the car information for any car of the model volvo !
# what is the car with the least accelerate? what is the car with the least accelerate ?
# what is its horsepower? what is its horsepower ?
# what about its number of cylinders? what about its number of cylinders ?
# what is largest horsepower of all cars? what is largest horsepower of all cars ?
# what is the accelerate of the car with this horsepower? what is the accelerate of the car with this horsepower ?
# what are the car ids of the cars with a greater accelerate than this? what are the car ids of the cars with a greater accelerate than this ?
# how many are there? how many are there ?
# what are the names of the countries that have no car makers? what are the names of the countries that have no car makers ?
# show me all the names of all the different countries outside of those! show me all the names of all the different countries outside of those !
# how many of these have more than 1 car maker? how many of these have more than 1 car maker ?
# how about more than 2? how about more than 2 ?
# show all models and horsepowers of all cars! show all models and horsepowers of all cars !
# now show just the ones with 4 cylinders. now show just the ones with 4 cylinders .
# what is the model of that with the lowest horsepower? what is the model of that with the lowest horsepower ?
# how about the greatest horsepower? how about the greatest horsepower ?
# what is the lowest horsepower of all cars? what is the lowest horsepower of all cars ?
# show all the ids and makes of those with a horsepower greater than this! show all the ids and makes of those with a horsepower greater than this !
# which ones have 5 cylinders or less? which ones have 5 cylinders or less ?
# how about 3 or less? how about 3 or less ?
# show me the mpg, horsepower and accelerate for all the cars that were produced before 1980! show me the mpg , horsepower and accelerate for all the cars that were produced before 1980 !
# also include the cars that have 8 cylinders! also include the cars that have 8 cylinders !
# what is the max horsepower for this group? what is the max horsepower for this group ?
# how about the max mpg? how about the max mpg ?
# show all the models that were built by the ford motor company. show all the models that were built by the ford motor company .
# what are all the models except those! what are all the models except those !
# also provide the weights for all different makes for each of these models. also provide the weights for all different makes for each of these models .
# list all the different models from these that have makes that are lighter than 3500! list all the different models from these that have makes that are lighter than 3500 !
# what are all the names of countries? what are all the names of countries ?
# which ones have at least one car maker? which ones have at least one car maker ?
# show me all of car names other than these! show me all of car names other than these !
# show all the car maker id, names, the models and makes they produce! show all the car maker id , names , the models and makes they produce !
# ...
# give me the description of the department that offers the most number of degrees. give me the description of the department that offers the most number of degrees .
# what's the name and id of that department? what 's the name and id of that department ?
# show me all the degrees offered by the engineering department. show me all the degrees offered by the engineering department .
# how many are there? how many are there ?
# show me courses that have exactly 2 sections. show me courses that have exactly 2 sections .
# show me names and ids for courses that have at most 2 sections. show me names and ids for courses that have at most 2 sections .
# which semester did the least number of students register? give me its name and id. which semester did the least number of students register ? give me its name and id .
# how about the semester that most number of students registered? how about the semester that most number of students registered ?
# show me all department names that contain the word "computer" show me all department names that contain the word `` computer ''
# show me their descriptions. show me their descriptions .
# how many people are enrolled in 2 degree programs in one semester? how many people are enrolled in 2 degree programs in one semester ?
# show me their first, middle, and last names. show me their first , middle , and last names .
# how many people are enrolled in the bachelor degree program? how many people are enrolled in the bachelor degree program ?
# what are their first, middle, and last names? what are their first , middle , and last names ?
# show me the descriptions of programs with 3 highest number of enrolled students. show me the descriptions of programs with 3 highest number of enrolled students .
# show me the name of program with the most enrolled students. show me the name of program with the most enrolled students .
# what is the description of the program that has the least number of enrolled students? what is the description of the program that has the least number of enrolled students ?
# how about the program that has the most number of enrolled students? how about the program that has the most number of enrolled students ?
# show me the id and summary. show me the id and summary .
# show me the id, first and last names of top 3 students who have enrolled for the most times in any program. show me the id , first and last names of top 3 students who have enrolled for the most times in any program .
# show me just the top 1. show me just the top 1 .
# give me the description of a semester with no enrolled students. give me the description of a semester with no enrolled students .
# what's the name of that semester? what 's the name of that semester ?
# what's the name of the course with the least number of enrollments? what 's the name of the course with the least number of enrollments ?
# how many enrollments does the course with most enrollments have? how many enrollments does the course with most enrollments have ?
# what's the name of that course? what 's the name of that course ?
# how many students currently live in north carolina? how many students currently live in north carolina ?
# how many of those students have not registered in any degree program? how many of those students have not registered in any degree program ?
# what are their last names? what are their last names ?
# show me date and id of transcripts with exactly 2 course results. show me date and id of transcripts with exactly 2 course results .
# how about transcripts with at least 2 course results? how about transcripts with at least 2 course results ?
# what is the address of the student with first name timothy and last name ward? what is the address of the student with first name timothy and last name ward ?
# what's his phone number? what 's his phone number ?
# who was the last student to register? show me the first, middle, and last names of that student. who was the last student to register ? show me the first , middle , and last names of that student .
# who was the first to register? who was the first to register ?
# who is the least recent graduate of the school? list the first, middle, and last names. who is the least recent graduate of the school ? list the first , middle , and last names .
# who is the earliest graduate of the school? who is the earliest graduate of the school ?
# give me the id of the address that holds the most number of students? give me the id of the address that holds the most number of students ?
# how many students live there? how many students live there ?
# give me all the lines as well as the id of that address. give me all the lines as well as the id of that address .
# give me details of the first transcript released. give me details of the first transcript released .
# tell me when it was released as well, along with its details. tell me when it was released as well , along with its details .
# what is the oldest transcript release date? what is the oldest transcript release date ?
# how about the latest? how about the latest ?
# how many times, at minimum, can a course enrollment result show in different transcript? show me the course enrollment id. how many times , at minimum , can a course enrollment result show in different transcript ? show me the course enrollment id .
# how many times at most? how many times at most ?
# show other details of the transcript with least number of results. show other details of the transcript with least number of results .
# show me the date and id of that transcript. show me the date and id of that transcript .
# find a semester when there was a master student enrolled. find a semester when there was a master student enrolled .
# how about a semester when there was a bachelor student enrolled? how about a semester when there was a bachelor student enrolled ?
# find a semester that both types of students were enrolled in. find a semester that both types of students were enrolled in .
# list all the information about the owners. list all the information about the owners .
# what about the professionals? what about the professionals ?
# now show the states of them. now show the states of them .
# which of them have both owners and professionals living there? which of them have both owners and professionals living there ?
# show all the dog ages. show all the dog ages .
# what is the maximum and minimum value? what is the maximum and minimum value ?
# which of the dogs have gone through treatments? which of the dogs have gone through treatments ?
# what about the average age of them? what about the average age of them ?
# list all the professionals who are employees. list all the professionals who are employees .
# how many of them live in connecticut? how many of them live in connecticut ?
# what about in indiana? what about in indiana ?
# among all the professionals, which have done treatment only 1 treatments? among all the professionals , which have done treatment only 1 treatments ?
# list the id, last name and cell phone of the professionals who live in the state of indiana or have done treatment on more than 2 treatments? list the id , last name and cell phone of the professionals who live in the state of indiana or have done treatment on more than 2 treatments ?
# show the dog name and total cost of each dog. show the dog name and total cost of each dog .
# which of them cost over 500? which of them cost over 500 ?
# what about more than 1000? what about more than 1000 ?
# list all the names of both professionals and owners. list all the names of both professionals and owners .
# what about the dog names? what about the dog names ?
# which human names are not used as dog names. which human names are not used as dog names .
# show the professional first names and the corresponding treatment type codes for the treatment. show the professional first names and the corresponding treatment type codes for the treatment .
# what about each professional's id, role, email and the treatment type code? what about each professional 's id , role , email and the treatment type code ?
# which professional did not provide any treatment? keep the id, role and email. which professional did not provide any treatment ? keep the id , role and email .
# show the number of dogs for each owner, keep the owner id. show the number of dogs for each owner , keep the owner id .
# which one has 2 dogs? which one has 2 dogs ?
# what about the one with the most dogs? what about the one with the most dogs ?
# how many treatment does each professional finished? how many treatment does each professional finished ?
# show the first name of the professionals who did only 1 treatment. show the first name of the professionals who did only 1 treatment .
# what about at least two treatments? what about at least two treatments ?
# show the id, role, and first name of each from the above. show the id , role , and first name of each from the above .
# how many dogs for each breed code? how many dogs for each breed code ?
# which breed codes are the most popular two? which breed codes are the most popular two ?
# what about the most common 1? what about the most common 1 ?
# what name is the breed? what name is the breed ?
# show the dog name and total cost of each dog. show the dog name and total cost of each dog .
# what are the owner names and the cost from their dogs. what are the owner names and the cost from their dogs .
# who has paid for the most treatments on the dogs? keep owner ids and last names. who has paid for the most treatments on the dogs ? keep owner ids and last names .
# list the treatment type code and the description. list the treatment type code and the description .
# for each treatment type, calculate the sum of costs, and order them in descending order. for each treatment type , calculate the sum of costs , and order them in descending order .
# show the treatment type description also. show the treatment type description also .
# so what is the description of the treatment type that costs the least money in total? so what is the description of the treatment type that costs the least money in total ?
# show the dog name and total cost of each dog. show the dog name and total cost of each dog .
# how many of them cost over 700? how many of them cost over 700 ?
# which owner paid the cost larger than 400, show the owner id and the zip code? which owner paid the cost larger than 400 , show the owner id and the zip code ?
# what about the owner who spent the largest cost? what about the owner who spent the largest cost ?
# list the professional first names and their types of treatments. list the professional first names and their types of treatments .
# add the counts of them also. add the counts of them also .
# among the results, who did only 1 type of treatment? list the professional ids and cell phone numbers of them. among the results , who did only 1 type of treatment ? list the professional ids and cell phone numbers of them .
# what about at least two types of treatments? what about at least two types of treatments ?
# what is the minimum, maximum and average value of the treatment costs? what is the minimum , maximum and average value of the treatment costs ?
# which professionals who did the minimum value of the treatment cost? provide the first name and last name. which professionals who did the minimum value of the treatment cost ? provide the first name and last name .
# what about the maximum cost? what about the maximum cost ?
# how about below the average of the cost? how about below the average of the cost ?
# how many dogs for each breed code? how many dogs for each breed code ?
# which one is the most popular one? which one is the most popular one ?
# what about the least popular one? what about the least popular one ?
# so which dogs are having the breed code? and the treatment dates? so which dogs are having the breed code ? and the treatment dates ?
# show the name of dogs whose owners are from the city 'lake tia'. show the name of dogs whose owners are from the city 'lake tia ' .
# add the owner's first names also. add the owner 's first names also .
# what about when the owner is from the state of 'virginia'? what about when the owner is from the state of 'virginia ' ?
# which one is the oldest dog? list the information of it. which one is the oldest dog ? list the information of it .
# what are the last names of the oldest dogs? what are the last names of the oldest dogs ?
# what about the owner last name of the youngest dog? what about the owner last name of the youngest dog ?
# show the cities and states of the professionals. show the cities and states of the professionals .
# how many of them are from 'hawaii'? how many of them are from 'hawaii ' ?
# list the emails of the professionals who live in the state of hawaii or the state of wisconsin. list the emails of the professionals who live in the state of hawaii or the state of wisconsin .
# show the states of the professionals. show the states of the professionals .
# how many of them are from 'wisconsin'? how many of them are from 'wisconsin ' ?
# list the role code ,  street ,  city ,  state from the above results. list the role code , street , city , state from the above results .
# what about those professionals who live in a city containing the substring 'west'? what about those professionals who live in a city containing the substring 'west ' ?
# show the states of the owners. show the states of the owners .
# how many of them are from 'vermont'? how many of them are from 'vermont ' ?
# list the first name, last name and email of the owners who lives in the states that has the substring 'north'. list the first name , last name and email of the owners who lives in the states that has the substring 'north ' .
# order the dog ages in descending order. order the dog ages in descending order .
# how many of them are below 4? how many of them are below 4 ?
# what about the ones that are below the average? what about the ones that are below the average ?
# show the treatment details. show the treatment details .
# order the cost in ascending order. order the cost in ascending order .
# what about in descending order? what about in descending order ?
# which one is the most recent cost? which one is the most recent cost ?
# show all the owner information. show all the owner information .
# what about the dogs? what about the dogs ?
# among those, how many of them have been sent to receive treatment? among those , how many of them have been sent to receive treatment ?
# what about those who did not? what about those who did not ?
# show all the owner information. show all the owner information .
# how many of them come from the state of 'arizona'? how many of them come from the state of 'arizona ' ?
# what about those who do not have any dogs temporarily? what about those who do not have any dogs temporarily ?
# how many professionals are there? how many professionals are there ?
# how many of them come from 'west heidi?' how many of them come from 'west heidi ? '
# what about those who did not operate any treatment on dogs? what about those who did not operate any treatment on dogs ?
# Independent: 339, 571, 0.593695
# Dependent: 257, 632, 0.406646
# First Independent: 264, 422, 0.625592
# Other Independent: 75, 149, 0.503356
# Independent Percent: 0.474647
# {'easy': 330, 'extra': 31, 'hard': 40, 'medium': 170}
# {'easy': 240, 'extra': 5, 'hard': 12, 'medium': 82}
# {'easy': 153, 'extra': 103, 'hard': 105, 'medium': 271}
# {'easy': 0.5779334500875657,
#  'extra': 0.0542907180385289,
#  'hard': 0.07005253940455342,
#  'medium': 0.29772329246935203}
# {'easy': 0.24208860759493672,
#  'extra': 0.1629746835443038,
#  'hard': 0.1661392405063291,
#  'medium': 0.4287974683544304}
# Total Hardness:  {'easy': 483, 'medium': 441, 'hard': 145, 'extra': 134}
# Total Hardness Distribution:  {'easy': 0.4014962593516209, 'medium': 0.36658354114713215, 'hard': 0.12053200332502079, 'extra': 0.1113881961762261}
# Total Hardness Match:  {'easy': 334, 'medium': 203, 'hard': 36, 'extra': 23}
# Total Hardness Accuracy:  {'easy': 0.6915113871635611, 'medium': 0.4603174603174603, 'hard': 0.2482758620689655, 'extra': 0.17164179104477612}

# %% [markdown]
# ### EditSQL

# %%
editsql_sparc_predictions = read_predictions(editsql_sparc_path)
# Out:
# 422 1203
# 422
# 1203

# %%
editsql_sparc_predictions[0]
# Out:
# {'example_id': 1,
#  'interaction': [{'interaction_id': 1,
#    'turn_id': 1,
#    'question': 'What are all the airlines ?',
#    'ground_truth': 'SELECT * FROM AIRLINES',
#    'sql': 'select * from airlines',
#    'exact': True},
#   {'interaction_id': 1,
#    'turn_id': 2,
#    'question': 'Of these , which is Jetblue Airways ?',
#    'ground_truth': 'SELECT * FROM AIRLINES WHERE Airline  =  "JetBlue Airways"',
#    'sql': 'select * from airlines where Airline = 1',
#    'exact': True},
#   {'interaction_id': 1,
#    'turn_id': 3,
#    'question': 'What is the country corresponding it ?',
#    'ground_truth': 'SELECT Country FROM AIRLINES WHERE Airline  =  "JetBlue Airways"',
#    'sql': 'select T2.Country from airlines as T1 join airports as T2 where T1.Airline = 1',
#    'exact': 0}]}

# %%
measure_accuracy(editsql_sparc_predictions)
# Out:
# Question Match: 0.471322
# Interaction Match: 0.293839

# %%
measure_context_independent_accuracy(editsql_sparc_predictions, sparc_dev, sparc_annotation_df)
# Out:
# what are all the airlines? what are all the airlines ?
# of these, which is jetblue airways? of these , which is jetblue airways ?
# what is the country corresponding it? what is the country corresponding it ?
# what are all the abbreviations? what are all the abbreviations ?
# what is the abbreviation for jetblue airways? what is the abbreviation for jetblue airways ?
# list all airline names and their abbreviations. list all airline names and their abbreviations .
# of these, list only those in the usa. of these , list only those in the usa .
# find all information about the airport in the city anthony. find all information about the airport in the city anthony .
# what is the airport code and airport name? what is the airport code and airport name ?
# what are all the airlines? what are all the airlines ?
# how many are there? how many are there ?
# what are all the airports? what are all the airports ?
# how many are there? how many are there ?
# what are all the flights? what are all the flights ?
# how many are there? how many are there ?
# what are all the airline names? what are all the airline names ?
# of this, which has the abbreviation 'ual'? of this , which has the abbreviation 'ual ' ?
# what are the names of the airlines in the usa? what are the names of the airlines in the usa ?
# how many are there? how many are there ?
# what are the city and country for all airports? what are the city and country for all airports ?
# of these, what are the city and country for alton airport? of these , what are the city and country for alton airport ?
# what are all the airport names? what are all the airport names ?
# of these, which has code 'ako'? of these , which has code 'ako ' ?
# what are all the airport names? what are all the airport names ?
# which is in aberdeen? which is in aberdeen ?
# what are all the flights departing from 'apg'? what are all the flights departing from 'apg ' ?
# how many are there? how many are there ?
# what flights land in ato? what flights land in ato ?
# how many are there? how many are there ?
# what are all the flights derparting from aberdeen? what are all the flights derparting from aberdeen ?
# how many are there? how many are there ?
# what are all the flights arriving in aberdeen. what are all the flights arriving in aberdeen .
# how many are there? how many are there ?
# what are all the flights that leave from aberdeen? what are all the flights that leave from aberdeen ?
# of those, which land in ashley? of those , which land in ashley ?
# how many are there? how many are there ?
# what are all the flights on jetblue airways? what are all the flights on jetblue airways ?
# how many are there? how many are there ?
# what are the united airlines flights? what are the united airlines flights ?
# how many are there? how many are there ?
# how many land in asy airport? how many land in asy airport ?
# what are the united airlines flights? what are the united airlines flights ?
# which ones leave from ahd? which ones leave from ahd ?
# how many are there? how many are there ?
# which united airlines flights fly into aberdeen? which united airlines flights fly into aberdeen ?
# how many are there? how many are there ?
# name all cities that have destination airports. name all cities that have destination airports .
# order them by number of arriving flights. order them by number of arriving flights .
# which one has the most? which one has the most ?
# name all cities that have source airports. name all cities that have source airports .
# order them by number of departing flights. order them by number of departing flights .
# which one has the most? which one has the most ?
# what are airport codes of any airport with a arriving flight? what are airport codes of any airport with a arriving flight ?
# also include codes of airports with departure flights. also include codes of airports with departure flights .
# which one has the highest number of flights? which one has the highest number of flights ?
# what are airport codes of any airport with a arriving flight? what are airport codes of any airport with a arriving flight ?
# also include codes of airports with departure flights. also include codes of airports with departure flights .
# which one has the least number of flights? which one has the least number of flights ?
# count the number of flights by airline. count the number of flights by airline .
# which airline has the most? which airline has the most ?
# what are all the airline abbreviations and what countries are they in? what are all the airline abbreviations and what countries are they in ?
# order them by the number of flights that they have. order them by the number of flights that they have .
# which one has the fewest? which one has the fewest ?
# which flights leave from ahd? which flights leave from ahd ?
# what are their airlines? what are their airlines ?
# which flights arrive in ahd? which flights arrive in ahd ?
# what are their airlines? what are their airlines ?
# which airlines have flights departing from apg? which airlines have flights departing from apg ?
# of those, which also have flights from cvo? of those , which also have flights from cvo ?
# which airlines have flights from cvo? which airlines have flights from cvo ?
# of these, which do not have flights from apg? of these , which do not have flights from apg ?
# what are all the airlines? what are all the airlines ?
# which ones have more than 10 flights? which ones have more than 10 flights ?
# what are all the airlines? what are all the airlines ?
# which ones have less than 200 flights? which ones have less than 200 flights ?
# what are all the flight numbers? what are all the flight numbers ?
# which belong to united airlines? which belong to united airlines ?
# what are all the flight numbers? what are all the flight numbers ?
# of these, which correspond to flights leaving from apg? of these , which correspond to flights leaving from apg ?
# what are all the flight numbers? what are all the flight numbers ?
# also, which numbers are for flights that land in apg? also , which numbers are for flights that land in apg ?
# what are all the flight numbers? what are all the flight numbers ?
# of these, which are departure flights? of these , which are departure flights ?
# which leave from aberdeen? which leave from aberdeen ?
# what are all the flight numbers? what are all the flight numbers ?
# of these, which are arrival flights? of these , which are arrival flights ?
# which land in aberdeen? which land in aberdeen ?
# what flights land in aberdeen? what flights land in aberdeen ?
# also include flights that land in abilene. also include flights that land in abilene .
# how many are there? how many are there ?
# what are the source airports? what are the source airports ?
# also include the destination airports. also include the destination airports .
# which airports are not included? which airports are not included ?
# what information is there on pets? what information is there on pets ?
# which pets weigh more than 10? which pets weigh more than 10 ?
# how many are there? how many are there ?
# order the pets by age order the pets by age
# how much does each one weigh? how much does each one weigh ?
# what about the first one? what about the first one ?
# what are the different types of pets? what are the different types of pets ?
# for each of those types, what is the maximum weight? for each of those types , what is the maximum weight ?
# which pets are owned by students older than 20? which pets are owned by students older than 20 ?
# how many are there? how many are there ?
# who are the female students? who are the female students ?
# of those, who has a pet? of those , who has a pet ?
# how many of those have dogs? how many of those have dogs ?
# what are the different pet types? what are the different pet types ?
# how many exist? how many exist ?
# what is the first name of every student? what is the first name of every student ?
# of those names, which ones correspond to somebody who has a cat? of those names , which ones correspond to somebody who has a cat ?
# also, combine those names with those who have a dog. also , combine those names with those who have a dog .
# which students have a dog as their type of pet? which students have a dog as their type of pet ?
# who also has a cat? who also has a cat ?
# what are their first names? what are their first names ?
# which students have a cat as their pets? which students have a cat as their pets ?
# what are they majoring in? what are they majoring in ?
# also, how old are they? also , how old are they ?
# what is every student's id? what is every student 's id ?
# of those ids, which correspond to those who own cats as pets? of those ids , which correspond to those who own cats as pets ?
# list all the other ids. list all the other ids .
# which students have dogs? which students have dogs ?
# of those, who does not own a cat? of those , who does not own a cat ?
# what are their first names and ages? what are their first names and ages ?
# who is the youngest pet? who is the youngest pet ?
# what type are they? what type are they ?
# also, how much do they weigh? also , how much do they weigh ?
# what are ids of every pet? what are ids of every pet ?
# for those, which refer to pets older than 1? for those , which refer to pets older than 1 ?
# also, how much do they weigh? also , how much do they weigh ?
# what are the different pet types? what are the different pet types ?
# for each of those, what is the maximum age? for each of those , what is the maximum age ?
# what about the average age? what about the average age ?
# what information is there on pets? what information is there on pets ?
# for each pet type, what is the average weight? for each pet type , what is the average weight ?
# which students have pets? which students have pets ?
# what are the different first names? what are the different first names ?
# also, what are their ages? also , what are their ages ?
# which students have pets? which students have pets ?
# of those, whose last name is smith? of those , whose last name is smith ?
# what is their pet's id? what is their pet 's id ?
# which of the students have pets? which of the students have pets ?
# how many pets does each of them have? how many pets does each of them have ?
# what is the first name and sex of each student? what is the first name and sex of each student ?
# which of those belong to somebody who has more than one pet? which of those belong to somebody who has more than one pet ?
# what is the id of the three-year old cat? what is the id of the three-year old cat ?
# who is the owner of that cat? who is the owner of that cat ?
# what is their last name? what is their last name ?
# which students do not own any pets? which students do not own any pets ?
# what is their average age? what is their average age ?
# what are the names of all the countries? what are the names of all the countries ?
# give the names of the ones that became independent after 1950. give the names of the ones that became independent after 1950 .
# how many countries are there? how many countries are there ?
# out of those, how many have a republic as their form of government? out of those , how many have a republic as their form of government ?
# what are the countries in the carribean region? what are the countries in the carribean region ?
# what is the surface area of each of those countries? what is the surface area of each of those countries ?
# find the total surface area of the above. find the total surface area of the above .
# what continent does each country belong to? what continent does each country belong to ?
# which one does anguila belong to? which one does anguila belong to ?
# what are the names of all the regions? what are the names of all the regions ?
# which of those is the city kabul located in? which of those is the city kabul located in ?
# what are all the languages? what are all the languages ?
# what are the languages spoken in aruba? what are the languages spoken in aruba ?
# which one is the most popular? which one is the most popular ?
# what are the population and life expectancies for all countries? what are the population and life expectancies for all countries ?
# of those, which ones are for the country brazil? of those , which ones are for the country brazil ?
# which region is angola in? which region is angola in ?
# for that country, what is its population? for that country , what is its population ?
# what are the life expectancies for all the countries? what are the life expectancies for all the countries ?
# what are the life expectancies for the countries in the region of central africa? what are the life expectancies for the countries in the region of central africa ?
# what is the average of those? what is the average of those ?
# what are the names of the countries in asia? what are the names of the countries in asia ?
# which one has the shortest life expectancy? which one has the shortest life expectancy ?
# how many people live in asia? how many people live in asia ?
# what about the largest gnp among them? what about the largest gnp among them ?
# which countries are in africa? which countries are in africa ?
# which countries are also republics? which countries are also republics ?
# what is the average of their life expectancies? what is the average of their life expectancies ?
# what are the countries in the continents of asia or europe? what are the countries in the continents of asia or europe ?
# what is the surface area of each country? what is the surface area of each country ?
# what is the total surface area summed up? what is the total surface area summed up ?
# what are the populations of each city in the district of gelderland? what are the populations of each city in the district of gelderland ?
# what is the total population in that district? what is the total population in that district ?
# what are all the nations? what are all the nations ?
# which of those have a government that is a us territory? which of those have a government that is a us territory ?
# for those, what is the average gnp and total population? for those , what is the average gnp and total population ?
# what are all the distinct languages used around the world? what are all the distinct languages used around the world ?
# how many are there? how many are there ?
# what are the distinct forms of government in the continent of africa? what are the distinct forms of government in the continent of africa ?
# how many are there? how many are there ?
# what is the information about the country aruba? what is the information about the country aruba ?
# what are the languages used in aruba? what are the languages used in aruba ?
# how many are there? how many are there ?
# what are the languages used in afghanistan? what are the languages used in afghanistan ?
# of those, how many are the official languages? of those , how many are the official languages ?
# how many languages are spoken in each country? how many languages are spoken in each country ?
# which country speaks the most? which country speaks the most ?
# how many languages are spoken on each continent? how many languages are spoken on each continent ?
# which one speaks the most languages? which one speaks the most languages ?
# what are the countries that speak english? what are the countries that speak english ?
# which of those also speak dutch? which of those also speak dutch ?
# how many of them are there? how many of them are there ?
# what are the names of countries which speak english? what are the names of countries which speak english ?
# of those countries, what are the names of the nations that speak french as well? of those countries , what are the names of the nations that speak french as well ?
# what are the official languages of each country? what are the official languages of each country ?
# of those countries, give the names of the ones that have english as one of the official languages. of those countries , give the names of the ones that have english as one of the official languages .
# of those, which also have french as another official language? of those , which also have french as another official language ?
# in which countries is chinese spoken? in which countries is chinese spoken ?
# which distinct continents are they in? which distinct continents are they in ?
# how many of them are there? how many of them are there ?
# what are all the different regions? what are all the different regions ?
# which of those speak dutch or english? which of those speak dutch or english ?
# what are the official languages for each country? what are the official languages for each country ?
# which of these countries have english or dutch? which of these countries have english or dutch ?
# what are all the different languages used in the continent of asia? what are all the different languages used in the continent of asia ?
# which one is used by the largest number of asian countries? which one is used by the largest number of asian countries ?
# which countries have republics as their form of government? which countries have republics as their form of government ?
# which language is spoken by only one of those countries? which language is spoken by only one of those countries ?
# what are the names of all the cities that use english? what are the names of all the cities that use english ?
# which of those has the largest population? which of those has the largest population ?
# what are the names, population, and life expectancy for all the countries in asia? what are the names , population , and life expectancy for all the countries in asia ?
# of those, which belong to the country with the largest surface area? of those , which belong to the country with the largest surface area ?
# what are the official languages of each country? what are the official languages of each country ?
# which countries do not have english as the official language? which countries do not have english as the official language ?
# in those countries, what is the average life expectancy? in those countries , what is the average life expectancy ?
# what are the names of each country that does not speak english? what are the names of each country that does not speak english ?
# how many people live in those countries? how many people live in those countries ?
# which country has a head of state named beatrix? which country has a head of state named beatrix ?
# what languages are spoken in that country? what languages are spoken in that country ?
# which of those languages is the official one? which of those languages is the official one ?
# what are the names of all the countries? what are the names of all the countries ?
# what are the names of those countries that were founded after 1930? what are the names of those countries that were founded after 1930 ?
# for those countries, how many unique official languages are spoken in total? for those countries , how many unique official languages are spoken in total ?
# what are all the information about european countries? what are all the information about european countries ?
# of those countries, what is the minimum surface area? of those countries , what is the minimum surface area ?
# what are the countries that have a greater surface area than that? what are the countries that have a greater surface area than that ?
# what is the maximum population of a country in asia? what is the maximum population of a country in asia ?
# which countries in africa have a population smaller than that? which countries in africa have a population smaller than that ?
# what is the smallest population of a country in africa? what is the smallest population of a country in africa ?
# which asian countries have a greater population than that? which asian countries have a greater population than that ?
# what are the country codes of all the countries? what are the country codes of all the countries ?
# of those countries, give the country codes for those which do not speak english. of those countries , give the country codes for those which do not speak english .
# what are the country codes of all the countries? what are the country codes of all the countries ?
# of those, which do not speak english? of those , which do not speak english ?
# what are the country codes for countries which are not republics? what are the country codes for countries which are not republics ?
# of those, which do not speak english? of those , which do not speak english ?
# what are the names of the countries where english is the official language? what are the names of the countries where english is the official language ?
# what are the names of the countries in europe that are not one of those? what are the names of the countries in europe that are not one of those ?
# what are the names of the cities in those countries? what are the names of the cities in those countries ?
# what are the countries in asia where chinese is spoken? what are the countries in asia where chinese is spoken ?
# of those, which have chinese as the official language? of those , which have chinese as the official language ?
# what are the different cities in those countries? what are the different cities in those countries ?
# which country has the smallest population? which country has the smallest population ?
# what is its name, independence year, and surface area? what is its name , independence year , and surface area ?
# what is the country with the largest surface area? what is the country with the largest surface area ?
# what is its population, name and leader? what is its population , name and leader ?
# what are the names of the countries? what are the names of the countries ?
# which of them speak at least three languages? which of them speak at least three languages ?
# also, how many languages are spoken in each of those countries? also , how many languages are spoken in each of those countries ?
# what is the average city population for each city? what is the average city population for each city ?
# for each district, count how many cities have a population greater than the average. for each district , count how many cities have a population greater than the average .
# the countries with which government form have an average life expectancy greater than age 72? the countries with which government form have an average life expectancy greater than age 72 ?
# for those, list the total population and government form name. for those , list the total population and government form name .
# which continents have an average life expectancy less than age 72? which continents have an average life expectancy less than age 72 ?
# give their average life expectancy and total population. give their average life expectancy and total population .
# what are the countries with the top 5 largest surface areas? what are the countries with the top 5 largest surface areas ?
# what are the surface areas and names of those countries? what are the surface areas and names of those countries ?
# order the countries by descending population size. order the countries by descending population size .
# give the names of the 3 countries which have the most. give the names of the 3 countries which have the most .
# order the countries by increasing population. order the countries by increasing population .
# give the names of the 3 countries with the lowest. give the names of the 3 countries with the lowest .
# what are the countries in the continent of asia? what are the countries in the continent of asia ?
# how many are there? how many are there ?
# which countries are in the continent of europe? which countries are in the continent of europe ?
# of those, what are the names of those that have a population of 80000? of those , what are the names of those that have a population of 80000 ?
# what countries are in north america? what countries are in north america ?
# of those, which have surface area greater than 3000? of those , which have surface area greater than 3000 ?
# what is the total population and average surface area of those countries? what is the total population and average surface area of those countries ?
# what are the names of all the cities? what are the names of all the cities ?
# which of those have a population between 160000 and 900000? which of those have a population between 160000 and 900000 ?
# what are the different languages? what are the different languages ?
# which one is spoken in the most countries? which one is spoken in the most countries ?
# tell me﻿ the director of the cartoon named "day of the dark knight!". tell me﻿ the director of the cartoon named `` day of the dark knight ! `` .
# what is the channel of this cartoon? what is the channel of this cartoon ?
# give me the titles of all cartoon directed by "ben jones" or "brandon vietti"? give me the titles of all cartoon directed by `` ben jones '' or `` brandon vietti '' ?
# show me all the information about the italian tv channels. show me all the information about the italian tv channels .
# how about the polish tv channels? how about the polish tv channels ?
# which country has the most of tv channels? list the country and number of tv channels it has. which country has the most of tv channels ? list the country and number of tv channels it has .
# tell me the tv channel of the cartoon titled "the eyes of despero!". tell me the tv channel of the cartoon titled `` the eyes of despero ! `` .
# how about this channel's series name? how about this channel 's series name ?
# tell me the number of different series names and contents in the tv channel table. tell me the number of different series names and contents in the tv channel table .
# tell me the package option for the series named "rock tv". tell me the package option for the series named `` rock tv '' .
# tell me the language of this series. tell me the language of this series .
# list the language used least number of tv channel. list language and number of tv channel. list the language used least number of tv channel . list language and number of tv channel .
# tell me the author of the cartoon "the rise of the blue beetle!" tell me the author of the cartoon `` the rise of the blue beetle ! ''
# how about its director? how about its director ?
# what is its tv channel? what is its tv channel ?
# tell me the country of the tv channel for the series named "sky radio". tell me the country of the tv channel for the series named `` sky radio '' .
# how about its content? how about its content ?
# i want to know the title of all cartoons showed on tv channel with series name "sky radio". i want to know the title of all cartoons showed on tv channel with series name `` sky radio '' .
# tell me the rating of the episode named "double down". tell me the rating of the episode named `` double down '' .
# how about the rating of the episode named "keepers". how about the rating of the episode named `` keepers '' .
# okay, i want to know the top 3 highest rating tv series. list the tv series's episode and rating. okay , i want to know the top 3 highest rating tv series . list the tv series 's episode and rating .
# tell me the weekly rank of the episode named "emily". tell me the weekly rank of the episode named `` emily '' .
# how about its share? how about its share ?
# tell me the minimum and maximum share of tv series. tell me the minimum and maximum share of tv series .
# tell me the rating of the episode titled "a love of a lifetime". tell me the rating of the episode titled `` a love of a lifetime '' .
# how about its weekly rank? how about its weekly rank ?
# and what is its tv channel? and what is its tv channel ?
# tell me the content of tv channel with the series named "sky radio". tell me the content of tv channel with the series named `` sky radio '' .
# how about its language? how about its language ?
# okay, now i want to know the episode of all tv series showed on tv channel with series name "sky radio". okay , now i want to know the episode of all tv series showed on tv channel with series name `` sky radio '' .
# tell me the air date of the cartoon titled "fall of the blue beetle!". tell me the air date of the cartoon titled `` fall of the blue beetle ! `` .
# what is its production code? what is its production code ?
# tell me the production code and channel of the most recently aired cartoon. tell me the production code and channel of the most recently aired cartoon .
# tell me the cartoons directed by ben jone. tell me the cartoons directed by ben jone .
# tell me the cartoons written by todd casey. tell me the cartoons written by todd casey .
# which countries' tv channels are playing some cartoon written by todd casey? which countries ' tv channels are playing some cartoon written by todd casey ?
# which countries' tv channels are playing some cartoon written by steven melching? which countries ' tv channels are playing some cartoon written by steven melching ?
# which countries' tv channels are not playing any cartoon written by todd casey? which countries ' tv channels are not playing any cartoon written by todd casey ?
# tell me the director of the cartoon titled "deep cover for batman!". tell me the director of the cartoon titled `` deep cover for batman ! `` .
# i want to know this cartoon's production code. i want to know this cartoon 's production code .
# tell me the series name and country of the tv channel that is playing some cartoons directed by ben jones and michael chang. tell me the series name and country of the tv channel that is playing some cartoons directed by ben jones and michael chang .
# tell me the country of the tv channel with series named "mtv music" tell me the country of the tv channel with series named `` mtv music ''
# tell me the number of italian channels. tell me the number of italian channels .
# find id of the tv channels that from the countries where have more than two tv channels. find id of the tv channels that from the countries where have more than two tv channels .
# who is the director of the cartoon titled "return of the fearsome fangs!"? who is the director of the cartoon titled `` return of the fearsome fangs ! `` ?
# tell me the cartoons directed by ben jones. tell me the cartoons directed by ben jones .
# find the id of tv channels that do not play any cartoon directed by ben jones. find the id of tv channels that do not play any cartoon directed by ben jones .
# show all the poker players. show all the poker players .
# how many are there? how many are there ?
# what is the earnings of each poker player? what is the earnings of each poker player ?
# sort them in descending order. sort them in descending order .
# show all the information about each poker player. show all the information about each poker player .
# what are their final table mades? what are their final table mades ?
# what are their final table mades and best finishes? what are their final table mades and best finishes ?
# what is the earnings of each poker player? what is the earnings of each poker player ?
# give me the average. give me the average .
# what is the money rank of each poker player? what is the money rank of each poker player ?
# sort them in the decreasing order. sort them in the decreasing order .
# return the top one. return the top one .
# which poker player has earnings less than 200000? which poker player has earnings less than 200000 ?
# among them, what is the maximum number of final tables made? among them , what is the maximum number of final tables made ?
# show all the poker players. show all the poker players .
# what are their names? what are their names ?
# which poker players have earnings higher than 300000? which poker players have earnings higher than 300000 ?
# what are their names? what are their names ?
# what are the names of all poker players? what are the names of all poker players ?
# sort them in the ascending order of the final tables made. sort them in the ascending order of the final tables made .
# what is the birth date of each poker player? what is the birth date of each poker player ?
# sort the list by the poker player's earnings. sort the list by the poker player 's earnings .
# give me the result for the player with the lowest earnings. give me the result for the player with the lowest earnings .
# what is the height of each poker player? what is the height of each poker player ?
# who has the largest height? who has the largest height ?
# what is his or her money rank? what is his or her money rank ?
# what is the height of each poker player? what is the height of each poker player ?
# who all have heights greater than 200? who all have heights greater than 200 ?
# what is the average earnings among them? what is the average earnings among them ?
# sort all the poker players in descending order of earnings. sort all the poker players in descending order of earnings .
# what are the names of poker players in descending order of earnings? what are the names of poker players in descending order of earnings ?
# show the nationality of each person. show the nationality of each person .
# group people by their nationality. group people by their nationality .
# for each of the result, show the corresponding number of people of that nationality? for each of the result , show the corresponding number of people of that nationality ?
# show the nationality of each person. show the nationality of each person .
# count the number of people for each nationality. count the number of people for each nationality .
# what is the most common nationality of people? what is the most common nationality of people ?
# count the number of people for each nationality. count the number of people for each nationality .
# which nationalities are held by at least two people? which nationalities are held by at least two people ?
# what are the names and birth dates of people? what are the names and birth dates of people ?
# sort the results in ascending alphabetical order of name. sort the results in ascending alphabetical order of name .
# what are the names of all people? what are the names of all people ?
# what about people whose nationality is not "russia"? what about people whose nationality is not `` russia '' ?
# show all the poker players. show all the poker players .
# show all people who are not poker players. show all people who are not poker players .
# give me their names. give me their names .
# what are the death tolls each time? what are the death tolls each time ?
# what is the maximum number of deaths in any one time? what is the maximum number of deaths in any one time ?
# what about the minimum? what about the minimum ?
# give me the maximum and also the minimum. give me the maximum and also the minimum .
# show me information about deaths caused by ships. show me information about deaths caused by ships .
# only ships with tonnage 't'. only ships with tonnage 't ' .
# only return the death and injury information for those ships. only return the death and injury information for those ships .
# what are the ids and names of the battles? what are the ids and names of the battles ?
# only show those that ships were lost in. only show those that ships were lost in .
# please, just the ones with 'brig' ship type. please , just the ones with 'brig ' ship type .
# how many people were killed or injured in each battle? how many people were killed or injured in each battle ?
# only show the deaths for those battles that produced at least ten deaths. only show the deaths for those battles that produced at least ten deaths .
# list the injuries caused by each ship (give ship id and name please). list the injuries caused by each ship ( give ship id and name please ) .
# sort it by decreasing number of injuries. sort it by decreasing number of injuries .
# only show the ship id and name that caused the most total injuries. only show the ship id and name that caused the most total injuries .
# which battles did the bulgarian commander 'kaloyan' fight in? which battles did the bulgarian commander 'kaloyan ' fight in ?
# how about the latin commander 'baldwin i'? how about the latin commander 'baldwin i ' ?
# just the ones where they were fighting one another, please. just the ones where they were fighting one another , please .
# which battle ids lost ships with tonnage '225'? which battle ids lost ships with tonnage '225 ' ?
# give the names of these battles, too. give the names of these battles , too .
# which battle ids and names did not lose any ship with tonnage '225'? which battle ids and names did not lose any ship with tonnage '225 ' ?
# how many is that? how many is that ?
# list the name and date of the battle that has lost the ship named 'lettice' list the name and date of the battle that has lost the ship named 'lettice '
# same for 'hms atlanta', please. same for 'hms atlanta ' , please .
# can you intersect those? can you intersect those ?
# which battle ids and names lost ships in the 'english channel'? which battle ids and names lost ships in the 'english channel ' ?
# which did not? which did not ?
# for these ones, show their names, results, and bulgarian commanders. for these ones , show their names , results , and bulgarian commanders .
# how many continents are there? how many continents are there ?
# show all their ids and names! show all their ids and names !
# what countries do they each have? what countries do they each have ?
# count how many there are for each continent name and id! count how many there are for each continent name and id !
# what are the names and ids of the different car makers? what are the names and ids of the different car makers ?
# what countries are they each from? what countries are they each from ?
# for each, how many models do they each produce? for each , how many models do they each produce ?
# can actually just show the name, id and the number of models? can actually just show the name , id and the number of models ?
# what is the average horsepower of all cars? what is the average horsepower of all cars ?
# how about the maximum? how about the maximum ?
# what about the minimum? what about the minimum ?
# what is the model of the car with this horsepower? what is the model of the car with this horsepower ?
# what is the average weight of all the cars? what is the average weight of all the cars ?
# list all the car information with weights above this? list all the car information with weights above this ?
# how about below this? how about below this ?
# please, show just their model names! please , show just their model names !
# what are the ids, and models of the cars were made in 1970? what are the ids , and models of the cars were made in 1970 ?
# show their horsepower and mpg as well? show their horsepower and mpg as well ?
# also provide the names of their makers! also provide the names of their makers !
# just show a unique list of all these different makers. just show a unique list of all these different makers .
# show me the makes and models of each car! show me the makes and models of each car !
# also provide which the year they were produced? also provide which the year they were produced ?
# which ones been produce in the earliest year? which ones been produce in the earliest year ?
# show just the make and year! show just the make and year !
# what are all the different car models? what are all the different car models ?
# show also all the car makes and the years that they were produced! show also all the car makes and the years that they were produced !
# show only those that were made after 1980! show only those that were made after 1980 !
# what are the distinct car models for these? what are the distinct car models for these ?
# what are the names and country name of each car maker? what are the names and country name of each car maker ?
# also provide the continent name for each! also provide the continent name for each !
# how many car makers are there per continent? how many car makers are there per continent ?
# how many countries are there? how many countries are there ?
# how many car makers belong to each one? how many car makers belong to each one ?
# what is the name of the country that has the least number? what is the name of the country that has the least number ?
# how about the most? how about the most ?
# how many makers are there? how many makers are there ?
# what are their full names and ids? what are their full names and ids ?
# what models have they each produced? what models have they each produced ?
# count how many modes there are per maker. count how many modes there are per maker .
# show all the car ids with the make amc hornet sporabout (sw)? show all the car ids with the make amc hornet sporabout ( sw ) ?
# what is its horsepower? what is its horsepower ?
# how about its mpg? how about its mpg ?
# how about its accelerate? how about its accelerate ?
# show all the different car makers? show all the different car makers ?
# what are the names of the countries they belong to? what are the names of the countries they belong to ?
# show just the car makers from france! show just the car makers from france !
# how many are there? how many are there ?
# how many car models are produced in total? how many car models are produced in total ?
# how many in germany? how many in germany ?
# how about in japan? how about in japan ?
# how about the usa? how about the usa ?
# what is all the car information for cars produced in 1974? what is all the car information for cars produced in 1974 ?
# now, show me just the weight and cylinders of these cars. now , show me just the weight and cylinders of these cars .
# list just those with 8 cylinders! list just those with 8 cylinders !
# what is the smallest weight? what is the smallest weight ?
# what are all the different country names? what are all the different country names ?
# which ones have no car makers? which ones have no car makers ?
# which ones have at least one? which ones have at least one ?
# also provide the country id! also provide the country id !
# show all the car makers and their country name? show all the car makers and their country name ?
# count how many there are per country name? count how many there are per country name ?
# show just those from countries in the continent europe. show just those from countries in the continent europe .
# list the country names of those with at least 3 manufacturers! list the country names of those with at least 3 manufacturers !
# what is the horsepower, make for each car! what is the horsepower , make for each car !
# show those with 8 cylinders! show those with 8 cylinders !
# how about 3? how about 3 ?
# show the one with the maximum horsepower. show the one with the maximum horsepower .
# what is id of the car with the max horsepower? what is id of the car with the max horsepower ?
# how about with the max mpg? how about with the max mpg ?
# show its make! show its make !
# now show its model! now show its model !
# what is the average edispl of all cars? what is the average edispl of all cars ?
# can you show the average per car make? can you show the average per car make ?
# how about per car model? how about per car model ?
# show the average for the model volvo! show the average for the model volvo !
# what are all the different models for each car? what are all the different models for each car ?
# what are the makes for each? what are the makes for each ?
# how many makes are there for each? how many makes are there for each ?
# what is the model name with the most makes? what is the model name with the most makes ?
# show the full names of all the different car makers? show the full names of all the different car makers ?
# also include the car models produced by each! also include the car models produced by each !
# show me just those produced by the maker with full name american motor company! show me just those produced by the maker with full name american motor company !
# how many are there? how many are there ?
# what is all the information for the makers that have designed at least 1 car model! what is all the information for the makers that have designed at least 1 car model !
# which ones have designed more than 1? which ones have designed more than 1 ?
# how about more than 3? how about more than 3 ?
# list just the full name and id! list just the full name and id !
# how many different models has maker with full name general motors produced? how many different models has maker with full name general motors produced ?
# how many different models weigh over 3500 pounds? how many different models weigh over 3500 pounds ?
# how many models have either of these features? how many models have either of these features ?
# show me the distinct list of their model names! show me the distinct list of their model names !
# show the years and weight of all the cars! show the years and weight of all the cars !
# show distinct years that the cars that weigh more than 3000 were produced! show distinct years that the cars that weigh more than 3000 were produced !
# how about the different years for those that weight less than 4000. how about the different years for those that weight less than 4000 .
# what are the distinct years, for the cars that are both? what are the distinct years , for the cars that are both ?
# what is the lowest accelerate for any car? what is the lowest accelerate for any car ?
# how about the highest? how about the highest ?
# what is the id, make and model of this car? what is the id , make and model of this car ?
# show just its horsepower. show just its horsepower .
# show all the car information for any car of the model volvo! show all the car information for any car of the model volvo !
# what is the car with the least accelerate? what is the car with the least accelerate ?
# what is its horsepower? what is its horsepower ?
# what about its number of cylinders? what about its number of cylinders ?
# what is largest horsepower of all cars? what is largest horsepower of all cars ?
# what is the accelerate of the car with this horsepower? what is the accelerate of the car with this horsepower ?
# what are the car ids of the cars with a greater accelerate than this? what are the car ids of the cars with a greater accelerate than this ?
# how many are there? how many are there ?
# what are the names of the countries that have no car makers? what are the names of the countries that have no car makers ?
# show me all the names of all the different countries outside of those! show me all the names of all the different countries outside of those !
# how many of these have more than 1 car maker? how many of these have more than 1 car maker ?
# how about more than 2? how about more than 2 ?
# show all models and horsepowers of all cars! show all models and horsepowers of all cars !
# now show just the ones with 4 cylinders. now show just the ones with 4 cylinders .
# what is the model of that with the lowest horsepower? what is the model of that with the lowest horsepower ?
# how about the greatest horsepower? how about the greatest horsepower ?
# what is the lowest horsepower of all cars? what is the lowest horsepower of all cars ?
# show all the ids and makes of those with a horsepower greater than this! show all the ids and makes of those with a horsepower greater than this !
# which ones have 5 cylinders or less? which ones have 5 cylinders or less ?
# how about 3 or less? how about 3 or less ?
# show me the mpg, horsepower and accelerate for all the cars that were produced before 1980! show me the mpg , horsepower and accelerate for all the cars that were produced before 1980 !
# also include the cars that have 8 cylinders! also include the cars that have 8 cylinders !
# what is the max horsepower for this group? what is the max horsepower for this group ?
# how about the max mpg? how about the max mpg ?
# show all the models that were built by the ford motor company. show all the models that were built by the ford motor company .
# what are all the models except those! what are all the models except those !
# also provide the weights for all different makes for each of these models. also provide the weights for all different makes for each of these models .
# list all the different models from these that have makes that are lighter than 3500! list all the different models from these that have makes that are lighter than 3500 !
# what are all the names of countries? what are all the names of countries ?
# which ones have at least one car maker? which ones have at least one car maker ?
# show me all of car names other than these! show me all of car names other than these !
# show all the car maker id, names, the models and makes they produce! show all the car maker id , names , the models and makes they produce !
# ...
# give me the description of the department that offers the most number of degrees. give me the description of the department that offers the most number of degrees .
# what's the name and id of that department? what 's the name and id of that department ?
# show me all the degrees offered by the engineering department. show me all the degrees offered by the engineering department .
# how many are there? how many are there ?
# show me courses that have exactly 2 sections. show me courses that have exactly 2 sections .
# show me names and ids for courses that have at most 2 sections. show me names and ids for courses that have at most 2 sections .
# which semester did the least number of students register? give me its name and id. which semester did the least number of students register ? give me its name and id .
# how about the semester that most number of students registered? how about the semester that most number of students registered ?
# show me all department names that contain the word "computer" show me all department names that contain the word `` computer ''
# show me their descriptions. show me their descriptions .
# how many people are enrolled in 2 degree programs in one semester? how many people are enrolled in 2 degree programs in one semester ?
# show me their first, middle, and last names. show me their first , middle , and last names .
# how many people are enrolled in the bachelor degree program? how many people are enrolled in the bachelor degree program ?
# what are their first, middle, and last names? what are their first , middle , and last names ?
# show me the descriptions of programs with 3 highest number of enrolled students. show me the descriptions of programs with 3 highest number of enrolled students .
# show me the name of program with the most enrolled students. show me the name of program with the most enrolled students .
# what is the description of the program that has the least number of enrolled students? what is the description of the program that has the least number of enrolled students ?
# how about the program that has the most number of enrolled students? how about the program that has the most number of enrolled students ?
# show me the id and summary. show me the id and summary .
# show me the id, first and last names of top 3 students who have enrolled for the most times in any program. show me the id , first and last names of top 3 students who have enrolled for the most times in any program .
# show me just the top 1. show me just the top 1 .
# give me the description of a semester with no enrolled students. give me the description of a semester with no enrolled students .
# what's the name of that semester? what 's the name of that semester ?
# what's the name of the course with the least number of enrollments? what 's the name of the course with the least number of enrollments ?
# how many enrollments does the course with most enrollments have? how many enrollments does the course with most enrollments have ?
# what's the name of that course? what 's the name of that course ?
# how many students currently live in north carolina? how many students currently live in north carolina ?
# how many of those students have not registered in any degree program? how many of those students have not registered in any degree program ?
# what are their last names? what are their last names ?
# show me date and id of transcripts with exactly 2 course results. show me date and id of transcripts with exactly 2 course results .
# how about transcripts with at least 2 course results? how about transcripts with at least 2 course results ?
# what is the address of the student with first name timothy and last name ward? what is the address of the student with first name timothy and last name ward ?
# what's his phone number? what 's his phone number ?
# who was the last student to register? show me the first, middle, and last names of that student. who was the last student to register ? show me the first , middle , and last names of that student .
# who was the first to register? who was the first to register ?
# who is the least recent graduate of the school? list the first, middle, and last names. who is the least recent graduate of the school ? list the first , middle , and last names .
# who is the earliest graduate of the school? who is the earliest graduate of the school ?
# give me the id of the address that holds the most number of students? give me the id of the address that holds the most number of students ?
# how many students live there? how many students live there ?
# give me all the lines as well as the id of that address. give me all the lines as well as the id of that address .
# give me details of the first transcript released. give me details of the first transcript released .
# tell me when it was released as well, along with its details. tell me when it was released as well , along with its details .
# what is the oldest transcript release date? what is the oldest transcript release date ?
# how about the latest? how about the latest ?
# how many times, at minimum, can a course enrollment result show in different transcript? show me the course enrollment id. how many times , at minimum , can a course enrollment result show in different transcript ? show me the course enrollment id .
# how many times at most? how many times at most ?
# show other details of the transcript with least number of results. show other details of the transcript with least number of results .
# show me the date and id of that transcript. show me the date and id of that transcript .
# find a semester when there was a master student enrolled. find a semester when there was a master student enrolled .
# how about a semester when there was a bachelor student enrolled? how about a semester when there was a bachelor student enrolled ?
# find a semester that both types of students were enrolled in. find a semester that both types of students were enrolled in .
# list all the information about the owners. list all the information about the owners .
# what about the professionals? what about the professionals ?
# now show the states of them. now show the states of them .
# which of them have both owners and professionals living there? which of them have both owners and professionals living there ?
# show all the dog ages. show all the dog ages .
# what is the maximum and minimum value? what is the maximum and minimum value ?
# which of the dogs have gone through treatments? which of the dogs have gone through treatments ?
# what about the average age of them? what about the average age of them ?
# list all the professionals who are employees. list all the professionals who are employees .
# how many of them live in connecticut? how many of them live in connecticut ?
# what about in indiana? what about in indiana ?
# among all the professionals, which have done treatment only 1 treatments? among all the professionals , which have done treatment only 1 treatments ?
# list the id, last name and cell phone of the professionals who live in the state of indiana or have done treatment on more than 2 treatments? list the id , last name and cell phone of the professionals who live in the state of indiana or have done treatment on more than 2 treatments ?
# show the dog name and total cost of each dog. show the dog name and total cost of each dog .
# which of them cost over 500? which of them cost over 500 ?
# what about more than 1000? what about more than 1000 ?
# list all the names of both professionals and owners. list all the names of both professionals and owners .
# what about the dog names? what about the dog names ?
# which human names are not used as dog names. which human names are not used as dog names .
# show the professional first names and the corresponding treatment type codes for the treatment. show the professional first names and the corresponding treatment type codes for the treatment .
# what about each professional's id, role, email and the treatment type code? what about each professional 's id , role , email and the treatment type code ?
# which professional did not provide any treatment? keep the id, role and email. which professional did not provide any treatment ? keep the id , role and email .
# show the number of dogs for each owner, keep the owner id. show the number of dogs for each owner , keep the owner id .
# which one has 2 dogs? which one has 2 dogs ?
# what about the one with the most dogs? what about the one with the most dogs ?
# how many treatment does each professional finished? how many treatment does each professional finished ?
# show the first name of the professionals who did only 1 treatment. show the first name of the professionals who did only 1 treatment .
# what about at least two treatments? what about at least two treatments ?
# show the id, role, and first name of each from the above. show the id , role , and first name of each from the above .
# how many dogs for each breed code? how many dogs for each breed code ?
# which breed codes are the most popular two? which breed codes are the most popular two ?
# what about the most common 1? what about the most common 1 ?
# what name is the breed? what name is the breed ?
# show the dog name and total cost of each dog. show the dog name and total cost of each dog .
# what are the owner names and the cost from their dogs. what are the owner names and the cost from their dogs .
# who has paid for the most treatments on the dogs? keep owner ids and last names. who has paid for the most treatments on the dogs ? keep owner ids and last names .
# list the treatment type code and the description. list the treatment type code and the description .
# for each treatment type, calculate the sum of costs, and order them in descending order. for each treatment type , calculate the sum of costs , and order them in descending order .
# show the treatment type description also. show the treatment type description also .
# so what is the description of the treatment type that costs the least money in total? so what is the description of the treatment type that costs the least money in total ?
# show the dog name and total cost of each dog. show the dog name and total cost of each dog .
# how many of them cost over 700? how many of them cost over 700 ?
# which owner paid the cost larger than 400, show the owner id and the zip code? which owner paid the cost larger than 400 , show the owner id and the zip code ?
# what about the owner who spent the largest cost? what about the owner who spent the largest cost ?
# list the professional first names and their types of treatments. list the professional first names and their types of treatments .
# add the counts of them also. add the counts of them also .
# among the results, who did only 1 type of treatment? list the professional ids and cell phone numbers of them. among the results , who did only 1 type of treatment ? list the professional ids and cell phone numbers of them .
# what about at least two types of treatments? what about at least two types of treatments ?
# what is the minimum, maximum and average value of the treatment costs? what is the minimum , maximum and average value of the treatment costs ?
# which professionals who did the minimum value of the treatment cost? provide the first name and last name. which professionals who did the minimum value of the treatment cost ? provide the first name and last name .
# what about the maximum cost? what about the maximum cost ?
# how about below the average of the cost? how about below the average of the cost ?
# how many dogs for each breed code? how many dogs for each breed code ?
# which one is the most popular one? which one is the most popular one ?
# what about the least popular one? what about the least popular one ?
# so which dogs are having the breed code? and the treatment dates? so which dogs are having the breed code ? and the treatment dates ?
# show the name of dogs whose owners are from the city 'lake tia'. show the name of dogs whose owners are from the city 'lake tia ' .
# add the owner's first names also. add the owner 's first names also .
# what about when the owner is from the state of 'virginia'? what about when the owner is from the state of 'virginia ' ?
# which one is the oldest dog? list the information of it. which one is the oldest dog ? list the information of it .
# what are the last names of the oldest dogs? what are the last names of the oldest dogs ?
# what about the owner last name of the youngest dog? what about the owner last name of the youngest dog ?
# show the cities and states of the professionals. show the cities and states of the professionals .
# how many of them are from 'hawaii'? how many of them are from 'hawaii ' ?
# list the emails of the professionals who live in the state of hawaii or the state of wisconsin. list the emails of the professionals who live in the state of hawaii or the state of wisconsin .
# show the states of the professionals. show the states of the professionals .
# how many of them are from 'wisconsin'? how many of them are from 'wisconsin ' ?
# list the role code ,  street ,  city ,  state from the above results. list the role code , street , city , state from the above results .
# what about those professionals who live in a city containing the substring 'west'? what about those professionals who live in a city containing the substring 'west ' ?
# show the states of the owners. show the states of the owners .
# how many of them are from 'vermont'? how many of them are from 'vermont ' ?
# list the first name, last name and email of the owners who lives in the states that has the substring 'north'. list the first name , last name and email of the owners who lives in the states that has the substring 'north ' .
# order the dog ages in descending order. order the dog ages in descending order .
# how many of them are below 4? how many of them are below 4 ?
# what about the ones that are below the average? what about the ones that are below the average ?
# show the treatment details. show the treatment details .
# order the cost in ascending order. order the cost in ascending order .
# what about in descending order? what about in descending order ?
# which one is the most recent cost? which one is the most recent cost ?
# show all the owner information. show all the owner information .
# what about the dogs? what about the dogs ?
# among those, how many of them have been sent to receive treatment? among those , how many of them have been sent to receive treatment ?
# what about those who did not? what about those who did not ?
# show all the owner information. show all the owner information .
# how many of them come from the state of 'arizona'? how many of them come from the state of 'arizona ' ?
# what about those who do not have any dogs temporarily? what about those who do not have any dogs temporarily ?
# how many professionals are there? how many professionals are there ?
# how many of them come from 'west heidi?' how many of them come from 'west heidi ? '
# what about those who did not operate any treatment on dogs? what about those who did not operate any treatment on dogs ?
# Independent: 333, 571, 0.583187
# Dependent: 234, 632, 0.370253
# First Independent: 262, 422, 0.620853
# Other Independent: 71, 149, 0.476510
# Independent Percent: 0.474647
# {'easy': 330, 'extra': 31, 'hard': 40, 'medium': 170}
# {'easy': 241, 'extra': 4, 'hard': 13, 'medium': 75}
# {'easy': 153, 'extra': 103, 'hard': 105, 'medium': 271}
# {'easy': 0.5779334500875657,
#  'extra': 0.0542907180385289,
#  'hard': 0.07005253940455342,
#  'medium': 0.29772329246935203}
# {'easy': 0.24208860759493672,
#  'extra': 0.1629746835443038,
#  'hard': 0.1661392405063291,
#  'medium': 0.4287974683544304}
# Total Hardness:  {'easy': 483, 'medium': 441, 'hard': 145, 'extra': 134}
# Total Hardness Distribution:  {'easy': 0.4014962593516209, 'medium': 0.36658354114713215, 'hard': 0.12053200332502079, 'extra': 0.1113881961762261}
# Total Hardness Match:  {'easy': 332, 'medium': 179, 'hard': 39, 'extra': 17}
# Total Hardness Accuracy:  {'easy': 0.6873706004140787, 'medium': 0.40589569160997735, 'hard': 0.2689655172413793, 'extra': 0.12686567164179105}

# %%
## Measure turn

def measure_interaction_match_pattern(predictions: List[Dict], source_examples: List[Dict]):
    pattern_count = dict()
    interaction_match_count = 0
    for p in predictions:
        example_id = p['example_id']
        has_error = False
        for turn in p['interaction']:
            if turn['exact'] == 1 or turn['exact'] is True:
                pass
            else:
                has_error = True
                break
        if has_error:
            continue
            
        interaction_match_count += 1
        
        # Turn statistics
        source = source_examples[example_id - 1]
        hardness = list()
        for turn in source['interaction']:
            h = eval_hardness(turn['sql'])
            hardness.append(h)
        key = "-".join(hardness)
        if key not in pattern_count:
            pattern_count[key] = 0
        pattern_count[key] += 1
    print("Interaction Match Count: ", interaction_match_count)
    return pattern_count

# %%
measure_interaction_match_pattern(duorat_sparc_predictions, sparc_dev)
# Out:
# Interaction Match Count:  146
# {'easy-easy': 36,
#  'medium-medium': 12,
#  'easy-medium': 22,
#  'medium-extra': 4,
#  'easy-easy-easy': 9,
#  'easy-easy-medium': 20,
#  'easy-hard': 10,
#  'medium-hard': 3,
#  'easy-easy-hard': 1,
#  'easy-easy-easy-medium': 1,
#  'medium-medium-medium-easy': 1,
#  'easy-medium-medium-extra': 1,
#  'easy-medium-easy': 3,
#  'easy-medium-hard': 2,
#  'medium-easy': 1,
#  'easy-medium-medium': 6,
#  'medium-medium-medium': 2,
#  'easy-medium-medium-hard': 1,
#  'medium-extra-extra': 1,
#  'medium-medium-extra': 1,
#  'medium-easy-hard-hard': 1,
#  'easy-easy-extra': 1,
#  'easy-extra-hard': 1,
#  'easy-easy-hard-hard': 1,
#  'easy-easy-medium-medium': 2,
#  'extra-extra': 1,
#  'hard-hard': 1,
#  'easy-easy-easy-hard': 1}

# %%
duorat_sparc_predictions
# Out:
# [{'example_id': 1,
#   'interaction': [{'interaction_id': 1,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the airlines?',
#     'groundtruth': 'SELECT * FROM AIRLINES',
#     'sql': 'SELECT airlines.Airline FROM airlines',
#     'exact': 0},
#    {'interaction_id': 1,
#     'turn_id': 2,
#     'question': ' [SEP] Of these, which is Jetblue Airways? [SEP] What are all the airlines?',
#     'groundtruth': 'SELECT * FROM AIRLINES WHERE Airline  =  "JetBlue Airways"',
#     'sql': 'SELECT * FROM airlines WHERE airlines.Airline = " Jetblue Airways "',
#     'exact': True},
#    {'interaction_id': 1,
#     'turn_id': 3,
#     'question': ' [SEP] What is the country corresponding it? [SEP] Of these, which is Jetblue Airways? [SEP] What are all the airlines?',
#     'groundtruth': 'SELECT Country FROM AIRLINES WHERE Airline  =  "JetBlue Airways"',
#     'sql': 'SELECT airlines.Country FROM airlines WHERE airlines.Airline = " Jetblue Airways "',
#     'exact': True}]},
#  {'example_id': 2,
#   'interaction': [{'interaction_id': 2,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the abbreviations?',
#     'groundtruth': 'SELECT Abbreviation FROM AIRLINES',
#     'sql': 'SELECT airlines.Abbreviation FROM airlines',
#     'exact': True},
#    {'interaction_id': 2,
#     'turn_id': 2,
#     'question': ' [SEP] What is the abbreviation for Jetblue Airways? [SEP] What are all the abbreviations?',
#     'groundtruth': 'SELECT Abbreviation FROM AIRLINES WHERE Airline  =  "JetBlue Airways"',
#     'sql': 'SELECT airlines.Abbreviation FROM airlines WHERE airlines.Airline = " Jetblue Airways "',
#     'exact': True}]},
#  {'example_id': 3,
#   'interaction': [{'interaction_id': 3,
#     'turn_id': 1,
#     'question': ' [SEP] List all airline names and their abbreviations.',
#     'groundtruth': 'SELECT Airline ,  Abbreviation FROM AIRLINES',
#     'sql': 'SELECT airlines.Airline, airlines.Abbreviation FROM airlines',
#     'exact': True},
#    {'interaction_id': 3,
#     'turn_id': 2,
#     'question': ' [SEP] Of these, list only those in the USA. [SEP] List all airline names and their abbreviations.',
#     'groundtruth': 'SELECT Airline ,  Abbreviation FROM AIRLINES WHERE Country  =  "USA"',
#     'sql': 'SELECT airlines.Airline, airlines.Abbreviation FROM airlines WHERE airlines.Country = " USA "',
#     'exact': True}]},
#  {'example_id': 4,
#   'interaction': [{'interaction_id': 4,
#     'turn_id': 1,
#     'question': ' [SEP] Find all information about the airport in the city Anthony.',
#     'groundtruth': 'SELECT * FROM AIRPORTS WHERE city  =  "Anthony"',
#     'sql': 'SELECT * FROM airports WHERE airports.City = " Anthony "',
#     'exact': True},
#    {'interaction_id': 4,
#     'turn_id': 2,
#     'question': ' [SEP] What is the airport code and airport name? [SEP] Find all information about the airport in the city Anthony.',
#     'groundtruth': 'SELECT AirportCode ,  AirportName FROM AIRPORTS WHERE city  =  "Anthony"',
#     'sql': 'SELECT airports.AirportCode, airports.AirportName FROM airports WHERE airports.City = " Anthony "',
#     'exact': True}]},
#  {'example_id': 5,
#   'interaction': [{'interaction_id': 5,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the airlines?',
#     'groundtruth': 'SELECT * FROM AIRLINES',
#     'sql': 'SELECT airlines.Airline FROM airlines',
#     'exact': 0},
#    {'interaction_id': 5,
#     'turn_id': 2,
#     'question': ' [SEP] How many are there? [SEP] What are all the airlines?',
#     'groundtruth': 'SELECT count(*) FROM AIRLINES',
#     'sql': 'SELECT Count(*) FROM airlines',
#     'exact': True}]},
#  {'example_id': 6,
#   'interaction': [{'interaction_id': 6,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the airports?',
#     'groundtruth': 'SELECT * FROM AIRPORTS',
#     'sql': 'SELECT * FROM airports',
#     'exact': True},
#    {'interaction_id': 6,
#     'turn_id': 2,
#     'question': ' [SEP] How many are there? [SEP] What are all the airports?',
#     'groundtruth': 'SELECT count(*) FROM AIRPORTS',
#     'sql': 'SELECT Count(*) FROM airports',
#     'exact': True}]},
#  {'example_id': 7,
#   'interaction': [{'interaction_id': 7,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the flights?',
#     'groundtruth': 'SELECT * FROM FLIGHTS',
#     'sql': 'SELECT * FROM flights',
#     'exact': True},
#    {'interaction_id': 7,
#     'turn_id': 2,
#     'question': ' [SEP] How many are there? [SEP] What are all the flights?',
#     'groundtruth': 'SELECT count(*) FROM FLIGHTS',
#     'sql': 'SELECT Count(*) FROM flights',
#     'exact': True}]},
#  {'example_id': 8,
#   'interaction': [{'interaction_id': 8,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the airline names?',
#     'groundtruth': 'SELECT Airline FROM AIRLINES',
#     'sql': 'SELECT DISTINCT airlines.Airline FROM airlines',
#     'exact': True},
#    {'interaction_id': 8,
#     'turn_id': 2,
#     'question': " [SEP] Of this, which has the abbreviation 'UAL'? [SEP] What are all the airline names?",
#     'groundtruth': 'SELECT Airline FROM AIRLINES WHERE Abbreviation  =  "UAL"',
#     'sql': 'SELECT airlines.Airline FROM airlines WHERE airlines.Abbreviation = " UAL "',
#     'exact': True}]},
#  {'example_id': 9,
#   'interaction': [{'interaction_id': 9,
#     'turn_id': 1,
#     'question': ' [SEP] What are the names of the airlines in the USA?',
#     'groundtruth': 'SELECT airline FROM AIRLINES WHERE Country  =  "USA"',
#     'sql': 'SELECT airlines.Airline FROM airlines WHERE airlines.Country = " USA "',
#     'exact': True},
#    {'interaction_id': 9,
#     'turn_id': 2,
#     'question': ' [SEP] How many are there? [SEP] What are the names of the airlines in the USA?',
#     'groundtruth': 'SELECT count(*) FROM AIRLINES WHERE Country  =  "USA"',
#     'sql': 'SELECT Count(*) FROM airlines WHERE airlines.Country = " USA "',
#     'exact': True}]},
#  {'example_id': 10,
#   'interaction': [{'interaction_id': 10,
#     'turn_id': 1,
#     'question': ' [SEP] What are the city and country for all airports?',
#     'groundtruth': 'SELECT City ,  Country FROM AIRPORTS',
#     'sql': 'SELECT airports.City, airports.CountryAbbrev, airports.Country FROM airports',
#     'exact': 0},
#    {'interaction_id': 10,
#     'turn_id': 2,
#     'question': ' [SEP] Of these, what are the city and country for Alton airport? [SEP] What are the city and country for all airports?',
#     'groundtruth': 'SELECT City ,  Country FROM AIRPORTS WHERE AirportName  =  "Alton"',
#     'sql': 'SELECT airports.City, airports.Country FROM airports WHERE airports.AirportName = " Alton "',
#     'exact': True}]},
#  {'example_id': 11,
#   'interaction': [{'interaction_id': 11,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the airport names?',
#     'groundtruth': 'SELECT AirportName FROM AIRPORTS',
#     'sql': 'SELECT airports.AirportName FROM airports',
#     'exact': True},
#    {'interaction_id': 11,
#     'turn_id': 2,
#     'question': " [SEP] Of these, which has code 'AKO'? [SEP] What are all the airport names?",
#     'groundtruth': 'SELECT AirportName FROM AIRPORTS WHERE AirportCode  =  "AKO"',
#     'sql': 'SELECT airports.AirportName FROM airports WHERE airports.AirportCode = " AKO "',
#     'exact': True}]},
#  {'example_id': 12,
#   'interaction': [{'interaction_id': 12,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the airport names?',
#     'groundtruth': 'SELECT AirportName FROM AIRPORTS',
#     'sql': 'SELECT airports.AirportName FROM airports',
#     'exact': True},
#    {'interaction_id': 12,
#     'turn_id': 2,
#     'question': ' [SEP] Which is in Aberdeen? [SEP] What are all the airport names?',
#     'groundtruth': 'SELECT AirportName FROM AIRPORTS WHERE City = "Aberdeen"',
#     'sql': 'SELECT airports.AirportName FROM airports WHERE airports.City = " Aberdeen "',
#     'exact': True}]},
#  {'example_id': 13,
#   'interaction': [{'interaction_id': 13,
#     'turn_id': 1,
#     'question': " [SEP] What are all the flights departing from 'APG'?",
#     'groundtruth': 'SELECT * FROM FLIGHTS WHERE SourceAirport  =  "APG"',
#     'sql': 'SELECT * FROM flights WHERE flights.SourceAirport = " APG "',
#     'exact': True},
#    {'interaction_id': 13,
#     'turn_id': 2,
#     'question': " [SEP] How many are there? [SEP] What are all the flights departing from 'APG'?",
#     'groundtruth': 'SELECT count(*) FROM FLIGHTS WHERE SourceAirport  =  "APG"',
#     'sql': 'SELECT Count(*) FROM flights WHERE flights.SourceAirport = " APG "',
#     'exact': True}]},
#  {'example_id': 14,
#   'interaction': [{'interaction_id': 14,
#     'turn_id': 1,
#     'question': ' [SEP] What flights land in ATO?',
#     'groundtruth': 'SELECT * FROM FLIGHTS WHERE DestAirport  =  "ATO"',
#     'sql': 'SELECT * FROM flights WHERE flights.DestAirport = " ATOO "',
#     'exact': True},
#    {'interaction_id': 14,
#     'turn_id': 2,
#     'question': ' [SEP] How many are there? [SEP] What flights land in ATO?',
#     'groundtruth': 'SELECT count(*) FROM FLIGHTS WHERE DestAirport  =  "ATO"',
#     'sql': 'SELECT Count(*) FROM flights WHERE flights.DestAirport = " ATO "',
#     'exact': True}]},
#  {'example_id': 15,
#   'interaction': [{'interaction_id': 15,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the flights derparting from Aberdeen?',
#     'groundtruth': 'SELECT * FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.SourceAirport  =  T2.AirportCode WHERE T2.City  =  "Aberdeen"',
#     'sql': 'SELECT * FROM flights JOIN flights JOIN airports ON airports.AirportCode = flights.SourceAirport AND airports.AirportCode = airports.AirportCode WHERE airports.City = " Aberdeen "',
#     'exact': False},
#    {'interaction_id': 15,
#     'turn_id': 2,
#     'question': ' [SEP] How many are there? [SEP] What are all the flights derparting from Aberdeen?',
#     'groundtruth': 'SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.SourceAirport  =  T2.AirportCode WHERE T2.City  =  "Aberdeen"',
#     'sql': 'SELECT Count(*) FROM airports JOIN flights ON airports.AirportCode = flights.SourceAirport WHERE airports.City = " Aberdeen "',
#     'exact': True}]},
#  {'example_id': 16,
#   'interaction': [{'interaction_id': 16,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the flights arriving in Aberdeen.',
#     'groundtruth': 'SELECT * FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode WHERE T2.City  =  "Aberdeen"',
#     'sql': 'SELECT * FROM flights JOIN airports ON flights.SourceAirport = airports.AirportCode WHERE airports.City = " Aberdeen "',
#     'exact': True},
#    {'interaction_id': 16,
#     'turn_id': 2,
#     'question': ' [SEP] How many are there? [SEP] What are all the flights arriving in Aberdeen.',
#     'groundtruth': 'SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode WHERE T2.City  =  "Aberdeen"',
#     'sql': 'SELECT Count(*) FROM flights JOIN airports ON flights.DestAirport = airports.AirportCode WHERE airports.City = " Aberdeen "',
#     'exact': True}]},
#  {'example_id': 17,
#   'interaction': [{'interaction_id': 17,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the flights that leave from Aberdeen?',
#     'groundtruth': 'SELECT * FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.SourceAirport  =  T2.AirportCode WHERE T2.City  =  "Aberdeen"',
#     'sql': 'SELECT * FROM flights JOIN airports ON flights.SourceAirport = airports.AirportCode WHERE airports.City = " Aberdeen "',
#     'exact': True},
#    {'interaction_id': 17,
#     'turn_id': 2,
#     'question': ' [SEP] Of those, which land in Ashley? [SEP] What are all the flights that leave from Aberdeen?',
#     'groundtruth': 'SELECT * FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode JOIN AIRPORTS AS T3 ON T1.SourceAirport  =  T3.AirportCode WHERE T2.City  =  "Ashley" AND T3.City  =  "Aberdeen"',
#     'sql': 'SELECT * FROM airports JOIN flights ON airports.AirportCode = flights.DestAirport WHERE airports.City = " Aberdeen " AND airports.AirportName = " Ashley "',
#     'exact': 0},
#    {'interaction_id': 17,
#     'turn_id': 3,
#     'question': ' [SEP] How many are there? [SEP] Of those, which land in Ashley? [SEP] What are all the flights that leave from Aberdeen?',
#     'groundtruth': 'SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode JOIN AIRPORTS AS T3 ON T1.SourceAirport  =  T3.AirportCode WHERE T2.City  =  "Ashley" AND T3.City  =  "Aberdeen"',
#     'sql': 'SELECT Count(*) FROM airports JOIN flights ON airports.AirportCode = flights.DestAirport WHERE airports.City = " Aberdeen " AND airports.City = " Ashley "',
#     'exact': False}]},
#  {'example_id': 18,
#   'interaction': [{'interaction_id': 18,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the flights on Jetblue Airways?',
#     'groundtruth': 'SELECT * FROM FLIGHTS AS T1 JOIN AIRLINES AS T2 ON T1.Airline  =  T2.uid WHERE T2.Airline = "JetBlue Airways"',
#     'sql': 'SELECT * FROM flights JOIN airlines ON flights.Airline = airlines.uid WHERE airlines.Airline = " Jetblue Airways "',
#     'exact': True},
#    {'interaction_id': 18,
#     'turn_id': 2,
#     'question': ' [SEP] How many are there? [SEP] What are all the flights on Jetblue Airways?',
#     'groundtruth': 'SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRLINES AS T2 ON T1.Airline  =  T2.uid WHERE T2.Airline = "JetBlue Airways"',
#     'sql': 'SELECT Count(*) FROM flights ON flights.Airline = flights.Airline JOIN airlines ON airlines.uid = airlines.uid JOIN flights WHERE airlines.Airline = " Jetblue Airways "',
#     'exact': False}]},
#  {'example_id': 19,
#   'interaction': [{'interaction_id': 19,
#     'turn_id': 1,
#     'question': ' [SEP] What are the United Airlines flights?',
#     'groundtruth': 'SELECT * FROM AIRLINES WHERE Airline  =  "United Airlines"',
#     'sql': 'SELECT * FROM airlines JOIN flights ON airlines.uid = flights.Airline WHERE airlines.Airline = " United Airlines "',
#     'exact': False},
#    {'interaction_id': 19,
#     'turn_id': 2,
#     'question': ' [SEP] How many are there? [SEP] What are the United Airlines flights?',
#     'groundtruth': 'SELECT count(*) FROM AIRLINES WHERE Airline  =  "United Airlines"',
#     'sql': 'SELECT Count(*) FROM airlines JOIN flights ON airlines.uid = flights.Airline WHERE airlines.Airline = " United Airlines "',
#     'exact': False},
#    {'interaction_id': 19,
#     'turn_id': 3,
#     'question': ' [SEP] How many land in ASY Airport? [SEP] How many are there? [SEP] What are the United Airlines flights?',
#     'groundtruth': 'SELECT count(*) FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T2.Airline  =  T1.uid WHERE T1.Airline  =  "United Airlines" AND T2.DestAirport  =  "ASY"',
#     'sql': 'SELECT Count(*) FROM airports JOIN flights ON airports.AirportCode = flights.SourceAirport AND flights.Airline = flights.Airline JOIN airlines WHERE airports.Country = " AS "',
#     'exact': 0}]},
#  {'example_id': 20,
#   'interaction': [{'interaction_id': 20,
#     'turn_id': 1,
#     'question': ' [SEP] What are the United Airlines flights?',
#     'groundtruth': 'SELECT * FROM AIRLINES WHERE Airline  =  "United Airlines"',
#     'sql': 'SELECT * FROM airlines JOIN flights ON airlines.uid = flights.Airline WHERE airlines.Airline = " United Airlines "',
#     'exact': False},
#    {'interaction_id': 20,
#     'turn_id': 2,
#     'question': ' [SEP] Which ones leave from AHD? [SEP] What are the United Airlines flights?',
#     'groundtruth': 'SELECT * FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T2.Airline  =  T1.uid WHERE T1.Airline  =  "United Airlines" AND T2.SourceAirport  =  "AHD"',
#     'sql': 'SELECT flights.FlightNo FROM airlines JOIN flights ON airlines.uid = flights.Airline WHERE airlines.Airline = " United Airlines " AND flights.DestAirport = " AH "',
#     'exact': 0},
#    {'interaction_id': 20,
#     'turn_id': 3,
#     'question': ' [SEP] How many are there? [SEP] Which ones leave from AHD? [SEP] What are the United Airlines flights?',
#     'groundtruth': 'SELECT count(*) FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T2.Airline  =  T1.uid WHERE T1.Airline  =  "United Airlines" AND T2.SourceAirport  =  "AHD"',
#     'sql': 'SELECT Count(*) FROM airlines JOIN airports JOIN flights ON airlines.uid = flights.Airline AND airports.AirportCode = flights.Airline WHERE airlines.Airline = " United Airlines " AND flights.SourceAirport = " AH "',
#     'exact': False}]},
#  {'example_id': 21,
#   'interaction': [{'interaction_id': 21,
#     'turn_id': 1,
#     'question': ' [SEP] Which United Airlines flights fly into Aberdeen?',
#     'groundtruth': 'SELECT * FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode JOIN AIRLINES AS T3 ON T3.uid  =  T1.Airline WHERE T2.City  =  "Aberdeen" AND T3.Airline  =  "United Airlines"',
#     'sql': 'SELECT * FROM airlines JOIN airports JOIN flights ON airlines.uid = flights.Airline AND airports.AirportCode = flights.SourceAirport AND airports.AirportCode = flights.DestAirport JOIN flights WHERE airports.City = " United " AND airports.City = " United "',
#     'exact': 0},
#    {'interaction_id': 21,
#     'turn_id': 2,
#     'question': ' [SEP] How many are there? [SEP] Which United Airlines flights fly into Aberdeen?',
#     'groundtruth': 'SELECT count(*) FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport  =  T2.AirportCode JOIN AIRLINES AS T3 ON T3.uid  =  T1.Airline WHERE T2.City  =  "Aberdeen" AND T3.Airline  =  "United Airlines"',
#     'sql': 'SELECT Count(*) FROM airlines JOIN flights ON airlines.uid = flights.SourceAirport JOIN airports ON airports.AirportCode = flights.SourceAirport JOIN airports WHERE airports.City = " United " AND airlines.Airline = " Aberdeen "',
#     'exact': False}]},
#  {'example_id': 22,
#   'interaction': [{'interaction_id': 22,
#     'turn_id': 1,
#     'question': ' [SEP] Name all cities that have destination airports.',
#     'groundtruth': 'SELECT T1.City FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport',
#     'sql': 'SELECT DISTINCT airports.City FROM airports',
#     'exact': False},
#    {'interaction_id': 22,
#     'turn_id': 2,
#     'question': ' [SEP] Order them by number of arriving flights. [SEP] Name all cities that have destination airports.',
#     'groundtruth': 'SELECT T1.City FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport GROUP BY T1.City ORDER BY count(*) DESC',
#     'sql': 'SELECT airports.City FROM airports JOIN flights ON airports.AirportCode = flights.DestAirport GROUP BY airports.City ORDER BY Count(*) Asc',
#     'exact': 0},
#    {'interaction_id': 22,
#     'turn_id': 3,
#     'question': ' [SEP] Which one has the most? [SEP] Order them by number of arriving flights. [SEP] Name all cities that have destination airports.',
#     'groundtruth': 'SELECT T1.City FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport GROUP BY T1.City ORDER BY count(*) DESC LIMIT 1',
#     'sql': 'SELECT airports.City FROM airports JOIN flights ON airports.AirportCode = flights.DestAirport GROUP BY airports.City ORDER BY Count(*) Desc LIMIT 1',
#     'exact': True}]},
#  {'example_id': 23,
#   'interaction': [{'interaction_id': 23,
#     'turn_id': 1,
#     'question': ' [SEP] Name all cities that have source airports.',
#     'groundtruth': 'SELECT T1.City FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.SourceAirport',
#     'sql': 'SELECT DISTINCT airports.City FROM airports',
#     'exact': False},
#    {'interaction_id': 23,
#     'turn_id': 2,
#     'question': ' [SEP] Order them by number of departing flights. [SEP] Name all cities that have source airports.',
#     'groundtruth': 'SELECT T1.City FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.SourceAirport GROUP BY T1.City ORDER BY count(*) DESC',
#     'sql': 'SELECT airports.City FROM airports JOIN flights ON airports.AirportCode = flights.SourceAirport GROUP BY flights.SourceAirport ORDER BY Count(*) Asc',
#     'exact': 0},
#    {'interaction_id': 23,
#     'turn_id': 3,
#     'question': ' [SEP] Which one has the most? [SEP] Order them by number of departing flights. [SEP] Name all cities that have source airports.',
#     'groundtruth': 'SELECT T1.City FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.SourceAirport GROUP BY T1.City ORDER BY count(*) DESC LIMIT 1',
#     'sql': 'SELECT airports.City FROM airports JOIN flights ON airports.AirportCode = flights.SourceAirport GROUP BY flights.SourceAirport ORDER BY Count(*) Desc LIMIT 1',
#     'exact': 0}]},
#  {'example_id': 24,
#   'interaction': [{'interaction_id': 24,
#     'turn_id': 1,
#     'question': ' [SEP] What are airport codes of any airport with a arriving flight?',
#     'groundtruth': 'SELECT T1.AirportCode FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport',
#     'sql': 'SELECT airports.AirportCode FROM airports JOIN flights ON airports.AirportCode = flights.DestAirport',
#     'exact': True},
#    {'interaction_id': 24,
#     'turn_id': 2,
#     'question': ' [SEP] Also include codes of airports with departure flights. [SEP] What are airport codes of any airport with a arriving flight?',
#     'groundtruth': 'SELECT T1.AirportCode FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport OR T1.AirportCode  =  T2.SourceAirport',
#     'sql': 'SELECT airports.AirportCode FROM airports JOIN flights ON airports.AirportCode = flights.DestAirport UNION SELECT airports.AirportCode FROM airports',
#     'exact': 0},
#    {'interaction_id': 24,
#     'turn_id': 3,
#     'question': ' [SEP] Which one has the highest number of flights? [SEP] Also include codes of airports with departure flights. [SEP] What are airport codes of any airport with a arriving flight?',
#     'groundtruth': 'SELECT T1.AirportCode FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport OR T1.AirportCode  =  T2.SourceAirport GROUP BY T1.AirportCode ORDER BY count(*) DESC LIMIT 1',
#     'sql': 'SELECT airports.AirportCode FROM airports JOIN flights ON airports.AirportCode = flights.DestAirport GROUP BY airports.AirportCode ORDER BY Count(*) Desc LIMIT 1',
#     'exact': True}]},
#  {'example_id': 25,
#   'interaction': [{'interaction_id': 25,
#     'turn_id': 1,
#     'question': ' [SEP] What are airport codes of any airport with a arriving flight?',
#     'groundtruth': 'SELECT T1.AirportCode FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport',
#     'sql': 'SELECT airports.AirportCode FROM airports JOIN flights ON airports.AirportCode = flights.DestAirport',
#     'exact': True},
#    {'interaction_id': 25,
#     'turn_id': 2,
#     'question': ' [SEP] Also include codes of airports with departure flights. [SEP] What are airport codes of any airport with a arriving flight?',
#     'groundtruth': 'SELECT T1.AirportCode FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport OR T1.AirportCode  =  T2.SourceAirport',
#     'sql': 'SELECT airports.AirportCode FROM airports JOIN flights ON airports.AirportCode = flights.DestAirport UNION SELECT airports.AirportCode FROM airports',
#     'exact': 0},
#    {'interaction_id': 25,
#     'turn_id': 3,
#     'question': ' [SEP] Which one has the least number of flights? [SEP] Also include codes of airports with departure flights. [SEP] What are airport codes of any airport with a arriving flight?',
#     'groundtruth': 'SELECT T1.AirportCode FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport OR T1.AirportCode  =  T2.SourceAirport GROUP BY T1.AirportCode ORDER BY count(*) LIMIT 1',
#     'sql': 'SELECT airports.AirportCode FROM airports JOIN flights ON airports.AirportCode = flights.DestAirport GROUP BY airports.AirportCode ORDER BY Count(*) Asc LIMIT 1',
#     'exact': True}]},
#  {'example_id': 26,
#   'interaction': [{'interaction_id': 26,
#     'turn_id': 1,
#     'question': ' [SEP] Count the number of flights by airline.',
#     'groundtruth': 'SELECT count(*) ,  T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline GROUP BY T1.Airline',
#     'sql': 'SELECT flights.Airline, Count(*) FROM flights GROUP BY airlines.uid',
#     'exact': 0},
#    {'interaction_id': 26,
#     'turn_id': 2,
#     'question': ' [SEP] Which airline has the most? [SEP] Count the number of flights by airline.',
#     'groundtruth': 'SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline GROUP BY T1.Airline ORDER BY count(*) DESC LIMIT 1',
#     'sql': 'SELECT airlines.Airline FROM airlines JOIN flights ON flights.Airline = flights.Airline GROUP BY flights.Airline ORDER BY Count(*) Desc LIMIT 1',
#     'exact': 0}]},
#  {'example_id': 27,
#   'interaction': [{'interaction_id': 27,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the airline abbreviations and what countries are they in?',
#     'groundtruth': 'SELECT Abbreviation ,  Country FROM AIRLINES',
#     'sql': 'SELECT airlines.Abbreviation, airlines.Country FROM airlines',
#     'exact': True},
#    {'interaction_id': 27,
#     'turn_id': 2,
#     'question': ' [SEP] Order them by the number of flights that they have. [SEP] What are all the airline abbreviations and what countries are they in?',
#     'groundtruth': 'SELECT T1.Abbreviation ,  T1.Country FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline GROUP BY T1.Airline ORDER BY count(*)',
#     'sql': 'SELECT airlines.Abbreviation, airlines.Country FROM airlines JOIN flights ON airlines.uid = flights.Airline GROUP BY airlines.Abbreviation ORDER BY Count(*) Asc',
#     'exact': 0},
#    {'interaction_id': 27,
#     'turn_id': 3,
#     'question': ' [SEP] Which one has the fewest? [SEP] Order them by the number of flights that they have. [SEP] What are all the airline abbreviations and what countries are they in?',
#     'groundtruth': 'SELECT T1.Abbreviation ,  T1.Country FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline GROUP BY T1.Airline ORDER BY count(*) LIMIT 1',
#     'sql': 'SELECT airlines.Abbreviation FROM airlines GROUP BY airlines.Abbreviation ORDER BY Count(*) Asc LIMIT 1',
#     'exact': 0}]},
#  {'example_id': 28,
#   'interaction': [{'interaction_id': 28,
#     'turn_id': 1,
#     'question': ' [SEP] Which flights leave from AHD?',
#     'groundtruth': 'SELECT * FROM FLIGHTS WHERE SourceAirport  =  "AHD"',
#     'sql': 'SELECT * FROM flights WHERE flights.SourceAirport = " AHDD "',
#     'exact': True},
#    {'interaction_id': 28,
#     'turn_id': 2,
#     'question': ' [SEP] What are their airlines? [SEP] Which flights leave from AHD?',
#     'groundtruth': 'SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.SourceAirport  =  "AHD"',
#     'sql': 'SELECT airlines.Airline FROM airlines JOIN flights ON airlines.uid = flights.Airline AND flights.Airline = flights.Airline JOIN flights WHERE flights.SourceAirport = " AH "',
#     'exact': False}]},
#  {'example_id': 29,
#   'interaction': [{'interaction_id': 29,
#     'turn_id': 1,
#     'question': ' [SEP] Which flights arrive in AHD?',
#     'groundtruth': 'SELECT * FROM FLIGHTS WHERE DestAirport  =  "AHD"',
#     'sql': 'SELECT * FROM flights WHERE flights.DestAirport = " AHD "',
#     'exact': True},
#    {'interaction_id': 29,
#     'turn_id': 2,
#     'question': ' [SEP] What are their airlines? [SEP] Which flights arrive in AHD?',
#     'groundtruth': 'SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.DestAirport  =  "AHD"',
#     'sql': 'SELECT airlines.Airline, flights.Airline FROM airlines ON airlines.uid = airlines.uid JOIN flights ON flights.Airline = flights.Airline JOIN flights WHERE flights.SourceAirport = " AH "',
#     'exact': 0}]},
#  {'example_id': 30,
#   'interaction': [{'interaction_id': 30,
#     'turn_id': 1,
#     'question': ' [SEP] Which airlines have flights departing from APG?',
#     'groundtruth': 'SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.SourceAirport  =  "APG"',
#     'sql': 'SELECT DISTINCT airlines.Airline FROM airlines JOIN flights ON airlines.uid = flights.Airline WHERE flights.SourceAirport = " APG "',
#     'exact': True},
#    {'interaction_id': 30,
#     'turn_id': 2,
#     'question': ' [SEP] Of those, which also have flights from CVO? [SEP] Which airlines have flights departing from APG?',
#     'groundtruth': 'SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.SourceAirport  =  "APG" INTERSECT SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.SourceAirport  =  "CVO"',
#     'sql': 'SELECT airlines.Airline FROM airlines JOIN flights ON airlines.uid = flights.Airline WHERE flights.SourceAirport = " APG " INTERSECT SELECT airlines.Airline FROM airlines JOIN flights ON airlines.uid = flights.Airline WHERE flights.SourceAirport = " CV "',
#     'exact': True}]},
#  {'example_id': 31,
#   'interaction': [{'interaction_id': 31,
#     'turn_id': 1,
#     'question': ' [SEP] Which airlines have flights from CVO?',
#     'groundtruth': 'SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.SourceAirport  =  "CVO"',
#     'sql': 'SELECT DISTINCT airlines.Airline FROM airlines JOIN flights ON airlines.uid = flights.Airline WHERE flights.SourceAirport = " CVO "',
#     'exact': True},
#    {'interaction_id': 31,
#     'turn_id': 2,
#     'question': ' [SEP] Of these, which do not have flights from APG? [SEP] Which airlines have flights from CVO?',
#     'groundtruth': 'SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.SourceAirport  =  "CVO" EXCEPT SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline WHERE T2.SourceAirport  =  "APG"',
#     'sql': 'SELECT airlines.Airline FROM airlines JOIN flights ON airlines.uid = flights.Airline WHERE flights.SourceAirport = " CV " EXCEPT SELECT airlines.Airline FROM airlines JOIN flights ON airlines.uid = flights.Airline WHERE flights.SourceAirport = " AP "',
#     'exact': True}]},
#  {'example_id': 32,
#   'interaction': [{'interaction_id': 32,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the airlines?',
#     'groundtruth': 'SELECT DISTINCT Airline FROM AIRLINES',
#     'sql': 'SELECT airlines.Airline FROM airlines',
#     'exact': True},
#    {'interaction_id': 32,
#     'turn_id': 2,
#     'question': ' [SEP] Which ones have more than 10 flights? [SEP] What are all the airlines?',
#     'groundtruth': 'SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline GROUP BY T1.Airline HAVING count(*)  >  10',
#     'sql': 'SELECT airlines.Airline FROM airlines JOIN flights ON airlines.uid = flights.Airline GROUP BY flights.Airline HAVING Count(*) > 10',
#     'exact': 0}]},
#  {'example_id': 33,
#   'interaction': [{'interaction_id': 33,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the airlines?',
#     'groundtruth': 'SELECT DISTINCT Airline FROM AIRLINES',
#     'sql': 'SELECT airlines.Airline FROM airlines',
#     'exact': True},
#    {'interaction_id': 33,
#     'turn_id': 2,
#     'question': ' [SEP] Which ones have less than 200 flights? [SEP] What are all the airlines?',
#     'groundtruth': 'SELECT T1.Airline FROM AIRLINES AS T1 JOIN FLIGHTS AS T2 ON T1.uid  =  T2.Airline GROUP BY T1.Airline HAVING count(*)  <  200',
#     'sql': 'SELECT airlines.Airline FROM airlines JOIN flights ON airlines.uid = flights.Airline GROUP BY flights.Airline HAVING Count(*) < 200',
#     'exact': 0}]},
#  {'example_id': 34,
#   'interaction': [{'interaction_id': 34,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the flight numbers?',
#     'groundtruth': 'SELECT FlightNo FROM FLIGHTS',
#     'sql': 'SELECT flights.FlightNo FROM flights',
#     'exact': True},
#    {'interaction_id': 34,
#     'turn_id': 2,
#     'question': ' [SEP] Which belong to United Airlines? [SEP] What are all the flight numbers?',
#     'groundtruth': 'SELECT T1.FlightNo FROM FLIGHTS AS T1 JOIN AIRLINES AS T2 ON T2.uid  =  T1.Airline WHERE T2.Airline  =  "United Airlines"',
#     'sql': 'SELECT flights.FlightNo FROM flights JOIN airlines ON flights.Airline = airlines.uid WHERE airlines.Airline = " United Airlines "',
#     'exact': True}]},
#  {'example_id': 35,
#   'interaction': [{'interaction_id': 35,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the flight numbers?',
#     'groundtruth': 'SELECT FlightNo FROM FLIGHTS',
#     'sql': 'SELECT flights.FlightNo FROM flights',
#     'exact': True},
#    {'interaction_id': 35,
#     'turn_id': 2,
#     'question': ' [SEP] Of these, which correspond to flights leaving from APG? [SEP] What are all the flight numbers?',
#     'groundtruth': 'SELECT FlightNo FROM FLIGHTS WHERE SourceAirport  =  "APG"',
#     'sql': 'SELECT flights.FlightNo FROM flights WHERE flights.SourceAirport = " APG "',
#     'exact': True}]},
#  {'example_id': 36,
#   'interaction': [{'interaction_id': 36,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the flight numbers?',
#     'groundtruth': 'SELECT FlightNo FROM FLIGHTS',
#     'sql': 'SELECT flights.FlightNo FROM flights',
#     'exact': True},
#    {'interaction_id': 36,
#     'turn_id': 2,
#     'question': ' [SEP] Also, which numbers are for flights that land in APG? [SEP] What are all the flight numbers?',
#     'groundtruth': 'SELECT FlightNo FROM FLIGHTS WHERE DestAirport  =  "APG"',
#     'sql': 'SELECT flights.FlightNo FROM flights WHERE flights.DestAirport = " AP " OR flights.DestAirport = " AP "',
#     'exact': 0}]},
#  {'example_id': 37,
#   'interaction': [{'interaction_id': 37,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the flight numbers?',
#     'groundtruth': 'SELECT FlightNo FROM FLIGHTS',
#     'sql': 'SELECT flights.FlightNo FROM flights',
#     'exact': True},
#    {'interaction_id': 37,
#     'turn_id': 2,
#     'question': ' [SEP] Of these, which are departure flights? [SEP] What are all the flight numbers?',
#     'groundtruth': 'SELECT T1.FlightNo FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.SourceAirport   =  T2.AirportCode',
#     'sql': 'SELECT flights.FlightNo FROM flights',
#     'exact': False},
#    {'interaction_id': 37,
#     'turn_id': 3,
#     'question': ' [SEP] Which leave from Aberdeen? [SEP] Of these, which are departure flights? [SEP] What are all the flight numbers?',
#     'groundtruth': 'SELECT T1.FlightNo FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.SourceAirport   =  T2.AirportCode WHERE T2.City  =  "Aberdeen"',
#     'sql': 'SELECT flights.FlightNo FROM flights JOIN airports ON flights.SourceAirport = airports.AirportCode WHERE airports.City = " Aberdeen "',
#     'exact': True}]},
#  {'example_id': 38,
#   'interaction': [{'interaction_id': 38,
#     'turn_id': 1,
#     'question': ' [SEP] What are all the flight numbers?',
#     'groundtruth': 'SELECT FlightNo FROM FLIGHTS',
#     'sql': 'SELECT flights.FlightNo FROM flights',
#     'exact': True},
#    {'interaction_id': 38,
#     'turn_id': 2,
#     'question': ' [SEP] Of these, which are arrival flights? [SEP] What are all the flight numbers?',
#     'groundtruth': 'SELECT T1.FlightNo FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport   =  T2.AirportCode',
#     'sql': 'SELECT flights.FlightNo FROM flights',
#     'exact': False},
#    {'interaction_id': 38,
#     'turn_id': 3,
#     'question': ' [SEP] Which land in Aberdeen? [SEP] Of these, which are arrival flights? [SEP] What are all the flight numbers?',
#     'groundtruth': 'SELECT T1.FlightNo FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport   =  T2.AirportCode WHERE T2.City  =  "Aberdeen"',
#     'sql': 'SELECT flights.FlightNo FROM airports JOIN flights ON airports.AirportCode = flights.DestAirport WHERE airports.City = " Aberdeen "',
#     'exact': True}]},
#  {'example_id': 39,
#   'interaction': [{'interaction_id': 39,
#     'turn_id': 1,
#     'question': ' [SEP] What flights land in Aberdeen?',
#     'groundtruth': 'SELECT * FROM Flights AS T1 JOIN Airports AS T2 ON T1.DestAirport  =  T2.AirportCode WHERE T2.city  =  "Aberdeen"',
#     'sql': 'SELECT * FROM airports JOIN flights ON airports.AirportCode = flights.SourceAirport WHERE airports.City = " Aberdeen "',
#     'exact': True},
#    {'interaction_id': 39,
#     'turn_id': 2,
#     'question': ' [SEP] Also include flights that land in Abilene. [SEP] What flights land in Aberdeen?',
#     'groundtruth': 'SELECT * FROM Flights AS T1 JOIN Airports AS T2 ON T1.DestAirport  =  T2.AirportCode WHERE T2.city  =  "Aberdeen" OR T2.city  =  "Abilene"',
#     'sql': 'SELECT Sum(flights.FlightNo) FROM airports JOIN flights ON airports.AirportCode = flights.DestAirport WHERE airports.City = " Aberdeen " OR airports.City = " Ab "',
#     'exact': 0},
#    {'interaction_id': 39,
#     'turn_id': 3,
#     'question': ' [SEP] How many are there? [SEP] Also include flights that land in Abilene. [SEP] What flights land in Aberdeen?',
#     'groundtruth': 'SELECT count(*) FROM Flights AS T1 JOIN Airports AS T2 ON T1.DestAirport  =  T2.AirportCode WHERE T2.city  =  "Aberdeen" OR T2.city  =  "Abilene"',
#     'sql': 'SELECT Count(*) FROM airports JOIN flights ON airports.AirportCode = flights.DestAirport WHERE airports.City = " Aberdeen " OR airports.City = " Ab "',
#     'exact': True}]},
#  {'example_id': 40,
#   'interaction': [{'interaction_id': 40,
#     'turn_id': 1,
#     'question': ' [SEP] What are the source airports?',
#     'groundtruth': 'SELECT SourceAirport FROM Flights',
#     'sql': 'SELECT DISTINCT airports.AirportName FROM airports',
#     'exact': 0},
#    {'interaction_id': 40,
#     'turn_id': 2,
#     'question': ' [SEP] Also include the destination airports. [SEP] What are the source airports?',
#     'groundtruth': 'SELECT SourceAirport FROM Flights UNION SELECT DestAirport FROM Flights',
#     'sql': 'SELECT flights.SourceAirport, flights.DestAirport FROM airports JOIN flights ON airports.AirportCode = flights.SourceAirport',
#     'exact': 0},
#    {'interaction_id': 40,
#     'turn_id': 3,
#     'question': ' [SEP] Which airports are not included? [SEP] Also include the destination airports. [SEP] What are the source airports?',
#     'groundtruth': 'SELECT AirportName FROM Airports WHERE AirportCode NOT IN (SELECT SourceAirport FROM Flights UNION SELECT DestAirport FROM Flights)',
#     'sql': 'SELECT airports.AirportCode FROM airports EXCEPT SELECT flights.SourceAirport FROM flights',
#     'exact': 0}]},
#  {'example_id': 41,
#   'interaction': [{'interaction_id': 41,
#     'turn_id': 1,
#     'question': ' [SEP] What information is there on pets?',
#     'groundtruth': 'SELECT * FROM pets',
#     'sql': 'SELECT * FROM Pets',
#     'exact': True},
#    {'interaction_id': 41,
#     'turn_id': 2,
#     'question': ' [SEP] Which pets weigh more than 10? [SEP] What information is there on pets?',
#     'groundtruth': 'SELECT * FROM pets WHERE weight  >  10',
#     'sql': 'SELECT * FROM Pets WHERE Pets.weight > 10',
#     'exact': True},
#    {'interaction_id': 41,
#     'turn_id': 3,
#     'question': ' [SEP] How many are there? [SEP] Which pets weigh more than 10? [SEP] What information is there on pets?',
#     'groundtruth': 'SELECT count(*) FROM pets WHERE weight  >  10',
#     'sql': 'SELECT Count(*) FROM Pets WHERE Pets.weight > 10',
#     'exact': True}]},
#  {'example_id': 42,
#   'interaction': [{'interaction_id': 42,
#     'turn_id': 1,
#     'question': ' [SEP] Order the pets by age',
#     'groundtruth': 'SELECT * FROM pets ORDER BY pet_age',
#     'sql': 'SELECT * FROM Pets ORDER BY Pets.pet_age Asc',
#     'exact': True},
#    {'interaction_id': 42,
#     'turn_id': 2,
#     'question': ' [SEP] How much does each one weigh? [SEP] Order the pets by age',
#     'groundtruth': 'SELECT weight FROM pets ORDER BY pet_age',
#     'sql': 'SELECT Pets.pet_age, Pets.weight FROM Pets ORDER BY Pets.pet_age Asc',
#     'exact': 0},
#    {'interaction_id': 42,
#     'turn_id': 3,
#     'question': ' [SEP] What about the first one? [SEP] How much does each one weigh? [SEP] Order the pets by age',
#     'groundtruth': 'SELECT weight FROM pets ORDER BY pet_age LIMIT 1',
#     'sql': 'SELECT Pets.weight, Pets.weight FROM Pets ORDER BY Pets.pet_age Asc LIMIT 1',
#     'exact': 0}]},
#  {'example_id': 43,
#   'interaction': [{'interaction_id': 43,
#     'turn_id': 1,
#     'question': ' [SEP] What are the different types of pets?',
#     'groundtruth': 'SELECT DISTINCT petType FROM pets',
#     'sql': 'SELECT DISTINCT Pets.PetType FROM Pets',
#     'exact': True},
#    {'interaction_id': 43,
#     'turn_id': 2,
#     'question': ' [SEP] For each of those types, what is the maximum weight? [SEP] What are the different types of pets?',
#     'groundtruth': 'SELECT max(weight) ,  petType FROM pets GROUP BY petType',
#     'sql': 'SELECT Pets.PetType, Max(Pets.weight) FROM Pets GROUP BY Pets.PetType',
#     'exact': True}]},
#  {'example_id': 44,
#   'interaction': [{'interaction_id': 44,
#     'turn_id': 1,
#     'question': ' [SEP] Which pets are owned by students older than 20?',
#     'groundtruth': 'SELECT * FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid WHERE T1.age  >  20',
#     'sql': 'SELECT Pets.PetID FROM Has_Pet JOIN Pets ON Pets.PetID = Pets.PetID JOIN Student ON Has_Pet.StuID = Student.StuID WHERE Student.Age > 20',
#     'exact': 0},
#    {'interaction_id': 44,
#     'turn_id': 2,
#     'question': ' [SEP] How many are there? [SEP] Which pets are owned by students older than 20?',
#     'groundtruth': 'SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid WHERE T1.age  >  20',
#     'sql': 'SELECT Count(*) FROM Has_Pet JOIN Pets ON Has_Pet.PetID = Pets.PetID JOIN Student ON Has_Pet.StuID = Student.StuID WHERE Student.Age > 20',
#     'exact': False}]},
#  {'example_id': 45,
#   'interaction': [{'interaction_id': 45,
#     'turn_id': 1,
#     'question': ' [SEP] Who are the female students?',
#     'groundtruth': "SELECT * FROM student WHERE sex  =  'F'",
#     'sql': 'SELECT * FROM Student WHERE Student.Sex = " f "',
#     'exact': True},
#    {'interaction_id': 45,
#     'turn_id': 2,
#     'question': ' [SEP] Of those, who has a pet? [SEP] Who are the female students?',
#     'groundtruth': "SELECT * FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid WHERE T1.sex  =  'F'",
#     'sql': 'SELECT * FROM Student JOIN Has_Pet ON Student.StuID = Has_Pet.StuID WHERE Student.Sex = " f "',
#     'exact': True},
#    {'interaction_id': 45,
#     'turn_id': 3,
#     'question': ' [SEP] How many of those have dogs? [SEP] Of those, who has a pet? [SEP] Who are the female students?',
#     'groundtruth': "SELECT count(*) FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T2.petid  =  T3.petid WHERE T1.sex  =  'F' AND T3.pettype  =  'dog'",
#     'sql': 'SELECT Count(*) FROM Student JOIN Has_Pet ON Student.StuID = Has_Pet.StuID WHERE Student.Sex = " f " AND Student.Sex = " f "',
#     'exact': 0}]},
#  {'example_id': 46,
#   'interaction': [{'interaction_id': 46,
#     'turn_id': 1,
#     'question': ' [SEP] What are the different pet types?',
#     'groundtruth': 'SELECT DISTINCT pettype FROM pets',
#     'sql': 'SELECT DISTINCT Pets.PetType FROM Pets',
#     'exact': True},
#    {'interaction_id': 46,
#     'turn_id': 2,
#     'question': ' [SEP] How many exist? [SEP] What are the different pet types?',
#     'groundtruth': 'SELECT count(DISTINCT pettype) FROM pets',
#     'sql': 'SELECT Count(DISTINCT Pets.PetType) FROM Pets',
#     'exact': True}]},
#  {'example_id': 47,
#   'interaction': [{'interaction_id': 47,
#     'turn_id': 1,
#     'question': ' [SEP] what is the first name of every student?',
#     'groundtruth': 'SELECT DISTINCT T1.Fname FROM student AS T1',
#     'sql': 'SELECT Student.Fname FROM Student',
#     'exact': True},
#    {'interaction_id': 47,
#     'turn_id': 2,
#     'question': ' [SEP] Of those names, which ones correspond to somebody who has a cat? [SEP] what is the first name of every student?',
#     'groundtruth': "SELECT DISTINCT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat'",
#     'sql': 'SELECT Student.Fname FROM Student JOIN Has_Pet ON Student.StuID = Has_Pet.StuID JOIN Pets ON Has_Pet.PetID = Pets.PetID WHERE Pets.PetType = " cat "',
#     'exact': True},
#    {'interaction_id': 47,
#     'turn_id': 3,
#     'question': ' [SEP] Also, combine those names with those who have a dog. [SEP] Of those names, which ones correspond to somebody who has a cat? [SEP] what is the first name of every student?',
#     'groundtruth': "SELECT DISTINCT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat' OR T3.pettype  =  'dog'",
#     'sql': 'SELECT Student.Fname FROM Student JOIN Has_Pet ON Student.StuID = Has_Pet.StuID JOIN Pets ON Has_Pet.PetID = Pets.PetID WHERE Pets.PetType = " % " OR Pets.PetType = " dog " UNION SELECT Student.LName FROM Student JOIN Has_Pet ON Student.StuID = Has_Pet.StuID JOIN Pets ON Has_Pet.PetID = Pets.PetID WHERE Pets.PetType = " dog "',
#     'exact': 0}]},
#  {'example_id': 48,
#   'interaction': [{'interaction_id': 48,
#     'turn_id': 1,
#     'question': ' [SEP] Which students have a dog as their type of pet?',
#     'groundtruth': "SELECT * FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'dog'",
#     'sql': 'SELECT * FROM Student JOIN Has_Pet ON Student.StuID = Has_Pet.StuID JOIN Pets ON Has_Pet.PetID = Pets.PetID WHERE Pets.PetType = " dog "',
#     'exact': True},
#    {'interaction_id': 48,
#     'turn_id': 2,
#     'question': ' [SEP] Who also has a cat? [SEP] Which students have a dog as their type of pet?',
#     'groundtruth': "SELECT * FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat' INTERSECT SELECT * FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'dog'",
#     'sql': 'SELECT Student.Fname FROM Student JOIN Has_Pet ON Student.StuID = Has_Pet.StuID JOIN Pets ON Has_Pet.PetID = Pets.PetID WHERE Pets.PetType = " dog " INTERSECT SELECT Student.LName FROM Student JOIN Has_Pet ON Student.StuID = Has_Pet.StuID JOIN Pets ON Has_Pet.PetID = Pets.PetID WHERE Pets.PetType = " cat "',
#     'exact': 0},
#    {'interaction_id': 48,
#     'turn_id': 3,
#     'question': ' [SEP] What are their first names? [SEP] Who also has a cat? [SEP] Which students have a dog as their type of pet?',
#     'groundtruth': "SELECT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat' INTERSECT SELECT T1.Fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'dog'",
#     'sql': 'SELECT Student.Fname FROM Student JOIN Has_Pet ON Student.StuID = Has_Pet.StuID JOIN Pets ON Has_Pet.PetID = Pets.PetID WHERE Pets.PetType = " dog " INTERSECT SELECT Student.Fname FROM Student JOIN Has_Pet ON Student.StuID = Has_Pet.StuID JOIN Pets ON Has_Pet.PetID = Pets.PetID WHERE Pets.PetType = " cat "',
#     'exact': True}]},
#  {'example_id': 49,
#   'interaction': [{'interaction_id': 49,
#     'turn_id': 1,
#     'question': ' [SEP] Which students have a cat as their pets?',
#     'groundtruth': "SELECT * FROM student WHERE stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat')",
#     'sql': 'SELECT * FROM Student JOIN Has_Pet ON Student.StuID = Has_Pet.StuID JOIN Pets ON Has_Pet.PetID = Pets.PetID WHERE Pets.PetType = " cat "',
#     'exact': 0},
#    {'interaction_id': 49,
#     'turn_id': 2,
#     'question': ' [SEP] What are they majoring in? [SEP] Which students have a cat as their pets?',
#     'groundtruth': "SELECT major FROM student WHERE stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat')",
#     'sql': 'SELECT Student.Major FROM Student JOIN Has_Pet ON Student.StuID = Has_Pet.StuID JOIN Pets ON Has_Pet.PetID = Pets.PetID WHERE Pets.PetType = " cat "',
#     'exact': 0},
#    {'interaction_id': 49,
#     'turn_id': 3,
#     'question': ' [SEP] Also, how old are they? [SEP] What are they majoring in? [SEP] Which students have a cat as their pets?',
#     'groundtruth': "SELECT major ,  age FROM student WHERE stuid NOT IN (SELECT T1.stuid FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid JOIN pets AS T3 ON T3.petid  =  T2.petid WHERE T3.pettype  =  'cat')",
#     'sql': 'SELECT Student.Age, Pets.pet_age FROM Student JOIN Has_Pet ON Student.StuID = Has_Pet.StuID JOIN Pets ON Has_Pet.PetID = Pets.PetID WHERE Pets.PetType = " cat "',
#     'exact': 0}]},
#  {'example_id': 50,
# ...
#     'sql': 'SELECT Professionals.first_name, Professionals.last_name FROM Professionals JOIN Treatments ON Professionals.professional_id = Treatments.professional_id ORDER BY Treatments.cost_of_treatment Desc LIMIT 1',
#     'exact': 0},
#    {'interaction_id': 411,
#     'turn_id': 4,
#     'question': ' [SEP] How about below the average of the cost? [SEP] What about the maximum cost? [SEP] Which professionals who did the minimum value of the treatment cost? Provide the first name and last name. [SEP] What is the minimum, maximum and average value of the treatment costs?',
#     'groundtruth': 'SELECT DISTINCT T1.first_name ,  T1.last_name FROM Professionals AS T1 JOIN Treatments AS T2 WHERE cost_of_treatment  <  ( SELECT avg(cost_of_treatment) FROM Treatments )',
#     'sql': 'SELECT Professionals.first_name, Professionals.last_name FROM Professionals JOIN Treatments ON Professionals.professional_id = Treatments.professional_id WHERE Treatments.cost_of_treatment < (SELECT Avg(Treatments.cost_of_treatment) FROM Treatments)',
#     'exact': True}]},
#  {'example_id': 412,
#   'interaction': [{'interaction_id': 412,
#     'turn_id': 1,
#     'question': ' [SEP] How many dogs for each breed code?',
#     'groundtruth': 'SELECT breed_code, count(*) FROM Dogs GROUP BY breed_code',
#     'sql': 'SELECT Dogs.breed_code, Count(*) FROM Dogs GROUP BY Dogs.breed_code',
#     'exact': True},
#    {'interaction_id': 412,
#     'turn_id': 2,
#     'question': ' [SEP] Which one is the most popular one? [SEP] How many dogs for each breed code?',
#     'groundtruth': 'SELECT breed_code, count(*) FROM Dogs GROUP BY breed_code Order BY count(*) DESC LIMIT 1',
#     'sql': 'SELECT Dogs.breed_code FROM Dogs GROUP BY Dogs.breed_code ORDER BY Count(*) Desc LIMIT 1',
#     'exact': 0},
#    {'interaction_id': 412,
#     'turn_id': 3,
#     'question': ' [SEP] What about the least popular one? [SEP] Which one is the most popular one? [SEP] How many dogs for each breed code?',
#     'groundtruth': 'SELECT breed_code, count(*) FROM Dogs GROUP BY breed_code Order BY count(*) ASC LIMIT 1',
#     'sql': 'SELECT Dogs.breed_code FROM Dogs GROUP BY Dogs.breed_code ORDER BY Count(*) Asc LIMIT 1',
#     'exact': 0},
#    {'interaction_id': 412,
#     'turn_id': 4,
#     'question': ' [SEP] So which dogs are having the breed code? And the treatment dates? [SEP] What about the least popular one? [SEP] Which one is the most popular one? [SEP] How many dogs for each breed code?',
#     'groundtruth': 'SELECT T1.name ,  T2.date_of_treatment FROM Dogs AS T1 JOIN Treatments AS T2 ON T1.dog_id  =  T2.dog_id WHERE T1.breed_code  =  ( SELECT breed_code FROM Dogs GROUP BY breed_code ORDER BY count(*) ASC LIMIT 1 )',
#     'sql': 'SELECT Dogs.breed_code, Treatments.date_of_treatment FROM Dogs JOIN Treatments ON Dogs.dog_id = Treatments.dog_id GROUP BY Dogs.breed_code ORDER BY Count(*) Asc LIMIT 1',
#     'exact': 0}]},
#  {'example_id': 413,
#   'interaction': [{'interaction_id': 413,
#     'turn_id': 1,
#     'question': " [SEP] Show the name of dogs whose owners are from the city 'Lake Tia'.",
#     'groundtruth': "SELECT T2.name FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id  =  T2.owner_id WHERE T1.city  =  'Lake Tia'",
#     'sql': 'SELECT Dogs.name, Owners.last_name FROM Dogs JOIN Owners ON Dogs.owner_id = Owners.owner_id WHERE Owners.city = " Lake Tia "',
#     'exact': 0},
#    {'interaction_id': 413,
#     'turn_id': 2,
#     'question': " [SEP] Add the owner's first names also. [SEP] Show the name of dogs whose owners are from the city 'Lake Tia'.",
#     'groundtruth': "SELECT T1.first_name, T2.name FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id  =  T2.owner_id WHERE T1.city  =  'Lake Tia'",
#     'sql': 'SELECT Dogs.name, Owners.last_name FROM Owners JOIN Dogs ON Owners.owner_id = Dogs.owner_id WHERE Owners.city = " Lake Tia "',
#     'exact': 0},
#    {'interaction_id': 413,
#     'turn_id': 3,
#     'question': " [SEP] What about when the owner is from the state of 'Virginia'? [SEP] Add the owner's first names also. [SEP] Show the name of dogs whose owners are from the city 'Lake Tia'.",
#     'groundtruth': "SELECT T1.first_name ,  T2.name FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id  =  T2.owner_id WHERE T1.state  =  'Virginia'",
#     'sql': 'SELECT Owners.first_name, Owners.last_name FROM Owners JOIN Dogs ON Owners.owner_id = Dogs.owner_id WHERE Owners.state = " Virginia "',
#     'exact': 0}]},
#  {'example_id': 414,
#   'interaction': [{'interaction_id': 414,
#     'turn_id': 1,
#     'question': ' [SEP] Which one is the oldest dog? List the information of it.',
#     'groundtruth': 'SELECT * FROM Dogs order by age asc limit 1',
#     'sql': 'SELECT * FROM Dogs ORDER BY Dogs.age Asc LIMIT 1',
#     'exact': True},
#    {'interaction_id': 414,
#     'turn_id': 2,
#     'question': ' [SEP] What are the last names of the oldest dogs? [SEP] Which one is the oldest dog? List the information of it.',
#     'groundtruth': 'SELECT T1.last_name FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id  =  T2.owner_id WHERE T2.age  =  ( SELECT max(age) FROM Dogs )',
#     'sql': 'SELECT Owners.last_name FROM Dogs ORDER BY Dogs.date_of_birth Desc LIMIT 1',
#     'exact': 0},
#    {'interaction_id': 414,
#     'turn_id': 3,
#     'question': ' [SEP] What about the owner last name of the youngest dog? [SEP] What are the last names of the oldest dogs? [SEP] Which one is the oldest dog? List the information of it.',
#     'groundtruth': 'SELECT T1.last_name FROM Owners AS T1 JOIN Dogs AS T2 ON T1.owner_id  =  T2.owner_id WHERE T2.age  =  ( SELECT min(age) FROM Dogs )',
#     'sql': 'SELECT Owners.last_name FROM Owners JOIN Dogs ON Owners.owner_id = Dogs.owner_id ORDER BY Dogs.age Asc LIMIT 1',
#     'exact': 0}]},
#  {'example_id': 415,
#   'interaction': [{'interaction_id': 415,
#     'turn_id': 1,
#     'question': ' [SEP] Show the cities and states of the professionals.',
#     'groundtruth': 'SELECT city, state FROM professionals',
#     'sql': 'SELECT Professionals.first_name, Professionals.state FROM Professionals',
#     'exact': 0},
#    {'interaction_id': 415,
#     'turn_id': 2,
#     'question': " [SEP] How many of them are from 'Hawaii'? [SEP] Show the cities and states of the professionals.",
#     'groundtruth': "SELECT count(*) FROM professionals WHERE state = 'Hawaii'",
#     'sql': 'SELECT Count(*) FROM Professionals WHERE Professionals.role_code = " Hawaii "',
#     'exact': 0},
#    {'interaction_id': 415,
#     'turn_id': 3,
#     'question': " [SEP] List the emails of the professionals who live in the state of Hawaii or the state of Wisconsin. [SEP] How many of them are from 'Hawaii'? [SEP] Show the cities and states of the professionals.",
#     'groundtruth': "SELECT email_address FROM Professionals WHERE state  =  'Hawaii' OR state  =  'Wisconsin'",
#     'sql': 'SELECT Professionals.email_address FROM Professionals WHERE Professionals.state = " Hawaii " OR Professionals.state = " Wisconsin "',
#     'exact': True}]},
#  {'example_id': 416,
#   'interaction': [{'interaction_id': 416,
#     'turn_id': 1,
#     'question': ' [SEP] Show the states of the professionals.',
#     'groundtruth': 'SELECT state FROM professionals',
#     'sql': 'SELECT Professionals.state FROM Professionals',
#     'exact': True},
#    {'interaction_id': 416,
#     'turn_id': 2,
#     'question': " [SEP] How many of them are from 'Wisconsin'? [SEP] Show the states of the professionals.",
#     'groundtruth': "SELECT count(*) FROM professionals WHERE state = 'Wisconsin'",
#     'sql': 'SELECT Count(*) FROM Professionals WHERE Professionals.state = " Wisconsin "',
#     'exact': True},
#    {'interaction_id': 416,
#     'turn_id': 3,
#     'question': " [SEP] List the role code ,  street ,  city ,  state from the above results. [SEP] How many of them are from 'Wisconsin'? [SEP] Show the states of the professionals.",
#     'groundtruth': "SELECT role_code ,  street ,  city ,  state FROM professionals WHERE state = 'Wisconsin'",
#     'sql': 'SELECT Professionals.role_code, Professionals.street, Professionals.city, Professionals.city FROM Professionals WHERE Professionals.state = " Wisconsin "',
#     'exact': 0},
#    {'interaction_id': 416,
#     'turn_id': 4,
#     'question': " [SEP] What about those professionals who live in a city containing the substring 'West'? [SEP] List the role code ,  street ,  city ,  state from the above results. [SEP] How many of them are from 'Wisconsin'? [SEP] Show the states of the professionals.",
#     'groundtruth': "SELECT role_code ,  street ,  city ,  state FROM professionals WHERE city LIKE '%West%'",
#     'sql': 'SELECT Count(*), Professionals.street, Professionals.state FROM Professionals WHERE Professionals.city LIKE " % West % "',
#     'exact': 0}]},
#  {'example_id': 417,
#   'interaction': [{'interaction_id': 417,
#     'turn_id': 1,
#     'question': ' [SEP] Show the states of the owners.',
#     'groundtruth': 'SELECT state FROM Owners',
#     'sql': 'SELECT Owners.state FROM Owners',
#     'exact': True},
#    {'interaction_id': 417,
#     'turn_id': 2,
#     'question': " [SEP] How many of them are from 'Vermont'? [SEP] Show the states of the owners.",
#     'groundtruth': "SELECT count(*) FROM Owners WHERE state = 'Vermont'",
#     'sql': 'SELECT Count(*) FROM Owners WHERE Owners.state = " Vermont "',
#     'exact': True},
#    {'interaction_id': 417,
#     'turn_id': 3,
#     'question': " [SEP] List the first name, last name and email of the owners who lives in the states that has the substring 'North'. [SEP] How many of them are from 'Vermont'? [SEP] Show the states of the owners.",
#     'groundtruth': "SELECT first_name ,  last_name ,  email_address FROM Owners WHERE state LIKE '%North%'",
#     'sql': 'SELECT Owners.first_name, Owners.last_name, Owners.email_address FROM Owners WHERE Owners.state LIKE " % North % "',
#     'exact': True}]},
#  {'example_id': 418,
#   'interaction': [{'interaction_id': 418,
#     'turn_id': 1,
#     'question': ' [SEP] Order the dog ages in descending order.',
#     'groundtruth': 'SELECT age FROM Dogs ORDER BY age',
#     'sql': 'SELECT * FROM Dogs ORDER BY Dogs.age Desc',
#     'exact': 0},
#    {'interaction_id': 418,
#     'turn_id': 2,
#     'question': ' [SEP] How many of them are below 4? [SEP] Order the dog ages in descending order.',
#     'groundtruth': 'SELECT count(*) FROM Dogs WHERE age  < 4',
#     'sql': 'SELECT Count(*) FROM Dogs WHERE Dogs.age < 4',
#     'exact': True},
#    {'interaction_id': 418,
#     'turn_id': 3,
#     'question': ' [SEP] What about the ones that are below the average? [SEP] How many of them are below 4? [SEP] Order the dog ages in descending order.',
#     'groundtruth': 'SELECT count(*) FROM Dogs WHERE age  <  ( SELECT avg(age) FROM Dogs )',
#     'sql': 'SELECT Count(*) FROM Dogs WHERE Dogs.age < (SELECT Avg(Dogs.age) FROM Dogs)',
#     'exact': True}]},
#  {'example_id': 419,
#   'interaction': [{'interaction_id': 419,
#     'turn_id': 1,
#     'question': ' [SEP] Show the treatment details.',
#     'groundtruth': 'SELECT * FROM Treatments',
#     'sql': 'SELECT * FROM Treatments',
#     'exact': True},
#    {'interaction_id': 419,
#     'turn_id': 2,
#     'question': ' [SEP] Order the cost in ascending order. [SEP] Show the treatment details.',
#     'groundtruth': 'SELECT cost_of_treatment FROM Treatments ORDER BY cost_of_treatment ASC',
#     'sql': 'SELECT * FROM Treatments ORDER BY Treatments.cost_of_treatment Asc',
#     'exact': 0},
#    {'interaction_id': 419,
#     'turn_id': 3,
#     'question': ' [SEP] What about in descending order? [SEP] Order the cost in ascending order. [SEP] Show the treatment details.',
#     'groundtruth': 'SELECT cost_of_treatment FROM Treatments ORDER BY cost_of_treatment DESC',
#     'sql': 'SELECT * FROM Treatments ORDER BY Treatments.cost_of_treatment Desc',
#     'exact': 0},
#    {'interaction_id': 419,
#     'turn_id': 4,
#     'question': ' [SEP] Which one is the most recent cost? [SEP] What about in descending order? [SEP] Order the cost in ascending order. [SEP] Show the treatment details.',
#     'groundtruth': 'SELECT cost_of_treatment FROM Treatments ORDER BY date_of_treatment DESC LIMIT 1',
#     'sql': 'SELECT Treatments.cost_of_treatment FROM Treatments ORDER BY Treatments.date_of_treatment Desc LIMIT 1',
#     'exact': True}]},
#  {'example_id': 420,
#   'interaction': [{'interaction_id': 420,
#     'turn_id': 1,
#     'question': ' [SEP] Show all the owner information.',
#     'groundtruth': 'SELECT * FROM Owners',
#     'sql': 'SELECT * FROM Owners',
#     'exact': True},
#    {'interaction_id': 420,
#     'turn_id': 2,
#     'question': ' [SEP] What about the dogs? [SEP] Show all the owner information.',
#     'groundtruth': 'SELECT count(*) FROM Dogs',
#     'sql': 'SELECT * FROM Owners',
#     'exact': 0},
#    {'interaction_id': 420,
#     'turn_id': 3,
#     'question': ' [SEP] Among those, how many of them have been sent to receive treatment? [SEP] What about the dogs? [SEP] Show all the owner information.',
#     'groundtruth': 'SELECT count(*) FROM Dogs WHERE dog_id IN ( SELECT dog_id FROM Treatments )',
#     'sql': 'SELECT Count(*) FROM Owners JOIN Dogs ON Owners.owner_id = Dogs.owner_id JOIN Treatments ON Dogs.dog_id = Treatments.dog_id GROUP BY Owners.owner_id',
#     'exact': 0},
#    {'interaction_id': 420,
#     'turn_id': 4,
#     'question': ' [SEP] What about those who did not? [SEP] Among those, how many of them have been sent to receive treatment? [SEP] What about the dogs? [SEP] Show all the owner information.',
#     'groundtruth': 'SELECT count(*) FROM Dogs WHERE dog_id NOT IN ( SELECT dog_id FROM Treatments )',
#     'sql': 'SELECT Count(*) FROM Owners WHERE Owners.owner_id NOT IN (SELECT Dogs.owner_id FROM Dogs)',
#     'exact': 0}]},
#  {'example_id': 421,
#   'interaction': [{'interaction_id': 421,
#     'turn_id': 1,
#     'question': ' [SEP] Show all the owner information.',
#     'groundtruth': 'SELECT * FROM Owners',
#     'sql': 'SELECT * FROM Owners',
#     'exact': True},
#    {'interaction_id': 421,
#     'turn_id': 2,
#     'question': " [SEP] How many of them come from the state of 'Arizona'? [SEP] Show all the owner information.",
#     'groundtruth': "SELECT count(*) FROM Owners WHERE state = 'Arizona'",
#     'sql': 'SELECT Count(*) FROM Owners WHERE Owners.state = " Arizona "',
#     'exact': True},
#    {'interaction_id': 421,
#     'turn_id': 3,
#     'question': " [SEP] What about those who do not have any dogs temporarily? [SEP] How many of them come from the state of 'Arizona'? [SEP] Show all the owner information.",
#     'groundtruth': 'SELECT count(*) FROM Owners WHERE owner_id NOT IN ( SELECT owner_id FROM Dogs )',
#     'sql': 'SELECT Count(*) FROM Owners WHERE Owners.owner_id NOT IN (SELECT Dogs.owner_id FROM Owners JOIN Dogs ON Owners.owner_id = Dogs.owner_id WHERE Owners.state = " Arizona " EXCEPT SELECT Owners.state FROM Owners WHERE Owners.state = " walk ")',
#     'exact': 0}]},
#  {'example_id': 422,
#   'interaction': [{'interaction_id': 422,
#     'turn_id': 1,
#     'question': ' [SEP] How many professionals are there?',
#     'groundtruth': 'SELECT count(*) FROM Professionals',
#     'sql': 'SELECT Count(*) FROM Professionals',
#     'exact': True},
#    {'interaction_id': 422,
#     'turn_id': 2,
#     'question': " [SEP] How many of them come from 'West Heidi?' [SEP] How many professionals are there?",
#     'groundtruth': "SELECT count(*) FROM Professionals WHERE city = 'West Heidi'",
#     'sql': 'SELECT Count(*) FROM Professionals WHERE Professionals.street = " West Heidi "',
#     'exact': 0},
#    {'interaction_id': 422,
#     'turn_id': 3,
#     'question': " [SEP] What about those who did not operate any treatment on dogs? [SEP] How many of them come from 'West Heidi?' [SEP] How many professionals are there?",
#     'groundtruth': 'SELECT count(*) FROM Professionals WHERE professional_id NOT IN ( SELECT professional_id FROM Treatments )',
#     'sql': 'SELECT Count(*) FROM Professionals EXCEPT SELECT * FROM Professionals JOIN Treatments ON Professionals.professional_id = Treatments.professional_id JOIN Dogs ON Treatments.dog_id = Dogs.dog_id WHERE Professionals.city = " West "',
#     'exact': 0}]}]

# %%
def evaluate_easy(sparc_dev):
    for ex in sparc_dev:
        for turn in ex['interaction']:
            h = eval_hardness(turn['sql'])
            if h == "easy":
                print(turn['query'])

# %%
evaluate_easy(sparc_dev)
# Out:
# SELECT * FROM AIRLINES
# SELECT * FROM AIRLINES WHERE Airline  =  "JetBlue Airways"
# SELECT Country FROM AIRLINES WHERE Airline  =  "JetBlue Airways"
# SELECT Abbreviation FROM AIRLINES
# SELECT Abbreviation FROM AIRLINES WHERE Airline  =  "JetBlue Airways"
# SELECT * FROM AIRPORTS WHERE city  =  "Anthony"
# SELECT * FROM AIRLINES
# SELECT count(*) FROM AIRLINES
# SELECT * FROM AIRPORTS
# SELECT count(*) FROM AIRPORTS
# SELECT * FROM FLIGHTS
# SELECT count(*) FROM FLIGHTS
# SELECT Airline FROM AIRLINES
# SELECT Airline FROM AIRLINES WHERE Abbreviation  =  "UAL"
# SELECT airline FROM AIRLINES WHERE Country  =  "USA"
# SELECT count(*) FROM AIRLINES WHERE Country  =  "USA"
# SELECT AirportName FROM AIRPORTS
# SELECT AirportName FROM AIRPORTS WHERE AirportCode  =  "AKO"
# SELECT AirportName FROM AIRPORTS
# SELECT AirportName FROM AIRPORTS WHERE City = "Aberdeen"
# SELECT * FROM FLIGHTS WHERE SourceAirport  =  "APG"
# SELECT count(*) FROM FLIGHTS WHERE SourceAirport  =  "APG"
# SELECT * FROM FLIGHTS WHERE DestAirport  =  "ATO"
# SELECT count(*) FROM FLIGHTS WHERE DestAirport  =  "ATO"
# SELECT * FROM AIRLINES WHERE Airline  =  "United Airlines"
# SELECT count(*) FROM AIRLINES WHERE Airline  =  "United Airlines"
# SELECT * FROM AIRLINES WHERE Airline  =  "United Airlines"
# SELECT T1.City FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport
# SELECT T1.City FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.SourceAirport
# SELECT T1.AirportCode FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport
# SELECT T1.AirportCode FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport OR T1.AirportCode  =  T2.SourceAirport
# SELECT T1.AirportCode FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport
# SELECT T1.AirportCode FROM AIRPORTS AS T1 JOIN FLIGHTS AS T2 ON T1.AirportCode  =  T2.DestAirport OR T1.AirportCode  =  T2.SourceAirport
# SELECT * FROM FLIGHTS WHERE SourceAirport  =  "AHD"
# SELECT * FROM FLIGHTS WHERE DestAirport  =  "AHD"
# SELECT DISTINCT Airline FROM AIRLINES
# SELECT DISTINCT Airline FROM AIRLINES
# SELECT FlightNo FROM FLIGHTS
# SELECT FlightNo FROM FLIGHTS
# SELECT FlightNo FROM FLIGHTS WHERE SourceAirport  =  "APG"
# SELECT FlightNo FROM FLIGHTS
# SELECT FlightNo FROM FLIGHTS WHERE DestAirport  =  "APG"
# SELECT FlightNo FROM FLIGHTS
# SELECT T1.FlightNo FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.SourceAirport   =  T2.AirportCode
# SELECT FlightNo FROM FLIGHTS
# SELECT T1.FlightNo FROM FLIGHTS AS T1 JOIN AIRPORTS AS T2 ON T1.DestAirport   =  T2.AirportCode
# SELECT SourceAirport FROM Flights
# SELECT * FROM pets
# SELECT * FROM pets WHERE weight  >  10
# SELECT count(*) FROM pets WHERE weight  >  10
# SELECT * FROM pets ORDER BY pet_age
# SELECT weight FROM pets ORDER BY pet_age
# SELECT DISTINCT petType FROM pets
# SELECT * FROM student WHERE sex  =  'F'
# SELECT DISTINCT pettype FROM pets
# SELECT count(DISTINCT pettype) FROM pets
# SELECT DISTINCT T1.Fname FROM student AS T1
# SELECT stuid FROM student
# SELECT petid FROM pets
# SELECT petid FROM pets WHERE pet_age  >  1
# SELECT DISTINCT pettype FROM pets
# SELECT * FROM pets
# SELECT * FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid
# SELECT DISTINCT T1.fname FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid
# SELECT * FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid
# SELECT * FROM student AS T1 JOIN has_pet AS T2 ON T1.stuid  =  T2.stuid
# SELECT Name FROM country
# SELECT Name FROM country WHERE IndepYear  >  1950
# SELECT count(*) FROM country
# SELECT count(*) FROM country WHERE GovernmentForm  =  "Republic"
# SELECT * FROM country WHERE Region  =  "Caribbean"
# SELECT SurfaceArea FROM country WHERE Region  =  "Caribbean"
# SELECT sum(SurfaceArea) FROM country WHERE Region  =  "Caribbean"
# SELECT Continent FROM country
# SELECT Continent FROM country WHERE Name  =  "Anguilla"
# SELECT Region FROM country
# SELECT LANGUAGE FROM countrylanguage
# SELECT Region FROM country WHERE Name  =  "Angola"
# SELECT Population FROM country WHERE Name  =  "Angola"
# SELECT LifeExpectancy FROM country
# SELECT LifeExpectancy FROM country WHERE Region  =  "Central Africa"
# SELECT avg(LifeExpectancy) FROM country WHERE Region  =  "Central Africa"
# SELECT Name FROM country WHERE Continent  =  "Asia"
# SELECT sum(Population) FROM country WHERE Continent  =  "Asia"
# SELECT max(GNP) FROM country WHERE Continent  =  "Asia"
# SELECT * FROM country WHERE Continent  =  "Africa"
# SELECT Population FROM city WHERE District  =  "Gelderland"
# SELECT sum(Population) FROM city WHERE District  =  "Gelderland"
# SELECT * FROM country
# SELECT * FROM country WHERE GovernmentForm  =  "US Territory"
# SELECT DISTINCT LANGUAGE FROM countrylanguage
# SELECT count(DISTINCT LANGUAGE) FROM countrylanguage
# SELECT DISTINCT GovernmentForm FROM country WHERE Continent  =  "Africa"
# SELECT count(DISTINCT GovernmentForm) FROM country WHERE Continent  =  "Africa"
# SELECT * FROM country WHERE Name  =  "Aruba"
# SELECT COUNT(*) FROM (SELECT T1.Name FROM country AS T1 JOIN countrylanguage AS T2 ON T1.Code  =  T2.CountryCode WHERE T2.Language  =  "English" INTERSECT SELECT T1.Name FROM country AS T1 JOIN countrylanguage AS T2 ON T1.Code  =  T2.CountryCode WHERE T2.Language  =  "Dutch")
# SELECT DISTINCT Region FROM country
# SELECT * FROM country WHERE GovernmentForm  =  "Republic"
# SELECT T1.Name FROM country AS t1
# SELECT T1.Name FROM country AS t1 WHERE  IndepYear  <  1930
# SELECT * FROM country WHERE Continent  =  "Europe"
# SELECT min(SurfaceArea) FROM country WHERE Continent  =  "Europe"
# SELECT min(population) FROM country WHERE Continent  =  "Asia"
# SELECT min(population) FROM country WHERE Continent  =  "Africa"
# SELECT CountryCode FROM countrylanguage
# SELECT DISTINCT CountryCode FROM countrylanguage
# SELECT DISTINCT CountryCode FROM countrylanguage WHERE LANGUAGE ! =  "English"
# SELECT Code FROM country WHERE GovernmentForm ! =  "Republic"
# SELECT Name FROM country
# SELECT avg(Population) FROM city
# SELECT * FROM country GROUP BY GovernmentForm HAVING avg(LifeExpectancy)  >  72
# SELECT Continent FROM country GROUP BY Continent HAVING avg(LifeExpectancy)  <  72
# SELECT * FROM country ORDER BY Population DESC
# SELECT * FROM country ORDER BY Population
# SELECT * FROM country WHERE continent  =  "Asia"
# SELECT count(*) FROM country WHERE continent  =  "Asia"
# SELECT * FROM country WHERE continent  =  "Europe"
# SELECT * FROM country WHERE Continent  =  "North America"
# SELECT name FROM city
# SELECT name FROM city WHERE Population BETWEEN 160000 AND 90000
# SELECT LANGUAGE FROM countrylanguage
# SELECT Directed_by FROM Cartoon WHERE Title = "Day of the Dark Knight!"
# SELECT Channel FROM Cartoon WHERE Title = "Day of the Dark Knight!"
# SELECT * FROM TV_Channel WHERE Country = "Italy"
# SELECT * FROM TV_Channel WHERE Country = "Poland"
# SELECT Channel FROM Cartoon WHERE Title = "The Eyes of Despero!"
# SELECT Package_Option FROM TV_Channel WHERE series_name = "Rock TV"
# SELECT Language FROM TV_Channel WHERE series_name = "Rock TV"
# SELECT Written_by FROM Cartoon WHERE Title = "The Rise of the Blue Beetle!"
# SELECT Directed_by FROM Cartoon WHERE Title = "The Rise of the Blue Beetle!"
# SELECT Country FROM TV_Channel WHERE series_name = "Sky Radio"
# SELECT Content FROM TV_Channel WHERE series_name = "Sky Radio"
# SELECT Rating FROM TV_series WHERE Episode = "Double Down"
# SELECT Rating FROM TV_series WHERE Episode = "Keepers"
# SELECT Weekly_Rank FROM TV_series WHERE Episode = "Emily"
# SELECT Share FROM TV_series WHERE Episode = "Emily"
# SELECT Rating FROM TV_series WHERE Episode = "A Love of a Lifetime"
# SELECT Weekly_Rank FROM TV_series WHERE Episode = "A Love of a Lifetime"
# SELECT Content FROM TV_Channel WHERE series_name = "Sky Radio"
# SELECT Language FROM TV_Channel WHERE series_name = "Sky Radio"
# SELECT Original_air_date FROM Cartoon WHERE Title = "Fall of the Blue Beetle!"
# SELECT Production_code FROM Cartoon WHERE Title = "Fall of the Blue Beetle!"
# SELECT Title FROM Cartoon WHERE Directed_by = "Ben Jones"
# SELECT Title FROM Cartoon WHERE Written_by = "Todd Casey"
# SELECT Directed_by FROM Cartoon WHERE Title = "Deep Cover for Batman!"
# SELECT Production_code FROM Cartoon WHERE Title = "Deep Cover for Batman!"
# SELECT Country FROM TV_Channel WHERE series_name = "MTV Music"
# SELECT COUNT(*) FROM TV_Channel WHERE Country = "Italy"
# SELECT id FROM tv_channel GROUP BY country HAVING count(*)  >  2
# SELECT Directed_by FROM Cartoon WHERE Title = "Return of the Fearsome Fangs!"
# SELECT Title FROM Cartoon WHERE Directed_by = "Ben Jones"
# SELECT * FROM poker_player
# SELECT count(*) FROM poker_player
# SELECT Earnings FROM poker_player
# SELECT Earnings FROM poker_player ORDER BY Earnings DESC
# SELECT * FROM poker_player
# SELECT Final_Table_Made FROM poker_player
# SELECT Earnings FROM poker_player
# SELECT avg(Earnings) FROM poker_player
# SELECT Money_Rank FROM poker_player
# SELECT Money_Rank FROM poker_player ORDER BY Earnings DESC
# SELECT * FROM poker_player WHERE Earnings  <  200000
# SELECT max(Final_Table_Made) FROM poker_player WHERE Earnings  <  200000
# SELECT * FROM poker_player
# SELECT T1.Name FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID
# SELECT * FROM poker_player WHERE Earnings  >  300000
# SELECT T1.Name FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID
# SELECT T1.Birth_Date FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID
# SELECT Height FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID
# SELECT Height FROM people AS T1 JOIN poker_player AS T2 ON T1.People_ID  =  T2.People_ID
# SELECT * FROM poker_player ORDER BY Earnings DESC
# SELECT Nationality FROM people
# SELECT * FROM people GROUP BY Nationality
# SELECT Nationality FROM people
# SELECT COUNT(*) FROM people GROUP BY Nationality
# SELECT COUNT(*) FROM people GROUP BY Nationality
# SELECT Nationality FROM people GROUP BY Nationality HAVING COUNT(*)  >=  2
# SELECT Name FROM people
# SELECT Name FROM people WHERE Nationality != "Russia"
# SELECT * FROM poker_player
# SELECT killed FROM death
# SELECT max(killed) FROM death
# SELECT min(killed) FROM death
# SELECT * FROM death as T1 JOIN ship as T2 ON T1.caused_by_ship_id  =  T2.id
# SELECT DISTINCT T1.name FROM battle AS T1 JOIN ship AS T2 ON T1.id  =  T2.lost_in_battle
# SELECT name FROM battle WHERE bulgarian_commander  =  'Kaloyan'
# SELECT name FROM battle WHERE latin_commander  =  'Baldwin I'
# SELECT lost_in_battle FROM ship WHERE tonnage  =  '225'
# SELECT count(*) FROM CONTINENTS;
# Select avg(horsepower) FROM CARS_DATA;
# SELECT avg(Weight) FROM CARS_DATA
# SELECT DISTINCT model FROM MODEL_LIST;
# SELECT count(*) from Countries;
# Select Count(*) FROM CAR_MAKERS;
# SELECT distinct Maker FROM CAR_MAKERS;
# SELECT count(*) FROM MODEL_LIST;
# SELECT * FROM CARS_DATA WHERE YEAR  =  1974;
# Select CountryName FROM COUNTRIES;
# SELECT avg(edispl) FROM CARS_DATA;
# SELECT distinct Model from CAR_NAMES;
# SELECT FullName FROM CAR_MAKERS;
# SELECT * FROM CAR_MAKERS AS T1 JOIN MODEL_LIST AS T2 ON T1.Id  =  T2.Maker;
# SELECT DISTINCT Year FROM CARS_DATA AS T1 WHERE Weight  >  3000;
# SELECT DISTINCT Year FROM CARS_DATA AS T1 WHERE Weight  <  4000;
# SELECT distinct T1.CountryName FROM COUNTRIES AS T1 JOIN CAR_MAKERS AS T2 ON T1.CountryId  =  T2.Country;
# SELECT COUNT(*) FROM ( SELECT T1.CountryId ,  COUNT(*) FROM COUNTRIES AS T1 JOIN CAR_MAKERS AS T2 ON T1.CountryId  =  T2.Country GROUP BY T1.CountryId HAVING count(*)  >  1 );
# SELECT COUNT(*) FROM ( SELECT T1.CountryId ,  COUNT(*) FROM COUNTRIES AS T1 JOIN CAR_MAKERS AS T2 ON T1.CountryId  =  T2.Country GROUP BY T1.CountryId HAVING count(*)  >  2 );
# SELECT min(Horsepower) FROM CARS_DATA;
# SELECT CountryName FROM countries;
# SELECT distinct T1.CountryName FROM countries AS T1 JOIN CAR_MAKERS AS T2 ON T1.countryId  =  T2.Country;
# SELECT count(*) FROM matches
# SELECT max(minutes) FROM matches
# SELECT avg(minutes) FROM matches
# SELECT count(DISTINCT tourney_name) FROM matches
# SELECT tourney_name FROM matches GROUP BY tourney_name HAVING count(*)  >  20
# SELECT tourney_name FROM matches GROUP BY tourney_name HAVING count(*)  >  10
# SELECT count(DISTINCT winner_name) FROM matches WHERE year = 2013
# SELECT count(*) FROM (SELECT winner_name FROM matches WHERE YEAR  =  2013 INTERSECT SELECT winner_name FROM matches WHERE YEAR  =  2016)
# SELECT count(*) FROM matches
# SELECT count(*) FROM matches WHERE loser_hand = "L"
# SELECT count(*) FROM players
# SELECT count(*) FROM players WHERE hand = 'R'
# SELECT count(*) FROM players WHERE hand = 'L'
# SELECT count(*) FROM players
# SELECT count(*) FROM matches
# SELECT birth_date FROM players
# SELECT count(*) FROM players GROUP BY country_code
# SELECT country_code FROM players GROUP BY country_code HAVING count(*)  >  50
# SELECT count(DISTINCT loser_name) FROM matches WHERE tourney_name  =  'Australian Open'
# SELECT count(DISTINCT winner_name) FROM matches WHERE tourney_name  =  'Australian Open'
# SELECT * FROM conductor
# SELECT count(*) FROM conductor
# SELECT Name FROM conductor
# SELECT Age FROM conductor
# SELECT Name FROM conductor ORDER BY Age ASC
# SELECT Name FROM conductor
# SELECT Name FROM conductor WHERE Nationality != 'USA'
# SELECT Record_Company FROM orchestra
# SELECT Record_Company FROM orchestra ORDER BY Year_of_Founded DESC
# SELECT Attendance FROM SHOW
# SELECT avg(Attendance) FROM SHOW
# SELECT SHARE FROM performance
# SELECT SHARE FROM performance WHERE TYPE != "Live final"
# SELECT Nationality FROM conductor
# SELECT count(DISTINCT Nationality) FROM conductor
# SELECT Name FROM conductor
# SELECT Year_of_Work FROM conductor
# SELECT Name FROM conductor ORDER BY Year_of_Work DESC
# SELECT Name FROM conductor
# SELECT Year_of_Work FROM conductor
# SELECT Name FROM conductor
# SELECT Name FROM conductor
# SELECT Name FROM conductor
# SELECT Name FROM conductor
# SELECT Record_Company FROM orchestra GROUP BY Record_Company
# SELECT Major_Record_Format FROM orchestra
# SELECT Record_Company FROM orchestra
# SELECT Orchestra FROM orchestra
# SELECT Record_Company FROM orchestra
# SELECT Record_Company FROM orchestra WHERE Year_of_Founded  <  2003
# SELECT Record_Company FROM orchestra WHERE Year_of_Founded  >  2003
# SELECT * FROM Documents
# SELECT document_id FROM Documents
# SELECT document_name FROM Documents
# SELECT document_name from Documents
# SELECT document_id FROM Documents WHERE document_name  =  "Robbin CV"
# SELECT template_id FROM Documents
# SELECT DISTINCT template_id FROM Documents
# SELECT count(DISTINCT template_id) FROM Documents
# SELECT document_id FROM Documents
# SELECT template_id FROM Documents
# SELECT template_id FROM Documents
# SELECT template_id FROM Documents
# SELECT template_id FROM Documents GROUP BY template_id HAVING count(*)  >  1
# SELECT template_id FROM Documents
# SELECT template_id FROM Templates
# SELECT * FROM Templates
# SELECT count(*) FROM Templates
# SELECT template_id FROM Templates
# SELECT template_type_code FROM Templates
# SELECT DISTINCT template_type_code FROM Templates
# SELECT template_id FROM Templates
# SELECT template_type_code FROM Templates
# SELECT count(*) FROM Templates WHERE template_type_code  =  "CV"
# SELECT version_number FROM Templates
# SELECT version_number FROM Templates WHERE version_number  >  5
# SELECT template_type_code FROM Templates
# SELECT template_type_code FROM Templates
# SELECT template_type_code FROM Templates
# SELECT template_type_code FROM Templates GROUP BY template_type_code HAVING count(*)  <  3
# SELECT Version_Number FROM Templates
# SELECT min(Version_Number) FROM Templates
# SELECT template_type_code FROM Templates
# SELECT document_name FROM Documents
# SELECT template_type_code FROM Templates
# SELECT template_type_code FROM Templates
# SELECT template_type_code FROM Templates
# SELECT template_type_code FROM Templates AS T1 JOIN Documents AS T2 ON T1.template_id  =  T2.template_id
# SELECT template_type_code FROM Ref_template_types
# SELECT template_type_description FROM Ref_template_types WHERE template_type_code  =  "AD"
# SELECT template_type_code FROM Ref_template_types
# SELECT template_type_code FROM Ref_template_types WHERE template_type_description  =  "Book"
# select Template_ID from Documents
# SELECT template_id from Templates
# SELECT * FROM Paragraphs
# SELECT count(*) FROM Paragraphs
# SELECT paragraph_id FROM Paragraphs
# SELECT paragraph_text FROM Paragraphs
# SELECT Other_Details FROM Paragraphs WHERE paragraph_text  =  'Korea'
# SELECT paragraph_text FROM Paragraphs
# SELECT document_id FROM Paragraphs
# SELECT document_id FROM Paragraphs
# SELECT document_id FROM Paragraphs GROUP BY document_id HAVING count(*)  >=  2
# SELECT document_id FROM Paragraphs
# SELECT document_id FROM Paragraphs
# SELECT document_id FROM Paragraphs GROUP BY document_id HAVING count(*) BETWEEN 1 AND 2
# SELECT * FROM singer
# SELECT count(*) FROM singer
# SELECT name FROM singer
# select age from singer
# select age from singer WHERE country  =  'France'
# select song_name from singer
# SELECT country FROM singer
# SELECT country FROM singer WHERE age  >  20
# SELECT DISTINCT country FROM singer WHERE age  >  20
# SELECT country FROM singer
# SELECT avg(age) FROM singer
# SELECT name FROM stadium
# SELECT name FROM stadium WHERE capacity BETWEEN 5000 AND 10000
# select capacity FROM stadium
# SELECT avg(capacity) FROM stadium
# SELECT * FROM concert WHERE YEAR  =  2014
# SELECT name from stadium
# SELECT YEAR FROM concert
# SELECT stadium_id FROM concert
# SELECT country FROM singer
# SELECT country FROM singer WHERE age  >  40
# SELECT country FROM singer WHERE age  <  30
# SELECT name FROM singer
# select name from singer
# SELECT name FROM singer
# SELECT Name FROM singer ORDER BY Net_Worth_Millions DESC
# SELECT DISTINCT Singer_ID from song
# SELECT * FROM employee WHERE age  <  30
# SELECT city FROM employee WHERE age  <  30
# SELECT * FROM shop
# SELECT sum(number_products) FROM shop
# SELECT avg(Number_products) FROM shop
# SELECT avg(number_products) FROM shop
# SELECT count(*) FROM evaluation
# SELECT Year_awarded FROM evaluation
# SELECT t1.name FROM employee AS t1 JOIN evaluation AS t2 ON t1.Employee_ID  =  t2.Employee_ID
# SELECT count(distinct Employee_ID) FROM evaluation
# SELECT t1.name FROM employee AS t1 JOIN evaluation AS t2 ON t1.Employee_ID  =  t2.Employee_ID
# SELECT count(distinct Shop_ID) FROM hiring
# SELECT t2.name FROM hiring AS t1 JOIN shop AS t2 ON t1.shop_id  =  t2.shop_id
# SELECT * FROM hiring
# SELECT count(*) FROM hiring
# SELECT * FROM visitor
# SELECT * FROM visitor ORDER BY Level_of_membership DESC
# SELECT name FROM visitor ORDER BY Level_of_membership DESC
# SELECT count(*) FROM visitor WHERE Level_of_membership  >  4
# SELECT count(*) FROM museum
# SELECT avg(num_of_staff) FROM museum
# SELECT name FROM museum WHERE open_year  <  2010
# SELECT name FROM museum WHERE open_year  >  2010
# SELECT min(num_of_staff) FROM museum WHERE open_year  >  2010
# SELECT t1.name FROM visitor AS t1 JOIN visit AS t2 ON t1.id  =  t2.visitor_id
# SELECT sum(Total_spent) FROM visit
# SELECT count(*) FROM museum
# SELECT sum(num_of_ticket) FROM visit
# SELECT sum(Total_spent) FROM visit
# SELECT max(Total_spent) FROM visit
# SELECT min(Level_of_membership) FROM visitor
# SELECT count(*) FROM visitor WHERE Level_of_membership  =  1
# SELECT name FROM museum WHERE open_year  <  2009
# SELECT name FROM museum WHERE open_year > 2011
# SELECT name FROM museum WHERE open_year  >  2010
# SELECT count(*) FROM Highschooler
# SELECT count(distinct grade) FROM Highschooler
# SELECT distinct grade FROM Highschooler
# SELECT count(*) FROM Highschooler
# SELECT grade FROM Highschooler GROUP BY grade HAVING count(*)  >=  10
# SELECT grade FROM Highschooler GROUP BY grade HAVING count(*)  >=  4
# SELECT name FROM highschooler
# SELECT name FROM highschooler
# SELECT count(*) FROM (SELECT * FROM Friend AS T1 JOIN Highschooler AS T2 ON T1.student_id  =  T2.id GROUP BY T1.student_id HAVING count(*)  > 5)
# SELECT count(*) FROM (SELECT * FROM Friend AS T1 JOIN Highschooler AS T2 ON T1.student_id  =  T2.id GROUP BY T1.student_id HAVING count(*)  >= 3)
# SELECT * FROM highschooler where name = "Kyle"
# SELECT * FROM highschooler where name = "Kyle"
# SELECT ID FROM highschooler
# SELECT student_id FROM Friend
# SELECT name FROM highschooler
# SELECT count(*) FROM (SELECT * FROM Friend AS T1 JOIN Highschooler AS T2 ON T1.student_id  =  T2.id GROUP BY T1.student_id HAVING count(*)  >= 5)
# SELECT distinct T2.name FROM Friend AS T1 JOIN Highschooler AS T2 ON T1.student_id  =  T2.id
# SELECT student_id FROM Friend
# SELECT count(*) FROM Likes AS T1 JOIN Highschooler AS T2 ON T1.liked_id  =  T2.id
# SELECT T2.name FROM Likes AS T1 JOIN Highschooler AS T2 ON T1.liked_id  =  T2.id
# SELECT count (*) FROM (SELECT T2.name FROM Friend AS T1 JOIN Highschooler AS T2 ON T1.student_id  =  T2.id INTERSECT SELECT T2.name FROM Likes AS T1 JOIN Highschooler AS T2 ON T1.liked_id  =  T2.id)
# SELECT T2.name FROM Likes AS T1 JOIN Highschooler AS T2 ON T1.student_id  =  T2.id
# SELECT count(distinct student_id) FROM likes
# SELECT T2.name FROM Likes AS T1 JOIN Highschooler AS T2 ON T1.student_id  =  T2.id
# SELECT name FROM highschooler
# SELECT grade FROM highschooler where name = "Kyle"
# SELECT avg(grade) FROM highschooler
# SELECT * FROM teacher
# SELECT count(*) FROM teacher
# SELECT Name FROM teacher
# SELECT Name FROM teacher ORDER BY Age ASC
# SELECT Hometown FROM teacher
# SELECT Hometown FROM teacher
# SELECT * FROM teacher WHERE Hometown != "Little Lever Urban Distric"
# SELECT Name FROM teacher WHERE Hometown != "Little Lever Urban Distric"
# SELECT Age FROM teacher
# SELECT * FROM teacher WHERE Age  =  32
# SELECT * FROM teacher ORDER BY Age
# SELECT Hometown FROM teacher
# SELECT * FROM teacher order BY Hometown
# SELECT COUNT(*) FROM teacher
# SELECT COUNT(*) FROM teacher GROUP BY Hometown
# SELECT COUNT(*) FROM teacher
# SELECT COUNT(*) FROM teacher GROUP BY Hometown
# SELECT Hometown FROM teacher GROUP BY Hometown HAVING COUNT(*)  >=  2
# SELECT * FROM course_arrange
# SELECT * FROM course_arrange
# SELECT * FROM course_arrange
# SELECT Name FROM teacher
# SELECT Name FROM teacher
# SELECT * FROM Other_Available_Features
# SELECT count(*) FROM Other_Available_Features
# SELECT * FROM Other_Available_Features WHERE feature_name  =  "AirCon"
# SELECT T2.property_type_description FROM Properties AS T1 JOIN Ref_Property_Types AS T2 ON T1.property_type_code  =  T2.property_type_code
# SELECT * FROM area_code_state
# SELECT count(*) FROM area_code_state
# SELECT * FROM contestants
# SELECT  contestant_name FROM contestants
# SELECT state FROM votes
# SELECT area_code FROM area_code_state
# SELECT max(area_code) FROM area_code_state
# SELECT min(area_code) FROM area_code_state
# SELECT * FROM votes
# SELECT * FROM votes WHERE state  =  'CA'
# SELECT max(created) FROM votes WHERE state  =  'CA'
# SELECT * FROM contestants
# SELECT contestant_name FROM contestants
# SELECT contestant_name FROM contestants WHERE contestant_name != 'Jessie Alloway'
# SELECT * FROM votes
# SELECT state FROM votes
# SELECT * FROM contestants
# SELECT * FROM votes
# SELECT * FROM contestants
# SELECT * FROM votes
# SELECT * FROM votes
# SELECT * FROM contestants
# SELECT * FROM area_code_state
# SELECT * FROM votes
# SELECT * FROM votes
# SELECT * FROM area_code_state
# SELECT * FROM Owners
# SELECT * FROM Professionals
# SELECT state FROM Professionals
# SELECT age FROM Dogs
# SELECT * FROM Professionals WHERE role_code = 'Employee'
# SELECT count(*) FROM Professionals WHERE state  =  'Connecticut'
# SELECT count(*) FROM Professionals WHERE state  =  'Indiana'
# SELECT name FROM Dogs
# SELECT * FROM Treatment_Types
# SELECT count(*) FROM professionals WHERE state = 'Hawaii'
# SELECT state FROM professionals
# SELECT count(*) FROM professionals WHERE state = 'Wisconsin'
# SELECT state FROM Owners
# SELECT count(*) FROM Owners WHERE state = 'Vermont'
# SELECT age FROM Dogs ORDER BY age
# SELECT count(*) FROM Dogs WHERE age  < 4
# SELECT * FROM Treatments
# SELECT cost_of_treatment FROM Treatments ORDER BY cost_of_treatment ASC
# SELECT cost_of_treatment FROM Treatments ORDER BY cost_of_treatment DESC
# SELECT * FROM Owners
# SELECT count(*) FROM Dogs
# SELECT * FROM Owners
# SELECT count(*) FROM Owners WHERE state = 'Arizona'
# SELECT count(*) FROM Professionals
# SELECT count(*) FROM Professionals WHERE city = 'West Heidi'
